# %%
import pandas as pd
df = pd.read_excel("runs/Mix6_mainCat_best/Pointer-Generator_Intra_Atten_32/word2Vec/exp/test_output.xls")

# %%
df.columns
# Out:
# Index(['article', 'keywords', 'reference', 'decoded', 'rouge_1', 'rouge_2',
#        'rouge_l', 'self_Bleu_1', 'self_Bleu_2', 'self_Bleu_3', 'self_Bleu_4',
#        'Bleu_1', 'Bleu_2', 'Bleu_3', 'Bleu_4', 'Meteor', 'article_lens',
#        'ref_lens', 'overlap', 'overlap_percent', 'gen_type'],
#       dtype='object')

# %%
df[df["rouge_1"]>=0.5][['rouge_1','article', 'reference', 'decoded', 'gen_type','overlap']]
# Out:
#         rouge_1                                            article  \
# 47849  0.545455  have been play with this for one week the imag...
# 47851  1.000000  this great video camera for the price . fairly...
# 47856  0.615385  like car there are those who just want drive t...
# 47812  1.000000  this very good phone system . there are many d...
# 47829  1.000000  you want cheap case that simply does the job m...
# 47790  0.714286  the sony cli the perfect combination style fun...
# 47757  0.526316  div class div input type hide name value class...
# 47731  1.000000  very nice gps very easy use really like the la...
# 47691  0.880000  had couple these was the first monopod actuall...
# 47685  0.956522  this really great price for large quantity goo...
# 47701  0.800000  this review the vomlite super bright lead bike...
# 47650  0.666667  have have this entire training system for labr...
# 47633  0.545455  use have magellan roadmate 800 and few week ag...
# ...
