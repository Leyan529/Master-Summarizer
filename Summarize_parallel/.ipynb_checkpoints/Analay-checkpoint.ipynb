# %%
import pandas as pd
from utils import config

from sklearn.model_selection import train_test_split

config.xls_path = '../Train-Data/Mix6_mainCat_20/pro_review.xlsx'
# config.xls_path = '/home/eagleuser/Users/leyan/Train-Data/Mix6_mainCat_new/pro_review.xlsx'
total_df = pd.read_excel(config.xls_path)
# total_df = total_df[total_df['review_len']>=50]
# total_df = total_df[total_df['summary_len']>=5]
total_df = total_df.sort_values(by=['review_len','overlap'], ascending = False)
train_df, val_df = train_test_split(total_df, test_size=0.1, 
                                    random_state=0, shuffle=True)

print(len(total_df))
print(len(train_df))
print(len(val_df))
# Out:
# 512937
# 461643
# 51294

# %%
def longest_common_subsequence(main_string, comparing_string):

#     main_string = main_string.split(" ")
#     comparing_string = comparing_string.split(" ")
    columns_length = len(main_string)  # Get the length of the first word or base word
    rows_length = len(comparing_string)  # Get the length of the second word or comparing word

    # MAKE A 2D LIST (MATRIX)
    dynamic_table = [[0] * (columns_length + 1) for i in range(rows_length + 1)]

    # rows_length = NUMBER OF ROWS
    # columns_length = NUMBER OF COLUMNS
    
    # FILL THE MATRIX FOLLOWING LCS ALGORITHM.
    for i in range(1, rows_length + 1):
        for j in range(1, columns_length + 1):
            if main_string[j - 1] == comparing_string[i - 1]:
                dynamic_table[i][j] = 1 + dynamic_table[i - 1][j - 1]

            else:
                dynamic_table[i][j] = max(dynamic_table[i - 1][j], dynamic_table[i][j - 1])

#     print("MATRIX ACCORDING TO LONGEST COMMON SUBSEQUENCE ALGORITHM: \n ")

    # for i in range(rows_length + 1):
    #     print(dynamic_table[i])

    #print("LENGTH OF LONGEST COMMON SUBSEQUENCE = ", dynamic_table[rows_length][columns_length])

    len_lcs = dynamic_table[rows_length][columns_length]

    i = len(comparing_string)
    j = len(main_string)

    lcs_string = str()

    # BACKTRACKING TO FIND THE LONGEST COMMON SUBSEQUENCE

    temp = True

    while temp is True:
        if dynamic_table[i][j] == 0:
            temp = False
        elif dynamic_table[i][j] == dynamic_table[i][j - 1]:
            j = j - 1

        else:
            lcs_string = main_string[j-1] + " " + lcs_string
            i = i - 1
            j = j - 1

    return lcs_string, len_lcs

# %%
# df.loc[i,'token_lcs'] = token_lcs
#             df.loc[i,'len_lcs'] = len_lcs
#             df.loc[i,'percent_lcs'] = percent_lcs
#             df.loc[i,'overlap_pos'] = overlap_pos
            
#             df.loc[i,'reveiw_len'] = len(rev_tokens)
#             df.loc[i,'summary_len'] = len(summary_tokens)

# %%
#%%
from tqdm import tqdm
from copy import deepcopy
def analay(df, mode):
    df['token_lcs'] = 0
    df['len_lcs'] = 0
    df['percent_lcs'] = 0
    df['overlap_pos'] = 0

    df['reveiw_len'] = 0
    df['summary_len'] = 0
#     df = df[:100]
    with tqdm(total=len(df)) as pbar:
        for i ,row in df.iterrows():       
            overlap_pos = None

            rev, summary = row['review'], row['summary']
            rev_tokens, summary_tokens = rev.split(" "), summary.split(" ")           
            token_lcs, len_lcs = longest_common_subsequence(rev_tokens, summary_tokens)
            percent_lcs = len_lcs / len(summary_tokens) * 100 # percent

            rev_sents = rev.split(" . ")
            overlap_sents = {idx: longest_common_subsequence(sent.split(" "), summary_tokens) for idx, sent in enumerate(rev_sents)}
            sort_overlap_sent = {k:v for k,v in sorted(overlap_sents.items(), key= lambda item: item[1], reverse=True)}
            overlap_sent_id = list(sort_overlap_sent.items())[0][0]

            if (overlap_sent_id == 0) and (percent_lcs >= 20): overlap_pos = 0 # overlap_Top 
            elif (overlap_sent_id == len(rev_tokens)-1) and (percent_lcs >= 20): overlap_pos = 1 # overlap_Final 
            elif (percent_lcs >= 20): overlap_pos = 2 # overlap_other 
            else: overlap_pos = -1 # no overlap 

            df.loc[i,'token_lcs'] = token_lcs
            df.loc[i,'len_lcs'] = len_lcs
            df.loc[i,'percent_lcs'] = percent_lcs
            df.loc[i,'overlap_pos'] = overlap_pos
            
            df.loc[i,'reveiw_len'] = len(rev_tokens)
            df.loc[i,'summary_len'] = len(summary_tokens)

            pbar.update(1)
            pbar.set_description("%s row: %s | overlap_pos: %s (%2.2f)percent| len_lcs: %s" % (mode, i, overlap_pos, percent_lcs, len_lcs))
#     df = df[df['token_lcs']!=0]
    return df

# %%
train_df.head()
# Out:
#          review_ID  rating  vote binaryrating  \
# 240956  1422144000       2     3     negative
# 509083  1514851200       2     2     negative
# 274813  1405728000       4     2     positive
# 348041  1491955200       4     4     positive
# 189227  1438128000       5     2     positive
#
#                                                    review  \
# 240956  not buy these glove they are good . after one ...
# 509083  buy this few month ago hold food . the plastic...
# 274813  the bag just picture . well construct and has ...
# 348041  purchase pair for year old son . little bigger...
# 189227  wear orthotic take out the arch support that t...
#
#                                                   summary  \
# 240956      <s> tear at the seam and hurt my knuckle </s>
# 509083             <s> lid does not click into place </s>
# 274813     <s> the bag is just as picture it is well </s>
# 348041  <s> the cup holder is the best part besides th...
# 189227  <s> my foot do not slide around but are perfec...
#
#                                                     cheat  cheat_num  overlap  \
# 240956                {'hurt', 'knuckle', 'seam', 'tear'}          4        6
# 509083                          {'click', 'place', 'lid'}          3        5
# 274813                         {'bag', 'well', 'picture'}          3        5
# 348041      {'great', 'padding', 'holder', 'best', 'cup'}          5        8
# 189227  {'foot', 'fit', 'slide', 'hurt', 'bunion', 'pe...          6       13
#
#         review_len  summary_len  \
# 240956          73           10
# 509083          86            8
# 274813          40           11
# 348041          46           13
# 189227          49           19
#
#                                                  POS_keys  \
# 240956  ['buy', 'glove', '', 'crap', 'wear', '', 'read...
# 509083  ['food', 'hold', 'size', 'correct', 'rating', ...
# 274813  ['', 'adequate', 'storage', 'insulate', 'compa...
# 348041  ['purchase', 'old', 'pair', 'son', '', '', '',...
# 189227  ['wear', 'orthotic', 'support', 'arch', 'ortho...
#
#                                                  DEP_keys  \
# 240956  ['buy', 'glove', 'crap', 'wear', 'hurt', 'knuc...
# 509083  ['ago', 'hold', 'month', 'food', 'few', 'size'...
# 274813  ['adequate', 'has', 'storage', 'construct', 'b...
# 348041  ['old', 'son', 'keep', 'cup', 'padding', 'grea...
# 189227  ['wear', 'orthotic', 'support', 'shoe', 'arch'...
#
#                                             Noun_adj_keys  \
# 240956  ['glove', 'good', 'punching', 'class', 'hardco...
# 509083  ['month', 'few', 'size', 'plastic', 'correct',...
# 274813  ['storage', 'construct', 'adequate', 'compartm...
# 348041  ['year', 'pair', 'son', 'old', 'padding', 'hol...
# 189227  ['support', 'arch', 'fit', 'perfectly orthotic...
#
#                                    TextRank_keys
# 240956              ['like', 'hardcore', 'read']
# 509083  ['month', 'ago', 'hold', 'food', 'shut']
# 274813          ['adequate', 'storage', 'water']
# 348041                      ['purchase', 'pair']
# 189227                 ['fit', 'bunion', 'shoe']

# %%
val_df.head()
# Out:
#          review_ID  rating  vote binaryrating  \
# 111956  1448841600       1    10     negative
# 356131  1205366400       2     7     negative
# 16534   1129766400       1     5     negative
# 79723   1419811200       5     2     positive
# 221481  1300752000       4    38     positive
#
#                                                    review  \
# 111956  the package come orange box chinese lettering ...
# 356131  really like this leather case but find one maj...
# 16534   have this recorder for about year . for first ...
# 79723   when see how low the price was this did lot re...
# 221481  order the red chair and far great . buy these ...
#
#                                                   summary  \
# 111956  <s> does not look anything like the amazon pri...
# 356131  <s> nice case but major flaw with the leather ...
# 16534          <s> guy do not buy this panasonic dmr </s>
# 79723   <s> an excellent dealand here how to find out ...
# 221481                <s> seat does not fold in half </s>
#
#                                                     cheat  cheat_num  overlap  \
# 111956             {'prime', 'amazon', 'picture', 'like'}          4        9
# 356131  {'major', 'belt', 'case', 'leather', 'clip', '...          6        9
# 16534                         {'buy', 'guy', 'panasonic'}          3        4
# 79723                             {'panel', 'tv', 'find'}          3        7
# 221481                           {'fold', 'seat', 'half'}          3        5
#
#         review_len  summary_len  \
# 111956          50           11
# 356131          60           13
# 16534           70            9
# 79723          143           15
# 221481         187            8
#
#                                                  POS_keys  \
# 111956  ['chinese', 'picture', 'box', 'prime', 'letter...
# 356131  ['flaw', 'major', 'case', 'clip', 'fall', 'tig...
# 16534   ['', 'first', 'mon', '', 'record', 'program', ...
# 79723   ['', 'great', 'average', 'black', 'home', 'fea...
# 221481  ['chair', 'red', '', '', 'little', 'chair', 'f...
#
#                                                  DEP_keys  \
# 111956  ['come', 'chinese', 'package', 'amazon', 'pict...
# 356131  ['find', 'major', 'case', 'leather', 'flaw', '...
# 16534   ['year', 'have', 'recorder', 'first', 'mon', '...
# 79723   ['connectivity', 'hdmi', 'drive', 'has', 'vide...
# 221481  ['chair', 'order', 'red', 'little', 'bit', 'si...
#
#                                             Noun_adj_keys  \
# 111956  ['package', 'amazon', 'picture', 'box', 'lette...
# 356131  ['leather', 'case', 'flaw', 'major', 'case', '...
# 16534   ['mon', 'first', 'service', 'time', 'contact',...
# 79723   ['video', 'connectivity', 'black', 'watch', 'c...
# 221481  ['chair', 'red', 'chair', 'bit', 'foam', 'litt...
#
#                                             TextRank_keys
# 111956                ['orange', 'box', 'chinese', 'try']
# 356131               ['leather', 'case', 'pull', 'major']
# 16534   ['ago', 'start', 'problem', 'ask', 'recorder',...
# 79723   ['panel', 'samsung', 'webpage', 'great', 'manu...
# 221481  ['red', 'chair', 'foam', 'similar', 'regular',...

# %%
p_train_df = analay(deepcopy(train_df), 'train')
p_train_df.to_excel('Analay/train_df.xlsx', encoding='utf8')

p_val_df = analay(deepcopy(val_df), 'test')
p_val_df.to_excel('Analay/val_df.xlsx', encoding='utf8')
# Out:
# train row: 285122 | overlap_pos: 2 (64.29)percent| len_lcs: 9: 100%|██████████| 461643/461643 [9:09:15<00:00, 10.63it/s]
# test row: 342607 | overlap_pos: 2 (61.54)percent| len_lcs: 8: 100%|██████████| 51294/51294 [10:19<00:00, 82.87it/s]

# %%
p_train_df.describe()
# Out:
#           review_ID         rating           vote      cheat_num  \
# count  4.616430e+05  461643.000000  461643.000000  461643.000000
# mean   1.405670e+09       3.664810      10.831203       4.135960
# std    9.223972e+07       1.519049      41.463846       1.364246
# min    9.319104e+08       1.000000       2.000000       3.000000
# 25%    1.374451e+09       2.000000       2.000000       3.000000
# 50%    1.433117e+09       4.000000       4.000000       4.000000
# 75%    1.466813e+09       5.000000       8.000000       5.000000
# max    1.537056e+09       5.000000    4971.000000      23.000000
#
#              overlap     review_len    summary_len       len_lcs  \
# count  461643.000000  461643.000000  461643.000000  461643.00000
# mean        6.949673     150.746460      11.928889       6.34022
# std         2.867635     134.184862       3.845734       3.25492
# min         3.000000      20.000000       5.000000       1.00000
# 25%         5.000000      65.000000       9.000000       4.00000
# 50%         6.000000     104.000000      11.000000       6.00000
# 75%         8.000000     182.000000      14.000000       8.00000
# max        44.000000    1000.000000      61.000000      49.00000
#
#          percent_lcs    overlap_pos     reveiw_len
# count  461643.000000  461643.000000  461643.000000
# mean       52.337098       1.498363     150.746460
# std        16.713223       0.883905     134.184862
# min         5.555556      -1.000000      20.000000
# 25%        38.461538       2.000000      65.000000
# 50%        50.000000       2.000000     104.000000
# 75%        66.666667       2.000000     182.000000
# max        92.307692       2.000000    1000.000000

# %%
import matplotlib.pyplot as plt
print('reveiw_len < 40 :',len(p_train_df[p_train_df['reveiw_len']<50]))
print('reveiw_len > 1000 :',len(p_train_df[p_train_df['reveiw_len']>=1000])) # # max pos, max_enc_steps 
s = p_train_df['reveiw_len'].describe(); print(s)
s = s.drop(labels = ['count'])
s.plot.bar()
plt.ylabel('length')
plt.title('reveiw_len')
plt.show()
# Out:
# reveiw_len < 40 : 47863
# reveiw_len > 1000 : 10
# count    461643.000000
# mean        150.746460
# std         134.184862
# min          20.000000
# 25%          65.000000
# 50%         104.000000
# 75%         182.000000
# max        1000.000000
# Name: reveiw_len, dtype: float64

# %%
print('summary_len > 40 :',len(p_train_df[p_train_df['summary_len']>40]))  # max_dec_steps
print('summary_len <= 7 :',len(p_train_df[p_train_df['summary_len']<=7])) # min_dec_steps

s = p_train_df['summary_len'].describe(); print(s)
s = s.drop(labels = ['count'])
s.plot.bar()
plt.ylabel('length')
plt.title('summary_len')
plt.show()
# Out:
# summary_len > 40 : 15
# summary_len <= 7 : 18644
# count    461643.000000
# mean         11.928889
# std           3.845734
# min           5.000000
# 25%           9.000000
# 50%          11.000000
# 75%          14.000000
# max          61.000000
# Name: summary_len, dtype: float64

# %% [markdown]
# # percent_lcs EDA(20 divided)

# %%
# 统计学上的四分为函数
# 原则上p是可以取0到1之间的任意值的。但是有一个四分位数是p分位数中较为有名的。

# 所谓四分位数；即把数值由小到大排列并分成四等份，处于三个分割点位置的数值就是四分位数。

# 第1四分位数 (Q1)，又称“较小四分位数”，等于该样本中所有数值由小到大排列后第25%的数字。
# 第2四分位数 (Q2)，又称“中位数”，等于该样本中所有数值由小到大排列后第50%的数字。
# 第3四分位数 (Q3)，又称“较大四分位数”，等于该样本中所有数值由小到大排列后第75%的数字。
# 第3四分位数与第1四分位数的差距又称四分位距（InterQuartile Range,IQR）

s = p_train_df['percent_lcs'].describe(); print(s)
s = s.drop(labels = ['count'])
s.plot.bar()
plt.ylabel('overlap(%)')
plt.title('percent_lcs')
plt.show()

print('percent_lcs x < 20 :%.2f' % float(len(p_train_df[p_train_df['percent_lcs']<20])/len(p_train_df)*100),'%' )  # overlap percent with summary
print('percent_lcs 20 < x < 40 :%.2f' % float( \
      len(p_train_df[(p_train_df['percent_lcs']>20) & (p_train_df['percent_lcs']<40)])/len(p_train_df)*100),'%')  # max_dec_steps
print('percent_lcs 40 < x < 60 :%.2f' % float( \
      len(p_train_df[(p_train_df['percent_lcs']>40) & (p_train_df['percent_lcs']<60)])/len(p_train_df)*100),'%')  # max_dec_steps
print('percent_lcs 60 < x < 80 :%.2f' % float( \
      len(p_train_df[(p_train_df['percent_lcs']>60) & (p_train_df['percent_lcs']<80)])/len(p_train_df)*100),'%')  # max_dec_steps
print('percent_lcs x > 80  :%.2f' % float( \
      len(p_train_df[(p_train_df['percent_lcs']>80)])/len(p_train_df)*100),'%')  # max_dec_steps


s = pd.Series({'x < 20':len(p_train_df[p_train_df['percent_lcs']<20])/len(p_train_df)*100, 
           '20 < x < 40':len(p_train_df[(p_train_df['percent_lcs']>20) & (p_train_df['percent_lcs']<40)])/len(p_train_df)*100, 
           '40 < x < 60':len(p_train_df[(p_train_df['percent_lcs']>40) & (p_train_df['percent_lcs']<60)])/len(p_train_df)*100, 
           '60 < x < 80':len(p_train_df[(p_train_df['percent_lcs']>60) & (p_train_df['percent_lcs']<80)])/len(p_train_df)*100, 
           'x > 80':len(p_train_df[p_train_df['percent_lcs']>80])/len(p_train_df)*100          
          })
s.plot.bar()
plt.ylabel('total(%)')
plt.title('percent_lcs EDA(20% divided)')
plt.show()
# Out:
# count    461643.000000
# mean         52.337098
# std          16.713223
# min           5.555556
# 25%          38.461538
# 50%          50.000000
# 75%          66.666667
# max          92.307692
# Name: percent_lcs, dtype: float64
# percent_lcs x < 20 :0.99 %
# percent_lcs 20 < x < 40 :24.00 %
# percent_lcs 40 < x < 60 :33.44 %
# percent_lcs 60 < x < 80 :29.90 %
# percent_lcs x > 80  :3.24 %

# %%
'''
overlap => lcs > (20% summary len)
overlap_pos : 0 Top
overlap_pos : 1 Final
overlap_pos : 2 Other Pos
overlap_pos : -1 No overlap
'''

# print('overlap Top : %2.2f'% float(len(p_train_df[p_train_df['overlap_pos'] == 0])/len(p_train_df)*100),'%') 
# print('overlap Final :%2.2f'% float(len(p_train_df[p_train_df['overlap_pos'] == 1])/len(p_train_df)*100),'%') 
# print('overlap Other Pos :%2.2f'% float(len(p_train_df[p_train_df['overlap_pos'] == 2])/len(p_train_df)*100),'%')
# print('No overlap :%2.2f'% float(len(p_train_df[p_train_df['overlap_pos'] == -1])/len(p_train_df)*100),'%') 

# s = pd.Series({'overlap Top':len(p_train_df[p_train_df['overlap_pos'] == 0])/len(p_train_df)*100, 
#            'overlap Final':len(p_train_df[p_train_df['overlap_pos'] == 1])/len(p_train_df)*100, 
#            'overlap Other Pos':len(p_train_df[p_train_df['overlap_pos'] == 2])/len(p_train_df)*100, 
#            'No overlap':len(p_train_df[p_train_df['overlap_pos'] == -1])/len(p_train_df)*100, 
#           })
# print(s)
# s.plot.bar()
# plt.ylabel('overlap(%)')
# plt.title('percent_lcs')
# plt.show()
# Out:
# '\noverlap => lcs > (20% summary len)\noverlap_pos : 0 Top\noverlap_pos : 1 Final\noverlap_pos : 2 Other Pos\noverlap_pos : -1 No overlap\n'

# %% [markdown]
# # Ext/Abs分界(50)

# %%
print('percent_lcs x > 50  %2.2f'% float(len(p_train_df[(p_train_df['percent_lcs']>50)])/len(p_train_df)*100),'%')  # max_dec_steps
print('percent_lcs x <= 50  %2.2f'% float(len(p_train_df[(p_train_df['percent_lcs']<=50)])/len(p_train_df)*100),'%')  # max_dec_steps

s = pd.Series({'x > 50':len(p_train_df[(p_train_df['percent_lcs']>50)])/len(p_train_df)*100, 
           'x < 50':len(p_train_df[(p_train_df['percent_lcs']<=50)])/len(p_train_df)*100,      
          })
s.plot.bar()
plt.ylabel('total(%)')
plt.title('percent_lcs')
plt.show()
# Out:
# percent_lcs x > 50  48.91 %
# percent_lcs x <= 50  51.09 %

# %%
'''
overlap => percent_lcs > (50% summary len)
overlap_pos : 0 Top
overlap_pos : 1 Final
overlap_pos : 2 Other Pos
overlap_pos : -1 No overlap
'''

print('overlap Top :%2.2f'% float(len(p_train_df[(p_train_df['overlap_pos'] == 0) & (p_train_df['percent_lcs']>50)])/len(p_train_df)*100),'%') 
print('overlap Final :%2.2f'% float(len(p_train_df[(p_train_df['overlap_pos'] == 1) & (p_train_df['percent_lcs']>50)])/len(p_train_df)*100),'%') 
print('overlap Other Pos :%2.2f'% float(len(p_train_df[(p_train_df['overlap_pos'] == 2) & (p_train_df['percent_lcs']>50)])/len(p_train_df)*100),'%') 
print('No overlap :%2.2f'% float(len(p_train_df[(p_train_df['percent_lcs']<=50)])/len(p_train_df)*100),'%') 

s = pd.Series({'overlap Top':len(p_train_df[(p_train_df['overlap_pos'] == 0) & (p_train_df['percent_lcs']>50)])/len(p_train_df)*100, 
           'overlap Final':len(p_train_df[(p_train_df['overlap_pos'] == 1) & (p_train_df['percent_lcs']>50)])/len(p_train_df)*100,      
           'overlap Other Pos':len(p_train_df[(p_train_df['overlap_pos'] == 2) & (p_train_df['percent_lcs']>50)])/len(p_train_df)*100,  
           'No overlap':len(p_train_df[(p_train_df['percent_lcs']<=50)])/len(p_train_df)*100,  
          })
s.plot.bar()
plt.ylabel('total(%)')
plt.title('overlap')
plt.show()
# Out:
# overlap Top :13.10 %
# overlap Final :0.00 %
# overlap Other Pos :35.80 %
# No overlap :51.09 %

# %%
def view(df, condition, view_num=10):
    package_dict = []
    for i in range(view_num):
        d1 = dict(p_train_df[eval(condition)].iloc[i])
        d2 = {'review':d1['review'],
              'summary':d1['summary'],
              'token_lcs':d1['token_lcs'],
              'overlap':d1['overlap'],
              'percent_lcs':d1['percent_lcs'],
              'keywords':d1['POS_keys']            
             }
        package_dict.append(d2)
    return package_dict
        
# view(p_train_df, "(p_train_df['overlap_pos'] == 2) & (p_train_df['percent_lcs']<50)")
view(p_train_df, "(p_train_df['review_len']<=50) & (p_train_df['percent_lcs']<=40) & (p_train_df['summary_len']>=15)")
# Out:
# [{'review': 'for the price pay this actually nice product fact would happy pay considerably more money for real leather version make quality leather rather than artificial . can see the screen talk the phone and text surf the internet without remove the phone from the bag .',
#   'summary': '<s> very nice concept at good price would love to have real leather version </s>',
#   'token_lcs': 'price would real leather version ',
#   'overlap': 6,
#   'percent_lcs': 33.33333333333333,
#   'keywords': "['product', 'nice', 'leather', 'version', 'rather', 'fact', 'real', 'quality', 'remove', 'phone', 'screen', 'talk', 'see']"},
#  {'review': 'just get today and will update review use it . first impression really good . like the functionality the various compartment . wish has one more water bottle slot though . one thing specific this color combination that the burst bright orange color practically neon orange .',
#   'summary': '<s> good first impression although dark grey burst should really read dark grey with neon orange trim </s>',
#   'token_lcs': 'first impression really orange orange ',
#   'overlap': 7,
#   'percent_lcs': 27.77777777777778,
#   'keywords': "['get', 'today', 'impression', 'first', 'various', 'compartment', 'bottle', 'though', 'color', 'orange']"},
#  {'review': 'read carefully for that take some blame however the write description specifically mention that this cable work with second generation ipad . does not there not pin connection anywhere ipad . was look for extra long cable for ipad . check that include generation ipad and order this .',
#   'summary': '<s> pay attention you can not use this cable with an ipad even though it say you can in the description </s>',
#   'token_lcs': 'this cable with ipad ',
#   'overlap': 7,
#   'percent_lcs': 18.181818181818183,
#   'keywords': "['write', 'generation', 'second', 'take', 'blame', 'description', 'connection', 'pin', 'cable', 'long', '']"},
#  {'review': 'these zoom from power but they are extremely blurry the higher magnification . already have power fix pentax binocular and they perform well that naturally go pentax when want upgrade . had over again would not have purchase this .',
#   'summary': '<s> want zoom binocular but these are not as good as the fix magnification binocular </s>',
#   'token_lcs': 'these but are the magnification binocular ',
#   'overlap': 10,
#   'percent_lcs': 37.5,
#   'keywords': "['', '', '']"},
#  {'review': 'the item take forever get here but overall nice case . bright color and really fun pop and help when anxious . all friend love pop too . however make out really cheap plastic and lot has already break off already only been use for few week .',
#   'summary': '<s> however this is definitely the longest it is take for me to receive any item purchase overseas but overall it is nice case </s>',
#   'token_lcs': 'the item but overall nice case ',
#   'overlap': 9,
#   'percent_lcs': 24.0,
#   'keywords': "['case', 'nice', 'bright', 'color', 'fun', 'pop', '', 'lot', 'already', 'plastic', 'cheap']"},
#  {'review': 'desantis quality always great . buy this for glock and not only fit perfect but there was need break like with other brand . good leather . always quality the interior was little rougher then have experience with other desantis but hoping will smooth out time .',
#   'summary': '<s> perfect fit for my glock no break in need smooth draw out of the package </s>',
#   'token_lcs': 'for glock need the out ',
#   'overlap': 9,
#   'percent_lcs': 29.411764705882355,
#   'keywords': "['always', 'desantis', '', 'leather', 'good', 'little', 'was', 'interior', 'rougher', 'quality']"},
#  {'review': 'the seal sizing guide was spot fit old town kayak like glove ship earlier than expect which allow put these the kayak week sooner . 4th july weekend come and the seal keep out bug and rain . great product from great supplier .',
#   'summary': '<s> seal do the job of keep the element and bug out of your kayak </s>',
#   'token_lcs': 'the the kayak out ',
#   'overlap': 7,
#   'percent_lcs': 25.0,
#   'keywords': "['kayak', 'town', 'old', 'week', '', 'supplier', 'great', 'product']"},
#  {'review': 'good for some type pain . however can actually push the wrong spot and cause some problem . might work for you . however most people are go wood the cutout the back you have pain cause less pain . the cushion actually pretty good otherwise .',
#   'summary': '<s> good for some with general soreness did not work as well for the coccyx pain for me </s>',
#   'token_lcs': 'good for some pain for the pain ',
#   'overlap': 6,
#   'percent_lcs': 36.84210526315789,
#   'keywords': "['type', 'good', 'spot', 'problem', 'cause', 'wrong', '', 'go', 'wood', '']"},
#  {'review': 'they make many firmware upgrade since launch and yet the main glitch still there . freeze and battery drain fast . hardware issue then only gopro4 can fix it . they spend too much money give these away pro althlete for publicity instead make stable product before mass production .',
#   'summary': '<s> full of bug am start to think it is hardware issue no firmware can solve this </s>',
#   'token_lcs': 'firmware issue can ',
#   'overlap': 5,
#   'percent_lcs': 16.666666666666664,
#   'keywords': "['main', 'glitch', 'battery', 'fast', '', 'much', 'stable', 'money', 'product']"},
#  {'review': 'what useful focal length . heavy feel solid and well make . like the focusing feature . use lot far the maximum aperture wonderful put use . great optical clarity . come with nice case . glad was fortunate enough buy .',
#   'summary': '<s> for year want such focal length the max aperture and other feature are bonus </s>',
#   'token_lcs': 'focal length and feature ',
#   'overlap': 6,
#   'percent_lcs': 25.0,
#   'keywords': "['length', 'focal', '', '', 'lot', 'use', 'wonderful', 'put', 'aperture', 'maximum', 'clarity', 'optical', 'case', 'nice', 'was', 'fortunate', 'buy', 'enough']"}]

# %%
dict(p_train_df[(p_train_df['overlap_pos'] == 2) & (p_train_df['percent_lcs']>50)].iloc[0:10])['summary']
# Out:
# 240956        <s> tear at the seam and hurt my knuckle </s>
# 348041    <s> the cup holder is the best part besides th...
# 72414     <s> nice case but front usb port are upside do...
# 332712    <s> had read the product review and two of the...
# 130017           <s> great hd monitor more than expect </s>
# 502977             <s> older dog play like puppy again </s>
# 397638    <s> buy this for my elderly father his first c...
# 161178    <s> first of all would not recommend skybell f...
# 107857    <s> camera is almost year old and the view scr...
# 303864    <s> the zipper never snag and the liner is ver...
# Name: summary, dtype: object
