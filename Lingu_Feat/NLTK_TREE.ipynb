# %%
from spacy import displacy
from collections import Counter
import en_core_web_sm
import networkx as nx

import spacy
from nltk import Tree
from spacy import displacy

from show import find_shortest_path, show_tree, show_displacy

nlp = en_core_web_sm.load()
from extract_key import extract_DEP, extract_POS

from spacy.pipeline import merge_entities
nlp.add_pipe(merge_entities)

# %%
sents = [ 'high quality image .',
         'amazing battery life .',
         'amazed with the image .',
         'Good and excellent camera .',
         'Performance is excellent .',
         'Keanu performs well .',
         'Keanu performs very well .',
         'Siri can sometimes help .',
         'I love this phone .',
         
         'Camera is worse than N81 .',
         'Support Bluetooth .',
         'very excellent volume .',
         'look excellent .',
         'exhausted very quickly .',
         'image quality high .',
        ]

# %%
for sent in sents:
    doc = nlp(sent)
    print('sentence: %s'%(doc))
    # print([(token, "head : " + token.head.text, token.dep_,token.pos_) for token in doc],'\n')
#     show_tree(doc)
#     [ print("%s(%s) ----%s----> %s(%s)"%(token.head.text, token.head.tag_,
#                                      token.dep_, 
#                                      token,token.tag_)) 
#     for token in doc]
    print(" ".join(["%s(%s)"%(token, token.tag_) for token in doc]))
    
    POS_fops = extract_POS(sent).run() 
    print(POS_fops)
    print('---------------------------------------')
# Out:
# sentence: high quality image .
# high(JJ) quality(NN) image(NN) .(.)
# (['high', 'image', 'quality'], ['image', 'quality'])
# ---------------------------------------
# sentence: amazing battery life .
# amazing(JJ) battery(NN) life(NN) .(.)
# (['amazing', 'life', 'battery'], ['life', 'battery'])
# ---------------------------------------
# sentence: amazed with the image .
# amazed(JJ) with(IN) the(DT) image(NN) .(.)
# (['image', 'amazed'], ['image', 'amazed'])
# ---------------------------------------
# sentence: Good and excellent camera .
# Good(JJ) and(CC) excellent(JJ) camera(NN) .(.)
# (['excellent', 'camera', 'Good'], ['camera', 'Good'])
# ---------------------------------------
# sentence: Performance is excellent .
# Performance(NN) is(VBZ) excellent(JJ) .(.)
# (['Performance', 'excellent'], ['Performance'])
# ---------------------------------------
# sentence: Keanu performs well .
# Keanu(NNP) performs(VBZ) well(RB) .(.)
# (['Keanu', 'well'], ['Keanu'])
# ---------------------------------------
# sentence: Keanu performs very well .
# Keanu(NNP) performs(VBZ) very(RB) well(RB) .(.)
# (['Keanu', 'well'], ['Keanu'])
# ---------------------------------------
# sentence: Siri can sometimes help .
# Siri(NNP) can(MD) sometimes(RB) help(VB) .(.)
# (['Siri', 'help'], ['Siri', 'help'])
# ---------------------------------------
# sentence: I love this phone .
# I(PRP) love(VBP) this(DT) phone(NN) .(.)
# (['love', 'phone'], ['love', 'phone'])
# ---------------------------------------
# sentence: Camera is worse than N81 .
# Camera(NN) is(VBZ) worse(JJR) than(IN) N81(NNP) .(.)
# (['Camera', 'worse'], ['Camera'])
# ---------------------------------------
# sentence: Support Bluetooth .
# Support(VB) Bluetooth(NNP) .(.)
# (['Bluetooth', 'Support'], ['Bluetooth', 'Support'])
# ---------------------------------------
# sentence: very excellent volume .
# very(RB) excellent(JJ) volume(NN) .(.)
# (['volume', 'excellent'], ['volume', 'excellent'])
# ---------------------------------------
# sentence: look excellent .
# look(VB) excellent(JJ) .(.)
# (['excellent', 'look'], ['look'])
# ---------------------------------------
# sentence: exhausted very quickly .
# exhausted(VBN) very(RB) quickly(RB) .(.)
# (['exhausted', 'quickly'], [])
# ---------------------------------------
# sentence: image quality high .
# image(NN) quality(NN) high(JJ) .(.)
# (['high', 'image', 'quality'], ['image', 'quality'])
# ---------------------------------------

# %%
sents = [ 'This camera has great zoom .',
         'The camera case looks nice .',
         'The screen wide .',
         'I love the picture quality .',
         'This camera has great zoom and resolution .',
         'The screen wide and clear .',
         'The battery life not long .',
         'The camera case nice .',
         'I love quality .'       
        ]

# %%
for sent in sents:
    doc = nlp(sent)
    print('sentence: %s'%(doc))
    # print([(token, "head : " + token.head.text, token.dep_,token.pos_) for token in doc],'\n')
    show_tree(doc)
    [ print("%s(%s) ----%s----> %s(%s)"%(token.head.text, token.head.tag_,
                                     token.dep_, 
                                     token,token.tag_)) 
    for token in doc]
    
    DEP_fops = extract_DEP(sent).run() 
    print(DEP_fops)
    print('---------------------------------------')
# Out:
# sentence: This camera has great zoom .
#      has
#   ____|______
#  |  camera  zoom
#  |    |      |
#  .   This  great
#
# camera(NN) ----det----> This(DT)
# has(VBZ) ----nsubj----> camera(NN)
# has(VBZ) ----ROOT----> has(VBZ)
# zoom(NN) ----amod----> great(JJ)
# has(VBZ) ----dobj----> zoom(NN)
# has(VBZ) ----punct----> .(.)
# (['has', 'zoom', 'great', 'camera'], ['zoom', 'camera'])
# ---------------------------------------
# sentence: The camera case looks nice .
#      looks
#   _____|________
#  |     |       case
#  |     |     ___|_____
# nice   .   The      camera
#
# case(NN) ----det----> The(DT)
# case(NN) ----compound----> camera(NN)
# looks(VBZ) ----nsubj----> case(NN)
# looks(VBZ) ----ROOT----> looks(VBZ)
# looks(VBZ) ----acomp----> nice(JJ)
# looks(VBZ) ----punct----> .(.)
# (['case', 'nice', 'looks'], ['case'])
# ---------------------------------------
# sentence: The screen wide .
#     wide
#   ___|_____
#  |       screen
#  |         |
#  .        The
#
# screen(NN) ----det----> The(DT)
# wide(RB) ----npadvmod----> screen(NN)
# wide(RB) ----ROOT----> wide(RB)
# wide(RB) ----punct----> .(.)
# (['screen', 'wide'], ['screen'])
# ---------------------------------------
# sentence: I love the picture quality .
#     love
#   ___|__________
#  |   |       quality
#  |   |     _____|_______
#  I   .   the         picture
#
# love(VBP) ----nsubj----> I(PRP)
# love(VBP) ----ROOT----> love(VBP)
# quality(NN) ----det----> the(DT)
# quality(NN) ----compound----> picture(NN)
# love(VBP) ----dobj----> quality(NN)
# love(VBP) ----punct----> .(.)
# (['quality', 'love', 'picture'], ['quality', 'picture'])
# ---------------------------------------
# sentence: This camera has great zoom and resolution .
#             has
#   ___________|____
#  |  camera       zoom
#  |    |       ____|_______
#  .   This  great and  resolution
#
# camera(NN) ----det----> This(DT)
# has(VBZ) ----nsubj----> camera(NN)
# has(VBZ) ----ROOT----> has(VBZ)
# zoom(NN) ----amod----> great(JJ)
# has(VBZ) ----dobj----> zoom(NN)
# zoom(NN) ----cc----> and(CC)
# zoom(NN) ----conj----> resolution(NN)
# has(VBZ) ----punct----> .(.)
# (['resolution', 'zoom', 'has', 'great', 'camera'], ['zoom', 'resolution', 'camera'])
# ---------------------------------------
# sentence: The screen wide and clear .
#     screen
#   ____|_________
#  |    |        wide
#  |    |      ___|_____
# The   .    and      clear
#
# screen(NN) ----det----> The(DT)
# screen(NN) ----ROOT----> screen(NN)
# screen(NN) ----amod----> wide(JJ)
# wide(JJ) ----cc----> and(CC)
# wide(JJ) ----conj----> clear(JJ)
# screen(NN) ----punct----> .(.)
# (['screen', 'clear', 'wide'], ['screen'])
# ---------------------------------------
# sentence: The battery life not long .
#     long
#   ___|________
#  |   |       life
#  |   |     ___|______
# not  .   The      battery
#
# life(NN) ----det----> The(DT)
# life(NN) ----compound----> battery(NN)
# long(RB) ----nsubj----> life(NN)
# long(RB) ----neg----> not(RB)
# long(RB) ----ROOT----> long(RB)
# long(RB) ----punct----> .(.)
# (['life', 'long', 'not', 'battery'], ['life', 'battery'])
# ---------------------------------------
# sentence: The camera case nice .
#     nice
#   ___|____
#  |       case
#  |    ____|_____
#  .  The       camera
#
# case(NN) ----det----> The(DT)
# case(NN) ----compound----> camera(NN)
# nice(JJ) ----nsubj----> case(NN)
# nice(JJ) ----ROOT----> nice(JJ)
# nice(JJ) ----punct----> .(.)
# (['case', 'nice', 'camera'], ['case', 'camera'])
# ---------------------------------------
# sentence: I love quality .
#       love
#   _____|_____
#  I  quality  .
#
# love(VBP) ----nsubj----> I(PRP)
# love(VBP) ----ROOT----> love(VBP)
# love(VBP) ----dobj----> quality(NN)
# love(VBP) ----punct----> .(.)
# (['quality', 'love'], ['quality'])
# ---------------------------------------
