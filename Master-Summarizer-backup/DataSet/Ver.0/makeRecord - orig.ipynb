# %%
import sys
# from product import *
from data_util.product import *

import pandas as pd
import random
import time
import re

import os
import hashlib
import struct
import subprocess
import collections
import tensorflow as tf
from tensorflow.core.example import example_pb2
import nltk

import sys
import shutil
import tqdm
import random

from copy import deepcopy
# from product import *

VOCAB_SIZE = 50000
CHUNK_SIZE = 1000  # num examples per chunk, for the chunked data

# %% [markdown]
# # Key word Attention DataSet 讀取

# %%
# from data_util.config import *
# _, category1, category2, _ = DVD_Player().getAttr()
_,category1,category2,_ = Cameras().getAttr()
# _,category1,category2,_ = Cell_Phones().getAttr()
# _,category1,category2,_ = GPS().getAttr()
# _,category1,category2,_ = Keyboards().getAttr()
# category1,category2 = config.category1 , config.category2

xlsx_path = "XLSX/category/%s_%s_key.xlsx"%(category1,category2)
# df.to_csv(csv_path) #默认dt是DataFrame的一个实例，参数解释如下
# key_train_df.to_excel(csv_path, encoding='utf8')
orign_key_df = pd.read_excel(xlsx_path)
print(xlsx_path + " Read finished")
len(orign_key_df)
orign_key_df.head()
# Out:
# XLSX/category/Electronics_Cameras_key.xlsx Read finished
#     review_ID                                             review  \
# 0  1356566400  this book was almost as small a pamphlet for 2...
# 1  1325721600  this book is a collectors item and i love they...
# 2   951782400  i would like to say the the cannon elph37oz is...
# 3   985910400  i have had and used q 370z for over a year and...
# 4   967075200  i used this camera once and it took relatively...
#
#                                   summary big_categories small_categories  \
# 0                               too small    Electronics     Camera Cases
# 1               wonderful book a keepsake    Electronics     Camera Cases
# 2                   elph 37oz is the best    Electronics      APS Cameras
# 3            a good all around aps camera    Electronics      APS Cameras
# 4  terrible camera worse customer service    Electronics      APS Cameras
#
#                                          lemm_review  \
# 0  ['this book was almost as small a pamphlet for...
# 1  ['this book is a collector item and i love the...
# 2  ['i would like to say the the cannon elph37 oz...
# 3  ['i have have and use q 370z for over a year a...
# 4  ['i use this camera once and it take relativel...
#
#                                         lemm_summary  lemm_review_len  \
# 0                              <s> too small </s> \n               44
# 1              <s> wonderful book a keepsake </s> \n               53
# 2                 <s> elph 37 oz is the best </s> \n               58
# 3           <s> a good all around aps camera </s> \n              137
# 4  <s> terrible camera worse customer service </s...               96
#
#    lemm_summary_len  overall  vote  \
# 0                 4        1     2
# 1                 6        5     9
# 2                 8        5    51
# 3                 8        5    13
# 4                 7        1    48
#
#                                        total_keyword  \
# 0                                                NaN
# 1  item wonderful,quality item,nostalgia wonderfu...
# 2           camera inferior,money extra,camera cheap
# 3  eye red,light low room increase lense mm,slrs ...
# 4  memory internal camera service camera send sty...
#
#                                            FOP_sents  \
# 0                                                NaN
# 1  great quality though and a wonderful nostalgia...
# 2  pay the extra money and get this one rather th...
# 3  yes i sometimes get red eye in low light but a...
# 4  however on my next trip the camera s internal ...
#
#                               total_mention_features
# 0  intend small book pamphlet gift expect emphasi...
# 1  item collector book price copy high buy price ...
# 2  cannon money camera buy decide camera picture ...
# 3  snapshot photographer year low lens red avoid ...
# 4  camera picture camera trip memory service comp...

# %% [markdown]
# # Key word load

# %%
fn = 'FOP-View/%s_%s_keywords2.txt' % (category1, category2)
print('load %s keywords...' % (fn))
total_keywords = set()
with open(fn, 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line in lines:
        k, v = line.split(":")
        total_keywords.add(k)
# Out:
# load FOP-View/Electronics_Cameras_keywords2.txt keywords...

# %% [markdown]
# # Total Opinion

# %%
opinion_lexicon = {}
for filename in os.listdir('opinion-lexicon-English/'):      
    if "txt" not in filename: continue
    print(filename)
    with open('opinion-lexicon-English/'+filename,'r') as f_input:
        lexion = []
        for line in f_input:
            if line.startswith(";"):
                continue
            word = line.replace("\n","")
            if word != "" : lexion.append(word)
        pos = filename.replace(".txt","")
        opinion_lexicon[pos] = lexion

opinion_lexicon["total-words"] = opinion_lexicon["negative-words"] + opinion_lexicon["positive-words"]
print("total-words 已取得")
# Out:
# negative-words.txt
# positive-words.txt
# total-words 已取得

# %% [markdown]
# # Summary 資料清理

# %%
import spacy
from collections import Counter
import en_core_web_sm
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English

nlp = en_core_web_sm.load()

# %%
def compose_summary(x):
    x = x.replace("\n","").replace("</s>","").replace("<s>","")
    x = "<s>" + x + "</s>"  
    x = " ".join([str(token) for token in nlp(x) if (" " not in str(token)) and \
                  (str(token).isalpha()) and \
                  (len(str(token)) > 1)   ])
    return x


def create_custom_tokenizer(nlp):
    prefix_re = re.compile(r'[0-9]\.')
    return Tokenizer(nlp.vocab, prefix_search=prefix_re.search)

def calc_summary_len(x):
#     tokens = [token for token in nlp(x)]
#     print(tokens)
#     print([len(t) for t in tokens])
#     return len(tokens)
    return len(x.split(" "))

nlp.tokenizer = create_custom_tokenizer(nlp)

orign_key_df['lemm_summary'] = orign_key_df['lemm_summary'].apply(compose_summary)
orign_key_df['lemm_summary_len'] = orign_key_df['lemm_summary'].apply(calc_summary_len)


amount = len(orign_key_df)
print('Total data : %s'%(amount))

orign_key_df.head()
# Out:
# Total data : 154488
#     review_ID                                             review  \
# 0  1356566400  this book was almost as small a pamphlet for 2...
# 1  1325721600  this book is a collectors item and i love they...
# 2   951782400  i would like to say the the cannon elph37oz is...
# 3   985910400  i have had and used q 370z for over a year and...
# 4   967075200  i used this camera once and it took relatively...
#
#                                   summary big_categories small_categories  \
# 0                               too small    Electronics     Camera Cases
# 1               wonderful book a keepsake    Electronics     Camera Cases
# 2                   elph 37oz is the best    Electronics      APS Cameras
# 3            a good all around aps camera    Electronics      APS Cameras
# 4  terrible camera worse customer service    Electronics      APS Cameras
#
#                                          lemm_review  \
# 0  ['this book was almost as small a pamphlet for...
# 1  ['this book is a collector item and i love the...
# 2  ['i would like to say the the cannon elph37 oz...
# 3  ['i have have and use q 370z for over a year a...
# 4  ['i use this camera once and it take relativel...
#
#                              lemm_summary  lemm_review_len  lemm_summary_len  \
# 0                               too small               44                 2
# 1                 wonderful book keepsake               53                 3
# 2                     elph oz is the best               58                 5
# 3              good all around aps camera              137                 5
# 4  terrible camera worse customer service               96                 5
#
#    overall  vote                                      total_keyword  \
# 0        1     2                                                NaN
# 1        5     9  item wonderful,quality item,nostalgia wonderfu...
# 2        5    51           camera inferior,money extra,camera cheap
# 3        5    13  eye red,light low room increase lense mm,slrs ...
# 4        1    48  memory internal camera service camera send sty...
#
#                                            FOP_sents  \
# 0                                                NaN
# 1  great quality though and a wonderful nostalgia...
# 2  pay the extra money and get this one rather th...
# 3  yes i sometimes get red eye in low light but a...
# 4  however on my next trip the camera s internal ...
#
#                               total_mention_features
# 0  intend small book pamphlet gift expect emphasi...
# 1  item collector book price copy high buy price ...
# 2  cannon money camera buy decide camera picture ...
# 3  snapshot photographer year low lens red avoid ...
# 4  camera picture camera trip memory service comp...

# %% [markdown]
# # review 多句合併

# %%
from copy import deepcopy
def compose_review(x):
    x = eval(x)
    x = "\n".join(x)
    x = x.replace("\n"," ")    
#     tokens = [str(token) for token in x.split(" ") if (" " not in str(token))and (str(token) == '.' or str(token).isalpha())]
    tokens = [str(token) for token in x.split(" ") if (" " not in str(token)) ]

    return " ".join(tokens)

def calc_review_len(x):
#     tokens = [token for token in nlp(x)]
#     print(tokens)
#     print([len(t) for t in tokens])
#     return len(tokens)
    return len(x.split(" "))
key_df = deepcopy(orign_key_df)
key_df['lemm_review'] = key_df['lemm_review'].apply(compose_review)
key_df['lemm_review_len'] = key_df['lemm_review'].apply(calc_review_len)
key_df.head()
# Out:
#     review_ID                                             review  \
# 0  1356566400  this book was almost as small a pamphlet for 2...
# 1  1325721600  this book is a collectors item and i love they...
# 2   951782400  i would like to say the the cannon elph37oz is...
# 3   985910400  i have had and used q 370z for over a year and...
# 4   967075200  i used this camera once and it took relatively...
#
#                                   summary big_categories small_categories  \
# 0                               too small    Electronics     Camera Cases
# 1               wonderful book a keepsake    Electronics     Camera Cases
# 2                   elph 37oz is the best    Electronics      APS Cameras
# 3            a good all around aps camera    Electronics      APS Cameras
# 4  terrible camera worse customer service    Electronics      APS Cameras
#
#                                          lemm_review  \
# 0  this book was almost as small a pamphlet for 2...
# 1  this book is a collector item and i love they ...
# 2  i would like to say the the cannon elph37 oz i...
# 3  i have have and use q 370z for over a year and...
# 4  i use this camera once and it take relatively ...
#
#                              lemm_summary  lemm_review_len  lemm_summary_len  \
# 0                               too small               47                 2
# 1                 wonderful book keepsake               58                 3
# 2                     elph oz is the best               61                 5
# 3              good all around aps camera              143                 5
# 4  terrible camera worse customer service              102                 5
#
#    overall  vote                                      total_keyword  \
# 0        1     2                                                NaN
# 1        5     9  item wonderful,quality item,nostalgia wonderfu...
# 2        5    51           camera inferior,money extra,camera cheap
# 3        5    13  eye red,light low room increase lense mm,slrs ...
# 4        1    48  memory internal camera service camera send sty...
#
#                                            FOP_sents  \
# 0                                                NaN
# 1  great quality though and a wonderful nostalgia...
# 2  pay the extra money and get this one rather th...
# 3  yes i sometimes get red eye in low light but a...
# 4  however on my next trip the camera s internal ...
#
#                               total_mention_features
# 0  intend small book pamphlet gift expect emphasi...
# 1  item collector book price copy high buy price ...
# 2  cannon money camera buy decide camera picture ...
# 3  snapshot photographer year low lens red avoid ...
# 4  camera picture camera trip memory service comp...

# %%
orign_key_df.head()
# Out:
#     review_ID                                             review  \
# 0  1356566400  this book was almost as small a pamphlet for 2...
# 1  1325721600  this book is a collectors item and i love they...
# 2   951782400  i would like to say the the cannon elph37oz is...
# 3   985910400  i have had and used q 370z for over a year and...
# 4   967075200  i used this camera once and it took relatively...
#
#                                   summary big_categories small_categories  \
# 0                               too small    Electronics     Camera Cases
# 1               wonderful book a keepsake    Electronics     Camera Cases
# 2                   elph 37oz is the best    Electronics      APS Cameras
# 3            a good all around aps camera    Electronics      APS Cameras
# 4  terrible camera worse customer service    Electronics      APS Cameras
#
#                                          lemm_review  \
# 0  ['this book was almost as small a pamphlet for...
# 1  ['this book is a collector item and i love the...
# 2  ['i would like to say the the cannon elph37 oz...
# 3  ['i have have and use q 370z for over a year a...
# 4  ['i use this camera once and it take relativel...
#
#                              lemm_summary  lemm_review_len  lemm_summary_len  \
# 0                               too small               44                 2
# 1                 wonderful book keepsake               53                 3
# 2                     elph oz is the best               58                 5
# 3              good all around aps camera              137                 5
# 4  terrible camera worse customer service               96                 5
#
#    overall  vote                                      total_keyword  \
# 0        1     2                                                NaN
# 1        5     9  item wonderful,quality item,nostalgia wonderfu...
# 2        5    51           camera inferior,money extra,camera cheap
# 3        5    13  eye red,light low room increase lense mm,slrs ...
# 4        1    48  memory internal camera service camera send sty...
#
#                                            FOP_sents  \
# 0                                                NaN
# 1  great quality though and a wonderful nostalgia...
# 2  pay the extra money and get this one rather th...
# 3  yes i sometimes get red eye in low light but a...
# 4  however on my next trip the camera s internal ...
#
#                               total_mention_features
# 0  intend small book pamphlet gift expect emphasi...
# 1  item collector book price copy high buy price ...
# 2  cannon money camera buy decide camera picture ...
# 3  snapshot photographer year low lens red avoid ...
# 4  camera picture camera trip memory service comp...

# %% [markdown]
# # 過濾不合適的訓練資料

# %%
def to_words(text):
    keywords = set()
    for words in text.split(","):
        for word in words.split(" "):
            keywords.add(word)
    keywords = " ".join(keywords)
    return keywords

def calc_keyword_num(x):
    return len(x.split(" "))

# and(key_df.lemm_review_len>20)
flit_key_df = key_df[(key_df.lemm_summary_len>=4) ] # 過濾single word summary
flit_key_df = flit_key_df[(flit_key_df.lemm_review_len <= 1000) ] # 過濾single word summary
flit_key_df = flit_key_df[(flit_key_df.lemm_review_len >= 50) ] # 過濾single word summary

flit_key_df = flit_key_df.dropna(
    axis=0,     # 0: 对行进行操作; 1: 对列进行操作
    how='any'   # 'any': 只要存在 NaN 就 drop 掉; 'all': 必须全部是 NaN 才 drop 
    )

# %% [markdown]
# # FOP_keywords 資料整理

# %%
flit_key_df['FOP_keywords'] = flit_key_df['total_keyword']
flit_key_df['FOP_keywords'] = flit_key_df['FOP_keywords'].apply(to_words)
flit_key_df['FOP_keywords_num'] = flit_key_df['FOP_keywords'].apply(calc_keyword_num)
flit_key_df = flit_key_df[(flit_key_df.FOP_keywords_num>=2) ] # 過濾single word summary
flit_key_df.head()
# Out:
#    review_ID                                             review  \
# 2  951782400  i would like to say the the cannon elph37oz is...
# 3  985910400  i have had and used q 370z for over a year and...
# 4  967075200  i used this camera once and it took relatively...
# 7  964742400  we are headed on vacation in a couple of weeks...
# 8  951868800  my review will focus on how well the 370z repl...
#
#                                              summary big_categories  \
# 2                              elph 37oz is the best    Electronics
# 3                       a good all around aps camera    Electronics
# 4             terrible camera worse customer service    Electronics
# 7                     i returned it and went digital    Electronics
# 8  a good enough replacement for 35mm point and s...    Electronics
#
#   small_categories                                        lemm_review  \
# 2      APS Cameras  i would like to say the the cannon elph37 oz i...
# 3      APS Cameras  i have have and use q 370z for over a year and...
# 4      APS Cameras  i use this camera once and it take relatively ...
# 7      APS Cameras  we are head on vacation in a couple of week an...
# 8      APS Cameras  my review will focus on how well the 370z repl...
#
#                                      lemm_summary  lemm_review_len  \
# 2                             elph oz is the best               61
# 3                      good all around aps camera              143
# 4          terrible camera worse customer service              102
# 7                        return it and go digital              177
# 8  good enough replacement for mm point and shoot              449
#
#    lemm_summary_len  overall  vote  \
# 2                 5        5    51
# 3                 5        5    13
# 4                 5        1    48
# 7                 5        2    34
# 8                 8        4   316
#
#                                        total_keyword  \
# 2           camera inferior,money extra,camera cheap
# 3  eye red,light low room increase lense mm,slrs ...
# 4  memory internal camera service camera send sty...
# 7  day cloudy,day dark,day indoor,day sunny,day o...
# 8  resolution indistinguishable definition precis...
#
#                                            FOP_sents  \
# 2  pay the extra money and get this one rather th...
# 3  yes i sometimes get red eye in low light but a...
# 4  however on my next trip the camera s internal ...
# 7  i try indoor outdoors sunny day after dark and...
# 8  resolution indistinguishable on 4x6 4x7 print ...
#
#                               total_mention_features  \
# 2  cannon money camera buy decide camera picture ...
# 3  snapshot photographer year low lens red avoid ...
# 4  camera picture camera trip memory service comp...
# 7  head vacation week lightweight couple camera t...
# 8  shoot point replace mm review focus replace si...
#
#                                         FOP_keywords  FOP_keywords_num
# 2                  money cheap inferior camera extra                 5
# 3      light room red eye mm lense increase slrs low                 9
# 4  money save olympus service stylus internal mem...                 9
# 7  resolution day dark outdoors cloudy sunny indo...                 9
# 8  resolution cartridge vacation continuous chang...                29

# %% [markdown]
# # Cheat Processing

# %%
flit_key_df['Cheat'] = False 

# flit_key_df.head()
from tqdm import tqdm
# 非符號alpha word重疊數
with tqdm(total=len(flit_key_df)) as pbar:
    for i ,row in flit_key_df.iterrows():
        rev_tokens = set(row['lemm_review'].split(" "))
#         rev_tokens = [str(token) for token in rev_tokens if not (str(token) == '.' or str(token).isalpha())]
#         rev_tokens = set(rev_tokens)
        
#         if 's' in rev_tokens: rev_tokens.remove('s')
#         if '.' in rev_tokens: rev_tokens.remove('.')
#         if 'i' in rev_tokens: rev_tokens.remove('i')
#         if 'a' in rev_tokens: rev_tokens.remove('a')
#         if 'the' in rev_tokens: rev_tokens.remove('the')
        
        summ_tokens = set(row['lemm_summary'].split(" "))
        key_words = rev_tokens & summ_tokens & (total_keywords| set(opinion_lexicon["total-words"]))
        if len(key_words) > 2: 
#             print(True)
            flit_key_df.loc[i,'Cheat'] = True

#         print(rev_tokens)
#         print(summ_tokens)
#         print([len(t) for t in summ_tokens])
        pbar.update(1)
    
flit_key_df = flit_key_df[(flit_key_df.Cheat == True) ] # 過濾single word summary
amount = len(flit_key_df)
print('Total data : %s'%(amount))
flit_key_df.head()
# Out:
# 100%|██████████| 77493/77493 [01:52<00:00, 690.01it/s]
# Total data : 32102
#     review_ID                                             review  \
# 4   967075200  i used this camera once and it took relatively...
# 8   951868800  my review will focus on how well the 370z repl...
# 10  974332800  if you want a point and shoot camera that you ...
# 35  942883200  i have had my camera for two months and i love...
# 44  960163200  when i got this camera it is nice looking and ...
#
#                                               summary big_categories  \
# 4              terrible camera worse customer service    Electronics
# 8   a good enough replacement for 35mm point and s...    Electronics
# 10                            best compact aps camera    Electronics
# 35   great first digital camera for non photographers    Electronics
# 44  use 3 days to trouble shoot the connecting the...    Electronics
#
#    small_categories                                        lemm_review  \
# 4       APS Cameras  i use this camera once and it take relatively ...
# 8       APS Cameras  my review will focus on how well the 370z repl...
# 10      APS Cameras  if you want a point and shoot camera that you ...
# 35  Digital Cameras  i have have my camera for two month and i love...
# 44  Digital Cameras  when i get this camera it is nice looking and ...
#
#                                          lemm_summary  lemm_review_len  \
# 4              terrible camera worse customer service              102
# 8      good enough replacement for mm point and shoot              449
# 10                            best compact aps camera              189
# 35    great first digital camera for non photographer              110
# 44  use day to trouble shoot the connect the seria...              193
#
#     lemm_summary_len  overall  vote  \
# 4                  5        1    48
# 8                  8        4   316
# 10                 4        5    79
# 35                 7        4    91
# 44                10        3     8
#
#                                         total_keyword  \
# 4   memory internal camera service camera send sty...
# 8   resolution indistinguishable definition precis...
# 10  range zoon,range size,size zoon,set pretty bro...
# 35             quality good,quality very good,mb card
# 44  buying worth picture nice photo upload cable s...
#
#                                             FOP_sents  \
# 4   however on my next trip the camera s internal ...
# 8   resolution indistinguishable on 4x6 4x7 print ...
# 10  i look at a pretty broad set of camera include...
# 35  i wish that it would take the 16 mb and the 32...
# 44  when i get this camera it is nice looking and ...
#
#                                total_mention_features  \
# 4   camera picture camera trip memory service comp...
# 8   shoot point replace mm review focus replace si...
# 10  shoot throw carry point bag camera shirt pocke...
# 35  month camera photographer professional picture...
# 44  camera buying picture day photo computer uploa...
#
#                                          FOP_keywords  FOP_keywords_num  Cheat
# 4   money save olympus service stylus internal mem...                 9   True
# 8   resolution cartridge vacation continuous chang...                29   True
# 10  simplicity size range surprisingly pretty broa...                13   True
# 35                          very mb card good quality                 5   True
# 44  worth serial photo upload nice cable buying pi...                11   True

# %% [markdown]
# # TextRank_keywords 資料整理

# %%
from summa import keywords as TextRank
from summa.summarizer import summarize
def textrank_keys(text):
    keywords1 = list()
    for words in TextRank.keywords(text).split('\n'):
        keywords1.extend(words.split(" "))
    keywords1 = set(keywords1)    
    
    return " ".join(list(keywords1))

def textrank_summ_keys(text): 
    keywords2 = list()
    for words in summarize(text, words=8).split('\n'):
        keywords2.extend(words.split(" "))
    keywords2 = set(keywords2)
    
    return " ".join(list(keywords2))

# flit_key_df['TextRank_keywords'] = flit_key_df['lemm_review'].apply(textrank_to_words)
# flit_key_df['TextRank_keywords_num'] = flit_key_df['TextRank_keywords'].apply(calc_num)
flit_key_df['TextRank_keywords'] = flit_key_df['FOP_keywords'] 
flit_key_df['TextRank_keywords_num'] = flit_key_df['FOP_keywords_num'] 
flit_key_df.loc[:,'TextRank_keywords'] = ''
flit_key_df.loc[:,'TextRank_keywords_num'] = 0
flit_key_df.head()
# Out:
#     review_ID                                             review  \
# 4   967075200  i used this camera once and it took relatively...
# 8   951868800  my review will focus on how well the 370z repl...
# 10  974332800  if you want a point and shoot camera that you ...
# 35  942883200  i have had my camera for two months and i love...
# 44  960163200  when i got this camera it is nice looking and ...
#
#                                               summary big_categories  \
# 4              terrible camera worse customer service    Electronics
# 8   a good enough replacement for 35mm point and s...    Electronics
# 10                            best compact aps camera    Electronics
# 35   great first digital camera for non photographers    Electronics
# 44  use 3 days to trouble shoot the connecting the...    Electronics
#
#    small_categories                                        lemm_review  \
# 4       APS Cameras  i use this camera once and it take relatively ...
# 8       APS Cameras  my review will focus on how well the 370z repl...
# 10      APS Cameras  if you want a point and shoot camera that you ...
# 35  Digital Cameras  i have have my camera for two month and i love...
# 44  Digital Cameras  when i get this camera it is nice looking and ...
#
#                                          lemm_summary  lemm_review_len  \
# 4              terrible camera worse customer service              102
# 8      good enough replacement for mm point and shoot              449
# 10                            best compact aps camera              189
# 35    great first digital camera for non photographer              110
# 44  use day to trouble shoot the connect the seria...              193
#
#     lemm_summary_len  overall  vote  \
# 4                  5        1    48
# 8                  8        4   316
# 10                 4        5    79
# 35                 7        4    91
# 44                10        3     8
#
#                                         total_keyword  \
# 4   memory internal camera service camera send sty...
# 8   resolution indistinguishable definition precis...
# 10  range zoon,range size,size zoon,set pretty bro...
# 35             quality good,quality very good,mb card
# 44  buying worth picture nice photo upload cable s...
#
#                                             FOP_sents  \
# 4   however on my next trip the camera s internal ...
# 8   resolution indistinguishable on 4x6 4x7 print ...
# 10  i look at a pretty broad set of camera include...
# 35  i wish that it would take the 16 mb and the 32...
# 44  when i get this camera it is nice looking and ...
#
#                                total_mention_features  \
# 4   camera picture camera trip memory service comp...
# 8   shoot point replace mm review focus replace si...
# 10  shoot throw carry point bag camera shirt pocke...
# 35  month camera photographer professional picture...
# 44  camera buying picture day photo computer uploa...
#
#                                          FOP_keywords  FOP_keywords_num  \
# 4   money save olympus service stylus internal mem...                 9
# 8   resolution cartridge vacation continuous chang...                29
# 10  simplicity size range surprisingly pretty broa...                13
# 35                          very mb card good quality                 5
# 44  worth serial photo upload nice cable buying pi...                11
#
#     Cheat TextRank_keywords  TextRank_keywords_num
# 4    True                                        0
# 8    True                                        0
# 10   True                                        0
# 35   True                                        0
# 44   True                                        0

# %%
from tqdm import tqdm
with tqdm(total=len(flit_key_df)) as pbar:
    for i ,row in flit_key_df.iterrows():
        TextRank_keywords = textrank_keys(row['lemm_review'])
    #     TextRank_keywords = textrank_summ_keys(row['lemm_review'])  
        num = calc_keyword_num(TextRank_keywords)
        flit_key_df.loc[i,'TextRank_keywords'] = TextRank_keywords
        flit_key_df.loc[i,'TextRank_keywords_num'] = num
        pbar.update(1)
        
flit_key_df.head()
# Out:
# 100%|██████████| 32102/32102 [06:22<00:00, 83.87it/s]
#     review_ID                                             review  \
# 4   967075200  i used this camera once and it took relatively...
# 8   951868800  my review will focus on how well the 370z repl...
# 10  974332800  if you want a point and shoot camera that you ...
# 35  942883200  i have had my camera for two months and i love...
# 44  960163200  when i got this camera it is nice looking and ...
#
#                                               summary big_categories  \
# 4              terrible camera worse customer service    Electronics
# 8   a good enough replacement for 35mm point and s...    Electronics
# 10                            best compact aps camera    Electronics
# 35   great first digital camera for non photographers    Electronics
# 44  use 3 days to trouble shoot the connecting the...    Electronics
#
#    small_categories                                        lemm_review  \
# 4       APS Cameras  i use this camera once and it take relatively ...
# 8       APS Cameras  my review will focus on how well the 370z repl...
# 10      APS Cameras  if you want a point and shoot camera that you ...
# 35  Digital Cameras  i have have my camera for two month and i love...
# 44  Digital Cameras  when i get this camera it is nice looking and ...
#
#                                          lemm_summary  lemm_review_len  \
# 4              terrible camera worse customer service              102
# 8      good enough replacement for mm point and shoot              449
# 10                            best compact aps camera              189
# 35    great first digital camera for non photographer              110
# 44  use day to trouble shoot the connect the seria...              193
#
#     lemm_summary_len  overall  vote  \
# 4                  5        1    48
# 8                  8        4   316
# 10                 4        5    79
# 35                 7        4    91
# 44                10        3     8
#
#                                         total_keyword  \
# 4   memory internal camera service camera send sty...
# 8   resolution indistinguishable definition precis...
# 10  range zoon,range size,size zoon,set pretty bro...
# 35             quality good,quality very good,mb card
# 44  buying worth picture nice photo upload cable s...
#
#                                             FOP_sents  \
# 4   however on my next trip the camera s internal ...
# 8   resolution indistinguishable on 4x6 4x7 print ...
# 10  i look at a pretty broad set of camera include...
# 35  i wish that it would take the 16 mb and the 32...
# 44  when i get this camera it is nice looking and ...
#
#                                total_mention_features  \
# 4   camera picture camera trip memory service comp...
# 8   shoot point replace mm review focus replace si...
# 10  shoot throw carry point bag camera shirt pocke...
# 35  month camera photographer professional picture...
# 44  camera buying picture day photo computer uploa...
#
#                                          FOP_keywords  FOP_keywords_num  \
# 4   money save olympus service stylus internal mem...                 9
# 8   resolution cartridge vacation continuous chang...                29
# 10  simplicity size range surprisingly pretty broa...                13
# 35                          very mb card good quality                 5
# 44  worth serial photo upload nice cable buying pi...                11
#
#     Cheat                                  TextRank_keywords  \
# 4    True                                  worse camera good
# 8    True  shot resolution day z red frame focal eye prec...
# 10   True  shoot shot expensive include speed wide option...
# 35   True                  photographer quality professional
# 44   True                  worth serial looking nice picture
#
#     TextRank_keywords_num
# 4                       3
# 8                      16
# 10                      9
# 35                      3
# 44                      5

# %%
from matplotlib import pyplot as plt
if not os.path.exists('XLSX/statistic'):
    os.makedirs('XLSX/statistic')
with open('XLSX/statistic/%s_%s_info.txt'%(category1,category2),'w') as f:
    max_rev_len = flit_key_df['lemm_review_len'].max()
    min_rev_len = flit_key_df['lemm_review_len'].min()
    mean_rev_len = flit_key_df['lemm_review_len'].mean()
    median_rev_len = flit_key_df['lemm_review_len'].median()

    f.write('max_rev_len :%s \n'%(max_rev_len))
    f.write('min_rev_len :%s \n'%(min_rev_len))
    f.write('mean_rev_len :%s \n'%(mean_rev_len))
    f.write('median_rev_len :%s \n'%(median_rev_len))
    
    f.write('\n\n\n')
    max_summary_len = flit_key_df['lemm_summary_len'].max()
    min_summary_len = flit_key_df['lemm_summary_len'].min()
    mean_summary_len = flit_key_df['lemm_summary_len'].mean()
    median_summary_len = flit_key_df['lemm_summary_len'].median()

    f.write('max_summary_len :%s \n'%(max_summary_len))
    f.write('min_summary_len :%s \n'%(min_summary_len))
    f.write('mean_summary_len :%s \n'%(mean_summary_len))
    f.write('median_summary_len :%s \n'%(median_summary_len))
    
    f.write('\n\n\n')
    max_FOP_keywords_num = flit_key_df['FOP_keywords_num'].max()
    min_FOP_keywords_num = flit_key_df['FOP_keywords_num'].min()
    mean_FOP_keywords_num = flit_key_df['FOP_keywords_num'].mean()
    median_FOP_keywords_num = flit_key_df['FOP_keywords_num'].median()

    f.write('max_FOP_keywords_num :%s \n'%(max_FOP_keywords_num))
    f.write('min_FOP_keywords_num :%s \n'%(min_FOP_keywords_num))
    f.write('mean_FOP_keywords_num :%s \n'%(mean_FOP_keywords_num))
    f.write('median_FOP_keywords_num :%s \n'%(median_FOP_keywords_num))
    
    f.write('\n\n\n')
    max_TextRank_keywords_num = flit_key_df['TextRank_keywords_num'].max()
    min_TextRank_keywords_num = flit_key_df['TextRank_keywords_num'].min()
    mean_TextRank_keywords_num = flit_key_df['TextRank_keywords_num'].mean()
    median_TextRank_keywords_num = flit_key_df['TextRank_keywords_num'].median()

    f.write('max_TextRank_keywords_num :%s \n'%(max_TextRank_keywords_num))
    f.write('min_TextRank_keywords_num :%s \n'%(min_TextRank_keywords_num))
    f.write('mean_TextRank_keywords_num :%s \n'%(mean_TextRank_keywords_num))
    f.write('median_TextRank_keywords_num :%s \n'%(median_TextRank_keywords_num))

    

# plt.xlim(xmax = mean_rev_len)
# plt.ylim(ymax = flit_key_df['lemm_review_len'].value_counts().max())

flit_key_df['lemm_review_len'].value_counts().hist()
plt.savefig('XLSX/statistic/review_len_%s_%s.png'%(category1,category2))
plt.show()
plt.close()

# plt.xlim(xmax = max_summary_len)
# plt.ylim(ymax = flit_key_df['lemm_summary_len'].value_counts().max())
flit_key_df['lemm_summary_len'].value_counts().hist()
plt.savefig('XLSX/statistic/summary_len_%s_%s.png'%(category1,category2))
plt.show()
plt.close()

# plt.xlim(xmax = mean_keyword_num)
flit_key_df['FOP_keywords_num'].value_counts().hist()
plt.savefig('XLSX/statistic/FOP_keywords_num_%s_%s.png'%(category1,category2))
plt.show()
plt.close()

flit_key_df['TextRank_keywords_num'].value_counts().hist()
plt.savefig('XLSX/statistic/TextRank_keywords_num_%s_%s.png'%(category1,category2))
plt.show()
plt.close()

# %% [markdown]
# # 製作record bin檔

# %%
import shutil
if not os.path.exists('bin'):
    shutil.rmtree('/bin', ignore_errors=True)

if not os.path.exists('bin/category/chunked'):
    os.makedirs('bin/category/chunked')

makevocab = True
if makevocab:
    vocab_counter = collections.Counter()
    
# train_file
flit_key_train_df = flit_key_df.iloc[:int(amount*0.6)]

# test_file
flit_key_test_df = flit_key_df.iloc[int(amount*0.6)+1:int(amount*0.8)]

# vald_file
flit_key_valid_df = flit_key_df.iloc[int(amount*0.8)+1:]
sentence_start = "<s>"
sentence_end = "</s>"


def xlsx2bin(set_name,df):
    sents = []
    with open("bin/category/%s.bin"%(set_name), 'wb') as file:
        i = 0
        for idx in tqdm(range(len(df))):
            series = df.iloc[idx]
            data_dict = series.to_dict()
            review_ID , big_categories , small_categories , \
            review , lemm_review , summary , lemm_summary , FOP_keywords ,TextRank_keywords = \
            data_dict['review_ID'],data_dict['big_categories'],data_dict['small_categories'],data_dict['review'],data_dict['lemm_review'], \
            data_dict['summary'],data_dict['lemm_summary'],data_dict['FOP_keywords'] ,data_dict['TextRank_keywords']
#             print(FOP_keywords)

            # save Embedding/word2Vec calculate sents
#             for sent in nltk.sent_tokenize(lemm_review):
#                 sent = sent.replace("." ,"")
#                 sents.append(str(sent).split()) # 切分词汇 

#             for sent in nltk.sent_tokenize(lemm_summary):
#                 sent = sent.replace(sentence_start ,"").replace(sentence_end ,"")
#                 sents.append(str(sent).split()) # 切分词汇 

            lemm_review = lemm_review.replace("\n","")
            lemm_summary = lemm_summary.replace("\n","").replace("."," ")
            lemm_summary = sentence_start + ' '+ lemm_summary + ' ' + sentence_end
#             print(lemm_summary)
            # Write to tf.Example
            tf_example = example_pb2.Example()
            try:
                tf_example.features.feature['orign_review'].bytes_list.value.extend(
                    [tf.compat.as_bytes(review, encoding='utf-8')])

                tf_example.features.feature['orign_summary'].bytes_list.value.extend(
                    [tf.compat.as_bytes(summary, encoding='utf-8')])
                
                tf_example.features.feature['review'].bytes_list.value.extend(
                    [tf.compat.as_bytes(lemm_review, encoding='utf-8')])

                tf_example.features.feature['summary'].bytes_list.value.extend(
                    [tf.compat.as_bytes(lemm_summary, encoding='utf-8')]) 
        
                tf_example.features.feature['FOP_keywords'].bytes_list.value.extend(
                    [tf.compat.as_bytes(FOP_keywords, encoding='utf-8')]) 
            
                tf_example.features.feature['TextRank_keywords'].bytes_list.value.extend(
                    [tf.compat.as_bytes(TextRank_keywords, encoding='utf-8')]) 

                tf_example_str = tf_example.SerializeToString()
                str_len = len(tf_example_str)  
                file.write(struct.pack('q', str_len))
                file.write(struct.pack('%ds' % str_len, tf_example_str))
            except Exception as e:
#                 print(e)
                pass
    print(" %s finished... "%(file.name))
    return sents
    
    
sents1 = xlsx2bin('train',flit_key_train_df)
sents2 = xlsx2bin('test',flit_key_test_df)
sents3 = xlsx2bin('valid',flit_key_valid_df)
# Out:
# 100%|██████████| 19261/19261 [00:03<00:00, 4865.95it/s]
#   7%|▋         | 426/6419 [00:00<00:01, 4250.68it/s]
#  bin/category/train.bin finished...
# 100%|██████████| 6419/6419 [00:01<00:00, 4761.68it/s]
#   8%|▊         | 514/6420 [00:00<00:01, 5135.07it/s]
#  bin/category/test.bin finished...
# 100%|██████████| 6420/6420 [00:01<00:00, 4995.66it/s]
#  bin/category/valid.bin finished...

# %%
with open("bin/category/bin-info.txt",'w',encoding='utf-8') as f :
    f.write("train : %s\n"%(len(flit_key_train_df)))
    f.write("test : %s\n"%(len(flit_key_test_df)))
    f.write("valid : %s\n"%(len(flit_key_valid_df)))

# %% [markdown]
# # 分割record bin檔(1000為單位)

# %%
def chunk_file(set_name, chunks_dir):
    in_file = 'bin/category/%s.bin' % set_name
    reader = open(in_file, "rb")
    chunk = 0
    finished = False
    while not finished:
#         chunk_fname = os.path.join('bin', '/%s/%s_%03d.bin' % (chunks_dir,set_name, chunk))  # new chunk
        chunk_fname = '%s/%s/%s_%03d.bin' % (chunks_dir,set_name,set_name, chunk)
        with open(chunk_fname, 'wb') as writer:
            for _ in range(CHUNK_SIZE):
                len_bytes = reader.read(8)
                if not len_bytes:
                    finished = True
                    break
                str_len = struct.unpack('q', len_bytes)[0]
                example_str = struct.unpack('%ds' % str_len, reader.read(str_len))[0]
                writer.write(struct.pack('q', str_len))
                writer.write(struct.pack('%ds' % str_len, example_str))
            chunk += 1


def chunk_all(chunks_dir = 'bin/category/chunked'):
    # Make a dir to hold the chunks
    
    # Chunk the data
    for set_name in ['train', 'valid', 'test']:
        if not os.path.isdir(os.path.join(chunks_dir,set_name)):
            os.mkdir(os.path.join(chunks_dir,set_name))
        print("Splitting %s data into chunks..." % set_name)
        chunk_file(set_name, chunks_dir)
    print("Saved chunked data in %s" % chunks_dir)
    
chunk_all()
# Out:
# Splitting train data into chunks...
# Splitting valid data into chunks...
# Splitting test data into chunks...
# Saved chunked data in bin/category/chunked

# %%
def main_valid():
    #Performing rouge evaluation on 1.9 lakh sentences takes lot of time. So, create mini validation set & test set by borrowing 15k samples each from these 1.9 lakh sentences
    bin_valid_chuncks = os.listdir('bin/category/chunked/valid/')
    bin_valid_chuncks.sort()
    if not os.path.exists('bin/category/chunked/main_valid'):
        os.makedirs('bin/category/chunked/main_valid')
        
    samples = random.sample(set(bin_valid_chuncks[:-1]), 2)      #Exclude last bin file; contains only 9k sentences
    valid_chunk, test_chunk = samples[0], samples[1]
    shutil.copyfile(os.path.join('bin/category/chunked/valid', valid_chunk), os.path.join("bin/category/chunked/main_valid", "valid_00.bin"))
    shutil.copyfile(os.path.join('bin/category/chunked/valid', test_chunk), os.path.join("bin/category/chunked/main_valid", "test_00.bin"))
main_valid()

# %% [markdown]
# # Embedding/word2Vec

# %%
sentences = [] # total sentence
for idx in tqdm(range(len(orign_key_df))):
    series = orign_key_df.iloc[idx]
    data_dict = series.to_dict()
    lemm_review_sents , lemm_summary  = data_dict['lemm_review'],data_dict['lemm_summary'] 
    lemm_review_sents = eval(lemm_review_sents)
    for sent in lemm_review_sents:
        sent_tokens = sent.split(" ")
#         tokens = [str(token) for token in sent.split() if (" " not in str(token))and (str(token) == '.' or str(token).isalpha())]
        tokens = [str(token) for token in sent.split() if (" " not in str(token))]
        sentences.append(tokens)     
    sentences.append(lemm_summary.split(" "))
print('word2Vec training sentence finished...')
# Out:
# 100%|██████████| 154488/154488 [00:42<00:00, 3630.81it/s]
# word2Vec training sentence finished...

# %%
# sentences = sents1 + sents2 + sents3

# %%
# 引入 word2vec
from gensim.models import word2vec
from glob import glob
import sys

import gensim
import torch
import torch.nn as nn
import torchsnooper
import os
import numpy as np

# 引入日志配置
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

vocab_count = 50000
# write vocab to file
if not os.path.exists('Embedding/category/word2Vec'):
    os.makedirs('Embedding/category/word2Vec')

# %%
if not os.path.exists("Embedding/category/word2Vec/word2Vec.300d.txt"):

    w2vec = word2vec.Word2Vec(sentences, size=300, min_count=1,max_vocab_size=None,iter=100,
                              sorted_vocab=1,max_final_vocab=vocab_count)

    

    w2vec.wv.save_word2vec_format('Embedding/category/word2Vec/word2Vec.300d.txt', binary=False)

    #保存模型，供日後使用
    # w2vec.save("Embedding/word2Vec/word2vec.model")
# Out:
# 2020-01-17 01:31:35,432 : INFO : collecting all words and their counts
# 2020-01-17 01:31:35,433 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-01-17 01:31:35,461 : INFO : PROGRESS: at sentence #10000, processed 169892 words, keeping 7021 word types
# 2020-01-17 01:31:35,486 : INFO : PROGRESS: at sentence #20000, processed 343690 words, keeping 10145 word types
# 2020-01-17 01:31:35,512 : INFO : PROGRESS: at sentence #30000, processed 515837 words, keeping 12352 word types
# 2020-01-17 01:31:35,537 : INFO : PROGRESS: at sentence #40000, processed 688469 words, keeping 14293 word types
# 2020-01-17 01:31:35,563 : INFO : PROGRESS: at sentence #50000, processed 861038 words, keeping 16162 word types
# 2020-01-17 01:31:35,587 : INFO : PROGRESS: at sentence #60000, processed 1032577 words, keeping 17704 word types
# 2020-01-17 01:31:35,614 : INFO : PROGRESS: at sentence #70000, processed 1207925 words, keeping 19145 word types
# 2020-01-17 01:31:35,638 : INFO : PROGRESS: at sentence #80000, processed 1378457 words, keeping 20605 word types
# 2020-01-17 01:31:35,664 : INFO : PROGRESS: at sentence #90000, processed 1549535 words, keeping 21946 word types
# 2020-01-17 01:31:35,692 : INFO : PROGRESS: at sentence #100000, processed 1725177 words, keeping 23284 word types
# 2020-01-17 01:31:35,718 : INFO : PROGRESS: at sentence #110000, processed 1900366 words, keeping 24821 word types
# 2020-01-17 01:31:35,744 : INFO : PROGRESS: at sentence #120000, processed 2072631 words, keeping 26100 word types
# 2020-01-17 01:31:35,772 : INFO : PROGRESS: at sentence #130000, processed 2247993 words, keeping 27384 word types
# 2020-01-17 01:31:35,799 : INFO : PROGRESS: at sentence #140000, processed 2424132 words, keeping 28614 word types
# 2020-01-17 01:31:35,824 : INFO : PROGRESS: at sentence #150000, processed 2596567 words, keeping 29640 word types
# 2020-01-17 01:31:35,850 : INFO : PROGRESS: at sentence #160000, processed 2770609 words, keeping 30699 word types
# 2020-01-17 01:31:35,876 : INFO : PROGRESS: at sentence #170000, processed 2954828 words, keeping 31715 word types
# 2020-01-17 01:31:35,922 : INFO : PROGRESS: at sentence #180000, processed 3128134 words, keeping 32610 word types
# 2020-01-17 01:31:35,957 : INFO : PROGRESS: at sentence #190000, processed 3303410 words, keeping 33538 word types
# 2020-01-17 01:31:35,992 : INFO : PROGRESS: at sentence #200000, processed 3476114 words, keeping 34338 word types
# 2020-01-17 01:31:36,019 : INFO : PROGRESS: at sentence #210000, processed 3648478 words, keeping 35227 word types
# 2020-01-17 01:31:36,046 : INFO : PROGRESS: at sentence #220000, processed 3824959 words, keeping 36055 word types
# 2020-01-17 01:31:36,072 : INFO : PROGRESS: at sentence #230000, processed 4001380 words, keeping 36988 word types
# 2020-01-17 01:31:36,102 : INFO : PROGRESS: at sentence #240000, processed 4178959 words, keeping 37936 word types
# 2020-01-17 01:31:36,142 : INFO : PROGRESS: at sentence #250000, processed 4350552 words, keeping 38856 word types
# 2020-01-17 01:31:36,170 : INFO : PROGRESS: at sentence #260000, processed 4524688 words, keeping 39735 word types
# 2020-01-17 01:31:36,195 : INFO : PROGRESS: at sentence #270000, processed 4698862 words, keeping 40375 word types
# 2020-01-17 01:31:36,222 : INFO : PROGRESS: at sentence #280000, processed 4866326 words, keeping 41213 word types
# 2020-01-17 01:31:36,248 : INFO : PROGRESS: at sentence #290000, processed 5043051 words, keeping 42002 word types
# 2020-01-17 01:31:36,279 : INFO : PROGRESS: at sentence #300000, processed 5214019 words, keeping 42732 word types
# 2020-01-17 01:31:36,307 : INFO : PROGRESS: at sentence #310000, processed 5389487 words, keeping 43413 word types
# 2020-01-17 01:31:36,336 : INFO : PROGRESS: at sentence #320000, processed 5564692 words, keeping 44287 word types
# 2020-01-17 01:31:36,364 : INFO : PROGRESS: at sentence #330000, processed 5743620 words, keeping 44874 word types
# 2020-01-17 01:31:36,389 : INFO : PROGRESS: at sentence #340000, processed 5912185 words, keeping 45622 word types
# 2020-01-17 01:31:36,419 : INFO : PROGRESS: at sentence #350000, processed 6082753 words, keeping 46230 word types
# 2020-01-17 01:31:36,449 : INFO : PROGRESS: at sentence #360000, processed 6253137 words, keeping 46762 word types
# 2020-01-17 01:31:36,475 : INFO : PROGRESS: at sentence #370000, processed 6430719 words, keeping 47521 word types
# 2020-01-17 01:31:36,503 : INFO : PROGRESS: at sentence #380000, processed 6605658 words, keeping 48319 word types
# 2020-01-17 01:31:36,527 : INFO : PROGRESS: at sentence #390000, processed 6784289 words, keeping 48968 word types
# 2020-01-17 01:31:36,556 : INFO : PROGRESS: at sentence #400000, processed 6963049 words, keeping 49777 word types
# 2020-01-17 01:31:36,584 : INFO : PROGRESS: at sentence #410000, processed 7153302 words, keeping 50203 word types
# 2020-01-17 01:31:36,610 : INFO : PROGRESS: at sentence #420000, processed 7336105 words, keeping 50730 word types
# 2020-01-17 01:31:36,637 : INFO : PROGRESS: at sentence #430000, processed 7517755 words, keeping 51212 word types
# 2020-01-17 01:31:36,664 : INFO : PROGRESS: at sentence #440000, processed 7700485 words, keeping 51524 word types
# 2020-01-17 01:31:36,690 : INFO : PROGRESS: at sentence #450000, processed 7875308 words, keeping 51879 word types
# 2020-01-17 01:31:36,717 : INFO : PROGRESS: at sentence #460000, processed 8051093 words, keeping 52140 word types
# 2020-01-17 01:31:36,743 : INFO : PROGRESS: at sentence #470000, processed 8221499 words, keeping 52459 word types
# 2020-01-17 01:31:36,784 : INFO : PROGRESS: at sentence #480000, processed 8405534 words, keeping 52739 word types
# 2020-01-17 01:31:36,810 : INFO : PROGRESS: at sentence #490000, processed 8587868 words, keeping 53102 word types
# 2020-01-17 01:31:36,836 : INFO : PROGRESS: at sentence #500000, processed 8772776 words, keeping 53493 word types
# 2020-01-17 01:31:36,861 : INFO : PROGRESS: at sentence #510000, processed 8951188 words, keeping 53854 word types
# 2020-01-17 01:31:36,888 : INFO : PROGRESS: at sentence #520000, processed 9134337 words, keeping 54143 word types
# 2020-01-17 01:31:36,915 : INFO : PROGRESS: at sentence #530000, processed 9317032 words, keeping 54717 word types
# 2020-01-17 01:31:36,943 : INFO : PROGRESS: at sentence #540000, processed 9497292 words, keeping 55389 word types
# 2020-01-17 01:31:36,972 : INFO : PROGRESS: at sentence #550000, processed 9682537 words, keeping 56114 word types
# 2020-01-17 01:31:37,015 : INFO : PROGRESS: at sentence #560000, processed 9867981 words, keeping 56679 word types
# 2020-01-17 01:31:37,050 : INFO : PROGRESS: at sentence #570000, processed 10052410 words, keeping 57272 word types
# 2020-01-17 01:31:37,077 : INFO : PROGRESS: at sentence #580000, processed 10226320 words, keeping 57859 word types
# 2020-01-17 01:31:37,102 : INFO : PROGRESS: at sentence #590000, processed 10402316 words, keeping 58465 word types
# 2020-01-17 01:31:37,127 : INFO : PROGRESS: at sentence #600000, processed 10580682 words, keeping 59089 word types
# 2020-01-17 01:31:37,156 : INFO : PROGRESS: at sentence #610000, processed 10764073 words, keeping 59751 word types
# 2020-01-17 01:31:37,184 : INFO : PROGRESS: at sentence #620000, processed 10940793 words, keeping 60229 word types
# 2020-01-17 01:31:37,211 : INFO : PROGRESS: at sentence #630000, processed 11117877 words, keeping 60765 word types
# 2020-01-17 01:31:37,239 : INFO : PROGRESS: at sentence #640000, processed 11307844 words, keeping 61366 word types
# 2020-01-17 01:31:37,266 : INFO : PROGRESS: at sentence #650000, processed 11485023 words, keeping 62012 word types
# 2020-01-17 01:31:37,293 : INFO : PROGRESS: at sentence #660000, processed 11666986 words, keeping 62621 word types
# 2020-01-17 01:31:37,322 : INFO : PROGRESS: at sentence #670000, processed 11851261 words, keeping 63124 word types
# 2020-01-17 01:31:37,366 : INFO : PROGRESS: at sentence #680000, processed 12033950 words, keeping 63781 word types
# 2020-01-17 01:31:37,395 : INFO : PROGRESS: at sentence #690000, processed 12210015 words, keeping 64364 word types
# 2020-01-17 01:31:37,422 : INFO : PROGRESS: at sentence #700000, processed 12397810 words, keeping 64927 word types
# 2020-01-17 01:31:37,450 : INFO : PROGRESS: at sentence #710000, processed 12576862 words, keeping 65509 word types
# 2020-01-17 01:31:37,475 : INFO : PROGRESS: at sentence #720000, processed 12751214 words, keeping 66158 word types
# 2020-01-17 01:31:37,504 : INFO : PROGRESS: at sentence #730000, processed 12934760 words, keeping 66724 word types
# 2020-01-17 01:31:37,529 : INFO : PROGRESS: at sentence #740000, processed 13110728 words, keeping 67162 word types
# 2020-01-17 01:31:37,561 : INFO : PROGRESS: at sentence #750000, processed 13298152 words, keeping 67908 word types
# 2020-01-17 01:31:37,591 : INFO : PROGRESS: at sentence #760000, processed 13483750 words, keeping 68473 word types
# 2020-01-17 01:31:37,618 : INFO : PROGRESS: at sentence #770000, processed 13671440 words, keeping 68986 word types
# 2020-01-17 01:31:37,646 : INFO : PROGRESS: at sentence #780000, processed 13845927 words, keeping 69517 word types
# 2020-01-17 01:31:37,678 : INFO : PROGRESS: at sentence #790000, processed 14025432 words, keeping 70039 word types
# 2020-01-17 01:31:37,707 : INFO : PROGRESS: at sentence #800000, processed 14222784 words, keeping 70616 word types
# 2020-01-17 01:31:37,736 : INFO : PROGRESS: at sentence #810000, processed 14411974 words, keeping 71059 word types
# 2020-01-17 01:31:37,763 : INFO : PROGRESS: at sentence #820000, processed 14596461 words, keeping 71523 word types
# 2020-01-17 01:31:37,807 : INFO : PROGRESS: at sentence #830000, processed 14772383 words, keeping 72027 word types
# 2020-01-17 01:31:37,834 : INFO : PROGRESS: at sentence #840000, processed 14952243 words, keeping 72578 word types
# 2020-01-17 01:31:37,872 : INFO : PROGRESS: at sentence #850000, processed 15136060 words, keeping 73120 word types
# 2020-01-17 01:31:37,899 : INFO : PROGRESS: at sentence #860000, processed 15317613 words, keeping 73699 word types
# 2020-01-17 01:31:37,927 : INFO : PROGRESS: at sentence #870000, processed 15495137 words, keeping 74329 word types
# 2020-01-17 01:31:37,954 : INFO : PROGRESS: at sentence #880000, processed 15673956 words, keeping 74808 word types
# 2020-01-17 01:31:37,983 : INFO : PROGRESS: at sentence #890000, processed 15861832 words, keeping 75315 word types
# 2020-01-17 01:31:38,013 : INFO : PROGRESS: at sentence #900000, processed 16048524 words, keeping 75819 word types
# 2020-01-17 01:31:38,042 : INFO : PROGRESS: at sentence #910000, processed 16240809 words, keeping 76367 word types
# 2020-01-17 01:31:38,070 : INFO : PROGRESS: at sentence #920000, processed 16421817 words, keeping 77033 word types
# 2020-01-17 01:31:38,098 : INFO : PROGRESS: at sentence #930000, processed 16604327 words, keeping 77579 word types
# 2020-01-17 01:31:38,124 : INFO : PROGRESS: at sentence #940000, processed 16785110 words, keeping 78071 word types
# 2020-01-17 01:31:38,155 : INFO : PROGRESS: at sentence #950000, processed 16965371 words, keeping 78656 word types
# 2020-01-17 01:31:38,183 : INFO : PROGRESS: at sentence #960000, processed 17148240 words, keeping 79148 word types
# 2020-01-17 01:31:38,212 : INFO : PROGRESS: at sentence #970000, processed 17322970 words, keeping 79580 word types
# 2020-01-17 01:31:38,240 : INFO : PROGRESS: at sentence #980000, processed 17497858 words, keeping 79997 word types
# 2020-01-17 01:31:38,268 : INFO : PROGRESS: at sentence #990000, processed 17677321 words, keeping 80377 word types
# 2020-01-17 01:31:38,297 : INFO : PROGRESS: at sentence #1000000, processed 17855641 words, keeping 80900 word types
# 2020-01-17 01:31:38,325 : INFO : PROGRESS: at sentence #1010000, processed 18038264 words, keeping 81421 word types
# 2020-01-17 01:31:38,352 : INFO : PROGRESS: at sentence #1020000, processed 18220594 words, keeping 81945 word types
# 2020-01-17 01:31:38,380 : INFO : PROGRESS: at sentence #1030000, processed 18408560 words, keeping 82467 word types
# 2020-01-17 01:31:38,409 : INFO : PROGRESS: at sentence #1040000, processed 18584597 words, keeping 83017 word types
# 2020-01-17 01:31:38,436 : INFO : PROGRESS: at sentence #1050000, processed 18769484 words, keeping 83510 word types
# 2020-01-17 01:31:38,464 : INFO : PROGRESS: at sentence #1060000, processed 18960948 words, keeping 84058 word types
# 2020-01-17 01:31:38,490 : INFO : PROGRESS: at sentence #1070000, processed 19144742 words, keeping 84422 word types
# 2020-01-17 01:31:38,521 : INFO : PROGRESS: at sentence #1080000, processed 19321899 words, keeping 84905 word types
# 2020-01-17 01:31:38,550 : INFO : PROGRESS: at sentence #1090000, processed 19501838 words, keeping 85463 word types
# 2020-01-17 01:31:38,577 : INFO : PROGRESS: at sentence #1100000, processed 19681847 words, keeping 86068 word types
# 2020-01-17 01:31:38,603 : INFO : PROGRESS: at sentence #1110000, processed 19852124 words, keeping 86563 word types
# 2020-01-17 01:31:38,630 : INFO : PROGRESS: at sentence #1120000, processed 20039599 words, keeping 87002 word types
# 2020-01-17 01:31:38,660 : INFO : PROGRESS: at sentence #1130000, processed 20216926 words, keeping 87424 word types
# 2020-01-17 01:31:38,686 : INFO : PROGRESS: at sentence #1140000, processed 20391496 words, keeping 87845 word types
# 2020-01-17 01:31:38,712 : INFO : PROGRESS: at sentence #1150000, processed 20562001 words, keeping 88221 word types
# 2020-01-17 01:31:38,741 : INFO : PROGRESS: at sentence #1160000, processed 20743377 words, keeping 88608 word types
# 2020-01-17 01:31:38,766 : INFO : PROGRESS: at sentence #1170000, processed 20913659 words, keeping 89033 word types
# 2020-01-17 01:31:38,793 : INFO : PROGRESS: at sentence #1180000, processed 21087144 words, keeping 89541 word types
# 2020-01-17 01:31:38,819 : INFO : PROGRESS: at sentence #1190000, processed 21259954 words, keeping 89969 word types
# 2020-01-17 01:31:38,845 : INFO : PROGRESS: at sentence #1200000, processed 21430060 words, keeping 90490 word types
# 2020-01-17 01:31:38,873 : INFO : PROGRESS: at sentence #1210000, processed 21608338 words, keeping 91055 word types
# 2020-01-17 01:31:38,900 : INFO : PROGRESS: at sentence #1220000, processed 21776245 words, keeping 91486 word types
# 2020-01-17 01:31:38,927 : INFO : PROGRESS: at sentence #1230000, processed 21951184 words, keeping 91917 word types
# 2020-01-17 01:31:38,954 : INFO : PROGRESS: at sentence #1240000, processed 22134688 words, keeping 92396 word types
# 2020-01-17 01:31:38,986 : INFO : PROGRESS: at sentence #1250000, processed 22313216 words, keeping 92920 word types
# 2020-01-17 01:31:39,013 : INFO : PROGRESS: at sentence #1260000, processed 22488010 words, keeping 93431 word types
# 2020-01-17 01:31:39,043 : INFO : PROGRESS: at sentence #1270000, processed 22677751 words, keeping 93925 word types
# 2020-01-17 01:31:39,070 : INFO : PROGRESS: at sentence #1280000, processed 22855080 words, keeping 94345 word types
# 2020-01-17 01:31:39,096 : INFO : PROGRESS: at sentence #1290000, processed 23027115 words, keeping 94839 word types
# 2020-01-17 01:31:39,122 : INFO : PROGRESS: at sentence #1300000, processed 23195824 words, keeping 95280 word types
# 2020-01-17 01:31:39,148 : INFO : PROGRESS: at sentence #1310000, processed 23369790 words, keeping 95662 word types
# 2020-01-17 01:31:39,174 : INFO : PROGRESS: at sentence #1320000, processed 23537424 words, keeping 96030 word types
# 2020-01-17 01:31:39,201 : INFO : PROGRESS: at sentence #1330000, processed 23711730 words, keeping 96320 word types
# 2020-01-17 01:31:39,227 : INFO : PROGRESS: at sentence #1340000, processed 23884500 words, keeping 96732 word types
# 2020-01-17 01:31:39,254 : INFO : PROGRESS: at sentence #1350000, processed 24056760 words, keeping 97041 word types
# 2020-01-17 01:31:39,280 : INFO : PROGRESS: at sentence #1360000, processed 24226850 words, keeping 97526 word types
# 2020-01-17 01:31:39,308 : INFO : PROGRESS: at sentence #1370000, processed 24398096 words, keeping 98011 word types
# 2020-01-17 01:31:39,334 : INFO : PROGRESS: at sentence #1380000, processed 24566567 words, keeping 98443 word types
# 2020-01-17 01:31:39,359 : INFO : PROGRESS: at sentence #1390000, processed 24740007 words, keeping 98829 word types
# 2020-01-17 01:31:39,384 : INFO : PROGRESS: at sentence #1400000, processed 24910699 words, keeping 99303 word types
# 2020-01-17 01:31:39,411 : INFO : PROGRESS: at sentence #1410000, processed 25075331 words, keeping 99737 word types
# 2020-01-17 01:31:39,438 : INFO : PROGRESS: at sentence #1420000, processed 25246633 words, keeping 100252 word types
# 2020-01-17 01:31:39,463 : INFO : PROGRESS: at sentence #1430000, processed 25411437 words, keeping 100700 word types
# 2020-01-17 01:31:39,490 : INFO : PROGRESS: at sentence #1440000, processed 25592572 words, keeping 101177 word types
# 2020-01-17 01:31:39,518 : INFO : PROGRESS: at sentence #1450000, processed 25765063 words, keeping 101583 word types
# 2020-01-17 01:31:39,546 : INFO : PROGRESS: at sentence #1460000, processed 25927817 words, keeping 102006 word types
# 2020-01-17 01:31:39,572 : INFO : PROGRESS: at sentence #1470000, processed 26095283 words, keeping 102432 word types
# 2020-01-17 01:31:39,598 : INFO : PROGRESS: at sentence #1480000, processed 26262652 words, keeping 102902 word types
# 2020-01-17 01:31:39,623 : INFO : PROGRESS: at sentence #1490000, processed 26439837 words, keeping 103275 word types
# 2020-01-17 01:31:39,646 : INFO : PROGRESS: at sentence #1500000, processed 26602512 words, keeping 103669 word types
# 2020-01-17 01:31:39,672 : INFO : PROGRESS: at sentence #1510000, processed 26767099 words, keeping 104029 word types
# 2020-01-17 01:31:39,698 : INFO : PROGRESS: at sentence #1520000, processed 26933595 words, keeping 104379 word types
# 2020-01-17 01:31:39,721 : INFO : PROGRESS: at sentence #1530000, processed 27091221 words, keeping 104731 word types
# 2020-01-17 01:31:39,747 : INFO : PROGRESS: at sentence #1540000, processed 27260507 words, keeping 105148 word types
# 2020-01-17 01:31:39,772 : INFO : PROGRESS: at sentence #1550000, processed 27426662 words, keeping 105559 word types
# 2020-01-17 01:31:39,797 : INFO : PROGRESS: at sentence #1560000, processed 27599280 words, keeping 105948 word types
# 2020-01-17 01:31:39,823 : INFO : PROGRESS: at sentence #1570000, processed 27770012 words, keeping 106421 word types
# 2020-01-17 01:31:39,866 : INFO : PROGRESS: at sentence #1580000, processed 27941592 words, keeping 106844 word types
# 2020-01-17 01:31:39,891 : INFO : PROGRESS: at sentence #1590000, processed 28106891 words, keeping 107257 word types
# 2020-01-17 01:31:39,916 : INFO : PROGRESS: at sentence #1600000, processed 28276824 words, keeping 107677 word types
# 2020-01-17 01:31:39,941 : INFO : PROGRESS: at sentence #1610000, processed 28440847 words, keeping 108136 word types
# 2020-01-17 01:31:39,969 : INFO : PROGRESS: at sentence #1620000, processed 28611679 words, keeping 108550 word types
# 2020-01-17 01:31:39,996 : INFO : PROGRESS: at sentence #1630000, processed 28787176 words, keeping 108896 word types
# 2020-01-17 01:31:40,022 : INFO : PROGRESS: at sentence #1640000, processed 28956052 words, keeping 109305 word types
# 2020-01-17 01:31:40,049 : INFO : PROGRESS: at sentence #1650000, processed 29120615 words, keeping 109781 word types
# 2020-01-17 01:31:40,075 : INFO : PROGRESS: at sentence #1660000, processed 29278684 words, keeping 110151 word types
# 2020-01-17 01:31:40,102 : INFO : PROGRESS: at sentence #1670000, processed 29447285 words, keeping 110560 word types
# 2020-01-17 01:31:40,129 : INFO : PROGRESS: at sentence #1680000, processed 29622349 words, keeping 110986 word types
# 2020-01-17 01:31:40,154 : INFO : PROGRESS: at sentence #1690000, processed 29784989 words, keeping 111395 word types
# 2020-01-17 01:31:40,179 : INFO : PROGRESS: at sentence #1700000, processed 29951911 words, keeping 111871 word types
# 2020-01-17 01:31:40,206 : INFO : PROGRESS: at sentence #1710000, processed 30125582 words, keeping 112238 word types
# 2020-01-17 01:31:40,234 : INFO : PROGRESS: at sentence #1720000, processed 30291843 words, keeping 112705 word types
# 2020-01-17 01:31:40,259 : INFO : PROGRESS: at sentence #1730000, processed 30459696 words, keeping 113110 word types
# 2020-01-17 01:31:40,281 : INFO : collected 113306 word types from a corpus of 30528396 raw words and 1734385 sentences
# 2020-01-17 01:31:40,346 : INFO : max_final_vocab=50000 and min_count=1 resulted in calc_min_count=3, effective_min_count=3
# 2020-01-17 01:31:40,347 : INFO : Loading a fresh vocabulary
# 2020-01-17 01:31:40,448 : INFO : effective_min_count=3 retains 38549 unique words (34% of original 113306, drops 74757)
# 2020-01-17 01:31:40,449 : INFO : effective_min_count=3 leaves 30438450 word corpus (99% of original 30528396, drops 89946)
# 2020-01-17 01:31:40,550 : INFO : deleting the raw counts dictionary of 113306 items
# 2020-01-17 01:31:40,554 : INFO : sample=0.001 downsamples 53 most-common words
# 2020-01-17 01:31:40,555 : INFO : downsampling leaves estimated 21217210 word corpus (69.7% of prior 30438450)
# 2020-01-17 01:31:40,684 : INFO : estimated required memory for 38549 words and 300 dimensions: 111792100 bytes
# 2020-01-17 01:31:40,685 : INFO : resetting layer weights
# 2020-01-17 01:31:41,079 : INFO : training model with 3 workers on 38549 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-01-17 01:31:42,097 : INFO : EPOCH 1 - PROGRESS: at 5.08% examples, 1044066 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:43,099 : INFO : EPOCH 1 - PROGRESS: at 10.27% examples, 1067113 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:44,099 : INFO : EPOCH 1 - PROGRESS: at 15.55% examples, 1078475 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:45,109 : INFO : EPOCH 1 - PROGRESS: at 20.85% examples, 1080878 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:46,118 : INFO : EPOCH 1 - PROGRESS: at 25.80% examples, 1078187 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:47,119 : INFO : EPOCH 1 - PROGRESS: at 30.78% examples, 1078871 words/s, in_qsize 6, out_qsize 1
# 2020-01-17 01:31:48,120 : INFO : EPOCH 1 - PROGRESS: at 35.87% examples, 1082708 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:49,130 : INFO : EPOCH 1 - PROGRESS: at 40.83% examples, 1082529 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:50,133 : INFO : EPOCH 1 - PROGRESS: at 45.84% examples, 1083982 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:51,136 : INFO : EPOCH 1 - PROGRESS: at 50.76% examples, 1083518 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:52,138 : INFO : EPOCH 1 - PROGRESS: at 55.35% examples, 1078025 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:53,139 : INFO : EPOCH 1 - PROGRESS: at 60.25% examples, 1076789 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:54,145 : INFO : EPOCH 1 - PROGRESS: at 65.20% examples, 1077245 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:55,147 : INFO : EPOCH 1 - PROGRESS: at 70.47% examples, 1078964 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:56,149 : INFO : EPOCH 1 - PROGRESS: at 75.50% examples, 1078378 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:57,151 : INFO : EPOCH 1 - PROGRESS: at 80.81% examples, 1079297 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:58,152 : INFO : EPOCH 1 - PROGRESS: at 86.07% examples, 1079288 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:31:59,154 : INFO : EPOCH 1 - PROGRESS: at 91.38% examples, 1078466 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:00,156 : INFO : EPOCH 1 - PROGRESS: at 96.79% examples, 1079339 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:00,733 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:32:00,736 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:32:00,741 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:32:00,741 : INFO : EPOCH - 1 : training on 30528396 raw words (21217170 effective words) took 19.6s, 1080015 effective words/s
# 2020-01-17 01:32:01,757 : INFO : EPOCH 2 - PROGRESS: at 5.15% examples, 1053648 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:02,762 : INFO : EPOCH 2 - PROGRESS: at 10.34% examples, 1069800 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:03,770 : INFO : EPOCH 2 - PROGRESS: at 15.58% examples, 1075917 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:04,776 : INFO : EPOCH 2 - PROGRESS: at 20.98% examples, 1084719 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:05,781 : INFO : EPOCH 2 - PROGRESS: at 26.06% examples, 1087834 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:06,783 : INFO : EPOCH 2 - PROGRESS: at 30.84% examples, 1079817 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:07,790 : INFO : EPOCH 2 - PROGRESS: at 35.87% examples, 1080567 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:08,793 : INFO : EPOCH 2 - PROGRESS: at 40.89% examples, 1083247 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:09,795 : INFO : EPOCH 2 - PROGRESS: at 45.91% examples, 1085559 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:10,800 : INFO : EPOCH 2 - PROGRESS: at 50.95% examples, 1086669 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:11,804 : INFO : EPOCH 2 - PROGRESS: at 55.80% examples, 1085696 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:12,806 : INFO : EPOCH 2 - PROGRESS: at 60.79% examples, 1086289 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:13,808 : INFO : EPOCH 2 - PROGRESS: at 65.80% examples, 1086104 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:14,814 : INFO : EPOCH 2 - PROGRESS: at 71.10% examples, 1087412 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:15,815 : INFO : EPOCH 2 - PROGRESS: at 76.32% examples, 1088596 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:16,822 : INFO : EPOCH 2 - PROGRESS: at 81.65% examples, 1088643 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:17,824 : INFO : EPOCH 2 - PROGRESS: at 86.92% examples, 1087950 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:18,826 : INFO : EPOCH 2 - PROGRESS: at 92.34% examples, 1088153 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:19,834 : INFO : EPOCH 2 - PROGRESS: at 97.72% examples, 1087852 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:20,233 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:32:20,243 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:32:20,247 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:32:20,248 : INFO : EPOCH - 2 : training on 30528396 raw words (21215357 effective words) took 19.5s, 1088206 effective words/s
# 2020-01-17 01:32:21,266 : INFO : EPOCH 3 - PROGRESS: at 5.29% examples, 1086098 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:22,267 : INFO : EPOCH 3 - PROGRESS: at 10.37% examples, 1078507 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:23,271 : INFO : EPOCH 3 - PROGRESS: at 15.41% examples, 1068919 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:24,274 : INFO : EPOCH 3 - PROGRESS: at 20.63% examples, 1070115 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:25,275 : INFO : EPOCH 3 - PROGRESS: at 25.60% examples, 1072497 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:26,278 : INFO : EPOCH 3 - PROGRESS: at 30.69% examples, 1077064 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:27,284 : INFO : EPOCH 3 - PROGRESS: at 35.73% examples, 1079304 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:28,294 : INFO : EPOCH 3 - PROGRESS: at 40.74% examples, 1080475 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:29,304 : INFO : EPOCH 3 - PROGRESS: at 45.74% examples, 1081372 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:30,305 : INFO : EPOCH 3 - PROGRESS: at 50.72% examples, 1082801 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:31,307 : INFO : EPOCH 3 - PROGRESS: at 55.57% examples, 1082435 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:32,308 : INFO : EPOCH 3 - PROGRESS: at 60.61% examples, 1083793 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:33,310 : INFO : EPOCH 3 - PROGRESS: at 65.57% examples, 1083337 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:34,321 : INFO : EPOCH 3 - PROGRESS: at 70.82% examples, 1083428 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:35,323 : INFO : EPOCH 3 - PROGRESS: at 75.98% examples, 1084419 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:36,323 : INFO : EPOCH 3 - PROGRESS: at 80.95% examples, 1080756 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:37,328 : INFO : EPOCH 3 - PROGRESS: at 86.32% examples, 1081527 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:38,330 : INFO : EPOCH 3 - PROGRESS: at 91.79% examples, 1082512 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:39,338 : INFO : EPOCH 3 - PROGRESS: at 97.08% examples, 1081432 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:39,856 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:32:39,861 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:32:39,865 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:32:39,866 : INFO : EPOCH - 3 : training on 30528396 raw words (21216049 effective words) took 19.6s, 1082405 effective words/s
# 2020-01-17 01:32:40,872 : INFO : EPOCH 4 - PROGRESS: at 5.11% examples, 1050756 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:41,875 : INFO : EPOCH 4 - PROGRESS: at 10.24% examples, 1062839 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:42,879 : INFO : EPOCH 4 - PROGRESS: at 15.41% examples, 1067974 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:43,881 : INFO : EPOCH 4 - PROGRESS: at 20.75% examples, 1076609 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:44,883 : INFO : EPOCH 4 - PROGRESS: at 25.67% examples, 1074904 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:45,887 : INFO : EPOCH 4 - PROGRESS: at 30.75% examples, 1079098 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:46,889 : INFO : EPOCH 4 - PROGRESS: at 35.87% examples, 1083574 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:47,890 : INFO : EPOCH 4 - PROGRESS: at 40.80% examples, 1083566 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:48,897 : INFO : EPOCH 4 - PROGRESS: at 45.84% examples, 1085290 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:49,899 : INFO : EPOCH 4 - PROGRESS: at 50.85% examples, 1086803 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:50,909 : INFO : EPOCH 4 - PROGRESS: at 55.64% examples, 1084116 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:51,918 : INFO : EPOCH 4 - PROGRESS: at 60.70% examples, 1085220 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:52,924 : INFO : EPOCH 4 - PROGRESS: at 65.76% examples, 1085928 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:53,931 : INFO : EPOCH 4 - PROGRESS: at 70.75% examples, 1082228 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:54,938 : INFO : EPOCH 4 - PROGRESS: at 75.85% examples, 1082010 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:55,940 : INFO : EPOCH 4 - PROGRESS: at 81.12% examples, 1082328 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:32:56,942 : INFO : EPOCH 4 - PROGRESS: at 86.56% examples, 1084013 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:57,946 : INFO : EPOCH 4 - PROGRESS: at 92.00% examples, 1084327 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:58,947 : INFO : EPOCH 4 - PROGRESS: at 97.46% examples, 1085331 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:32:59,402 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:32:59,408 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:32:59,414 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:32:59,414 : INFO : EPOCH - 4 : training on 30528396 raw words (21217527 effective words) took 19.5s, 1085689 effective words/s
# 2020-01-17 01:33:00,425 : INFO : EPOCH 5 - PROGRESS: at 5.22% examples, 1067637 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:01,428 : INFO : EPOCH 5 - PROGRESS: at 10.44% examples, 1082067 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:02,429 : INFO : EPOCH 5 - PROGRESS: at 15.58% examples, 1079511 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:03,433 : INFO : EPOCH 5 - PROGRESS: at 20.72% examples, 1074484 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:04,433 : INFO : EPOCH 5 - PROGRESS: at 25.80% examples, 1080286 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:05,434 : INFO : EPOCH 5 - PROGRESS: at 30.87% examples, 1084190 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:06,438 : INFO : EPOCH 5 - PROGRESS: at 35.93% examples, 1085673 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:07,439 : INFO : EPOCH 5 - PROGRESS: at 40.89% examples, 1086438 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:08,441 : INFO : EPOCH 5 - PROGRESS: at 45.88% examples, 1087543 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:09,446 : INFO : EPOCH 5 - PROGRESS: at 50.92% examples, 1088536 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:10,457 : INFO : EPOCH 5 - PROGRESS: at 55.98% examples, 1090412 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:11,470 : INFO : EPOCH 5 - PROGRESS: at 60.85% examples, 1087892 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:12,472 : INFO : EPOCH 5 - PROGRESS: at 65.84% examples, 1087073 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:13,475 : INFO : EPOCH 5 - PROGRESS: at 70.85% examples, 1084100 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:14,483 : INFO : EPOCH 5 - PROGRESS: at 76.04% examples, 1085072 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:15,485 : INFO : EPOCH 5 - PROGRESS: at 81.37% examples, 1085585 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:16,486 : INFO : EPOCH 5 - PROGRESS: at 86.62% examples, 1085189 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:17,491 : INFO : EPOCH 5 - PROGRESS: at 92.14% examples, 1086131 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:18,493 : INFO : EPOCH 5 - PROGRESS: at 97.52% examples, 1086338 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:18,932 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:33:18,938 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:33:18,938 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:33:18,939 : INFO : EPOCH - 5 : training on 30528396 raw words (21218329 effective words) took 19.5s, 1087091 effective words/s
# 2020-01-17 01:33:19,950 : INFO : EPOCH 6 - PROGRESS: at 5.25% examples, 1073813 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:20,959 : INFO : EPOCH 6 - PROGRESS: at 10.34% examples, 1067662 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:21,965 : INFO : EPOCH 6 - PROGRESS: at 15.72% examples, 1084278 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:22,965 : INFO : EPOCH 6 - PROGRESS: at 20.95% examples, 1084240 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:23,975 : INFO : EPOCH 6 - PROGRESS: at 26.06% examples, 1087627 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:24,982 : INFO : EPOCH 6 - PROGRESS: at 30.75% examples, 1075223 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:25,992 : INFO : EPOCH 6 - PROGRESS: at 35.93% examples, 1081129 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:26,992 : INFO : EPOCH 6 - PROGRESS: at 40.99% examples, 1085039 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:28,005 : INFO : EPOCH 6 - PROGRESS: at 45.91% examples, 1083560 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:29,010 : INFO : EPOCH 6 - PROGRESS: at 50.95% examples, 1084907 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:30,013 : INFO : EPOCH 6 - PROGRESS: at 55.73% examples, 1082910 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:31,016 : INFO : EPOCH 6 - PROGRESS: at 60.82% examples, 1085342 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:32,019 : INFO : EPOCH 6 - PROGRESS: at 65.94% examples, 1086787 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:33,031 : INFO : EPOCH 6 - PROGRESS: at 71.19% examples, 1087114 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:34,031 : INFO : EPOCH 6 - PROGRESS: at 76.32% examples, 1086999 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:35,031 : INFO : EPOCH 6 - PROGRESS: at 81.74% examples, 1088929 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:36,039 : INFO : EPOCH 6 - PROGRESS: at 86.98% examples, 1087471 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:37,042 : INFO : EPOCH 6 - PROGRESS: at 92.34% examples, 1086939 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:38,049 : INFO : EPOCH 6 - PROGRESS: at 97.66% examples, 1086023 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:38,470 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:33:38,476 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:33:38,477 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:33:38,478 : INFO : EPOCH - 6 : training on 30528396 raw words (21218446 effective words) took 19.5s, 1086286 effective words/s
# 2020-01-17 01:33:39,489 : INFO : EPOCH 7 - PROGRESS: at 5.15% examples, 1058042 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:40,490 : INFO : EPOCH 7 - PROGRESS: at 10.44% examples, 1084598 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:41,497 : INFO : EPOCH 7 - PROGRESS: at 15.72% examples, 1088092 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:42,498 : INFO : EPOCH 7 - PROGRESS: at 21.04% examples, 1092126 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:33:43,505 : INFO : EPOCH 7 - PROGRESS: at 26.06% examples, 1090376 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:44,508 : INFO : EPOCH 7 - PROGRESS: at 31.14% examples, 1092310 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:45,511 : INFO : EPOCH 7 - PROGRESS: at 36.15% examples, 1091803 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:46,520 : INFO : EPOCH 7 - PROGRESS: at 41.11% examples, 1090492 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:47,521 : INFO : EPOCH 7 - PROGRESS: at 46.00% examples, 1089210 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:48,523 : INFO : EPOCH 7 - PROGRESS: at 50.95% examples, 1088174 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:49,526 : INFO : EPOCH 7 - PROGRESS: at 55.94% examples, 1089781 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:50,530 : INFO : EPOCH 7 - PROGRESS: at 60.93% examples, 1090454 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:51,533 : INFO : EPOCH 7 - PROGRESS: at 65.91% examples, 1088763 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:52,534 : INFO : EPOCH 7 - PROGRESS: at 71.13% examples, 1089286 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:53,536 : INFO : EPOCH 7 - PROGRESS: at 76.25% examples, 1088992 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:54,543 : INFO : EPOCH 7 - PROGRESS: at 81.69% examples, 1090283 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:55,543 : INFO : EPOCH 7 - PROGRESS: at 86.62% examples, 1085983 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:56,547 : INFO : EPOCH 7 - PROGRESS: at 92.03% examples, 1085794 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:57,550 : INFO : EPOCH 7 - PROGRESS: at 97.36% examples, 1085111 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:33:58,020 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:33:58,031 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:33:58,032 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:33:58,032 : INFO : EPOCH - 7 : training on 30528396 raw words (21218402 effective words) took 19.5s, 1085671 effective words/s
# 2020-01-17 01:33:59,040 : INFO : EPOCH 8 - PROGRESS: at 5.29% examples, 1084657 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:00,046 : INFO : EPOCH 8 - PROGRESS: at 10.57% examples, 1095559 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:01,055 : INFO : EPOCH 8 - PROGRESS: at 15.82% examples, 1092126 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:02,068 : INFO : EPOCH 8 - PROGRESS: at 20.91% examples, 1079820 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:03,068 : INFO : EPOCH 8 - PROGRESS: at 25.93% examples, 1082190 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:04,071 : INFO : EPOCH 8 - PROGRESS: at 31.00% examples, 1085274 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:05,076 : INFO : EPOCH 8 - PROGRESS: at 36.02% examples, 1085507 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:06,079 : INFO : EPOCH 8 - PROGRESS: at 40.93% examples, 1083973 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:07,079 : INFO : EPOCH 8 - PROGRESS: at 45.80% examples, 1082652 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:08,086 : INFO : EPOCH 8 - PROGRESS: at 50.76% examples, 1082576 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:09,093 : INFO : EPOCH 8 - PROGRESS: at 55.64% examples, 1082374 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:10,095 : INFO : EPOCH 8 - PROGRESS: at 60.79% examples, 1086064 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:11,103 : INFO : EPOCH 8 - PROGRESS: at 65.84% examples, 1085871 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:12,109 : INFO : EPOCH 8 - PROGRESS: at 71.10% examples, 1086709 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:13,110 : INFO : EPOCH 8 - PROGRESS: at 76.29% examples, 1087514 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:14,111 : INFO : EPOCH 8 - PROGRESS: at 81.65% examples, 1088463 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:15,118 : INFO : EPOCH 8 - PROGRESS: at 87.05% examples, 1089079 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:16,124 : INFO : EPOCH 8 - PROGRESS: at 92.54% examples, 1089775 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:17,127 : INFO : EPOCH 8 - PROGRESS: at 98.08% examples, 1091120 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:17,458 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:34:17,465 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:34:17,466 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:34:17,466 : INFO : EPOCH - 8 : training on 30528396 raw words (21216231 effective words) took 19.4s, 1092069 effective words/s
# 2020-01-17 01:34:18,480 : INFO : EPOCH 9 - PROGRESS: at 5.25% examples, 1071776 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:19,483 : INFO : EPOCH 9 - PROGRESS: at 10.53% examples, 1090662 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:20,486 : INFO : EPOCH 9 - PROGRESS: at 15.82% examples, 1093473 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:21,494 : INFO : EPOCH 9 - PROGRESS: at 21.11% examples, 1092729 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:22,498 : INFO : EPOCH 9 - PROGRESS: at 26.29% examples, 1098442 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:23,504 : INFO : EPOCH 9 - PROGRESS: at 31.29% examples, 1096260 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:24,510 : INFO : EPOCH 9 - PROGRESS: at 36.41% examples, 1097705 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:25,513 : INFO : EPOCH 9 - PROGRESS: at 41.42% examples, 1097307 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:26,514 : INFO : EPOCH 9 - PROGRESS: at 46.15% examples, 1092167 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:27,517 : INFO : EPOCH 9 - PROGRESS: at 50.89% examples, 1086022 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:28,521 : INFO : EPOCH 9 - PROGRESS: at 55.77% examples, 1085802 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:29,521 : INFO : EPOCH 9 - PROGRESS: at 60.70% examples, 1085251 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:30,522 : INFO : EPOCH 9 - PROGRESS: at 65.60% examples, 1083756 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:31,522 : INFO : EPOCH 9 - PROGRESS: at 70.85% examples, 1084614 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:32,527 : INFO : EPOCH 9 - PROGRESS: at 76.01% examples, 1085303 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:33,530 : INFO : EPOCH 9 - PROGRESS: at 81.30% examples, 1085350 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:34,531 : INFO : EPOCH 9 - PROGRESS: at 86.62% examples, 1085761 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:35,534 : INFO : EPOCH 9 - PROGRESS: at 92.10% examples, 1086423 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:36,539 : INFO : EPOCH 9 - PROGRESS: at 97.49% examples, 1086399 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:36,988 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:34:36,998 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:34:36,999 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:34:37,000 : INFO : EPOCH - 9 : training on 30528396 raw words (21220455 effective words) took 19.5s, 1086693 effective words/s
# 2020-01-17 01:34:38,013 : INFO : EPOCH 10 - PROGRESS: at 5.39% examples, 1102180 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:39,017 : INFO : EPOCH 10 - PROGRESS: at 10.64% examples, 1101958 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:40,019 : INFO : EPOCH 10 - PROGRESS: at 16.00% examples, 1105813 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:41,025 : INFO : EPOCH 10 - PROGRESS: at 21.27% examples, 1102527 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:42,029 : INFO : EPOCH 10 - PROGRESS: at 26.42% examples, 1105122 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:43,035 : INFO : EPOCH 10 - PROGRESS: at 31.38% examples, 1100597 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:44,041 : INFO : EPOCH 10 - PROGRESS: at 36.34% examples, 1096633 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:45,045 : INFO : EPOCH 10 - PROGRESS: at 41.35% examples, 1096269 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:46,052 : INFO : EPOCH 10 - PROGRESS: at 46.24% examples, 1094166 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:47,060 : INFO : EPOCH 10 - PROGRESS: at 51.37% examples, 1096307 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:48,062 : INFO : EPOCH 10 - PROGRESS: at 56.40% examples, 1097007 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:49,062 : INFO : EPOCH 10 - PROGRESS: at 61.26% examples, 1095139 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:50,065 : INFO : EPOCH 10 - PROGRESS: at 66.27% examples, 1093633 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:51,072 : INFO : EPOCH 10 - PROGRESS: at 71.46% examples, 1092876 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:52,074 : INFO : EPOCH 10 - PROGRESS: at 76.51% examples, 1091373 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:34:53,079 : INFO : EPOCH 10 - PROGRESS: at 81.81% examples, 1090930 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:54,081 : INFO : EPOCH 10 - PROGRESS: at 87.09% examples, 1090040 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:55,088 : INFO : EPOCH 10 - PROGRESS: at 92.37% examples, 1088361 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:56,090 : INFO : EPOCH 10 - PROGRESS: at 97.79% examples, 1088758 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:56,492 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 01:34:56,495 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 01:34:56,496 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 01:34:56,497 : INFO : EPOCH - 10 : training on 30528396 raw words (21217580 effective words) took 19.5s, 1088742 effective words/s
# 2020-01-17 01:34:57,521 : INFO : EPOCH 11 - PROGRESS: at 4.88% examples, 1000155 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:58,525 : INFO : EPOCH 11 - PROGRESS: at 10.08% examples, 1044121 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:34:59,529 : INFO : EPOCH 11 - PROGRESS: at 15.18% examples, 1050673 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 01:35:00,540 : INFO : EPOCH 11 - PROGRESS: at 20.38% examples, 1054514 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:35:01,542 : INFO : EPOCH 11 - PROGRESS: at 25.50% examples, 1065216 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:35:02,549 : INFO : EPOCH 11 - PROGRESS: at 30.66% examples, 1072607 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:35:03,551 : INFO : EPOCH 11 - PROGRESS: at 35.73% examples, 1077190 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 01:35:04,552 : INFO : EPOCH 11 - PROGRESS: at 40.64% examples, 1077080 words/s, in_qsize 6, out_qsize 0
# ...
# 2020-01-17 02:02:28,064 : INFO : EPOCH 95 - PROGRESS: at 5.08% examples, 1042166 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:29,070 : INFO : EPOCH 95 - PROGRESS: at 10.15% examples, 1050811 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:30,080 : INFO : EPOCH 95 - PROGRESS: at 15.38% examples, 1062356 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:31,084 : INFO : EPOCH 95 - PROGRESS: at 20.52% examples, 1061603 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:32,086 : INFO : EPOCH 95 - PROGRESS: at 25.60% examples, 1069636 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:33,094 : INFO : EPOCH 95 - PROGRESS: at 30.59% examples, 1070468 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:34,096 : INFO : EPOCH 95 - PROGRESS: at 35.67% examples, 1075240 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:35,098 : INFO : EPOCH 95 - PROGRESS: at 40.70% examples, 1078724 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:36,099 : INFO : EPOCH 95 - PROGRESS: at 45.54% examples, 1076132 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:37,102 : INFO : EPOCH 95 - PROGRESS: at 50.37% examples, 1075205 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:38,103 : INFO : EPOCH 95 - PROGRESS: at 55.31% examples, 1077506 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:39,105 : INFO : EPOCH 95 - PROGRESS: at 60.28% examples, 1077352 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:40,111 : INFO : EPOCH 95 - PROGRESS: at 65.23% examples, 1077808 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:41,116 : INFO : EPOCH 95 - PROGRESS: at 70.51% examples, 1079246 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:42,117 : INFO : EPOCH 95 - PROGRESS: at 75.59% examples, 1079688 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:43,126 : INFO : EPOCH 95 - PROGRESS: at 80.85% examples, 1079232 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:44,129 : INFO : EPOCH 95 - PROGRESS: at 85.89% examples, 1076602 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:45,130 : INFO : EPOCH 95 - PROGRESS: at 91.28% examples, 1076716 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:46,137 : INFO : EPOCH 95 - PROGRESS: at 96.53% examples, 1075584 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:46,772 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 02:02:46,775 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 02:02:46,782 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 02:02:46,782 : INFO : EPOCH - 95 : training on 30528396 raw words (21218398 effective words) took 19.7s, 1075948 effective words/s
# 2020-01-17 02:02:47,793 : INFO : EPOCH 96 - PROGRESS: at 4.81% examples, 987516 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:48,793 : INFO : EPOCH 96 - PROGRESS: at 10.08% examples, 1046574 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:49,802 : INFO : EPOCH 96 - PROGRESS: at 15.18% examples, 1050262 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:50,805 : INFO : EPOCH 96 - PROGRESS: at 20.59% examples, 1066561 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:51,808 : INFO : EPOCH 96 - PROGRESS: at 25.21% examples, 1054284 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:52,810 : INFO : EPOCH 96 - PROGRESS: at 30.31% examples, 1061949 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:53,811 : INFO : EPOCH 96 - PROGRESS: at 35.08% examples, 1059500 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:54,814 : INFO : EPOCH 96 - PROGRESS: at 40.07% examples, 1063031 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:55,825 : INFO : EPOCH 96 - PROGRESS: at 45.03% examples, 1064209 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:02:56,830 : INFO : EPOCH 96 - PROGRESS: at 49.83% examples, 1063503 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:57,839 : INFO : EPOCH 96 - PROGRESS: at 54.56% examples, 1061631 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:58,845 : INFO : EPOCH 96 - PROGRESS: at 59.43% examples, 1061322 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:02:59,853 : INFO : EPOCH 96 - PROGRESS: at 64.43% examples, 1063343 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:00,855 : INFO : EPOCH 96 - PROGRESS: at 69.60% examples, 1064964 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:01,856 : INFO : EPOCH 96 - PROGRESS: at 74.53% examples, 1064179 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:02,859 : INFO : EPOCH 96 - PROGRESS: at 79.74% examples, 1064547 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:03,862 : INFO : EPOCH 96 - PROGRESS: at 84.55% examples, 1059991 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:04,865 : INFO : EPOCH 96 - PROGRESS: at 90.02% examples, 1062105 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:05,871 : INFO : EPOCH 96 - PROGRESS: at 95.21% examples, 1061455 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:06,738 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 02:03:06,741 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 02:03:06,748 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 02:03:06,749 : INFO : EPOCH - 96 : training on 30528396 raw words (21218663 effective words) took 20.0s, 1063089 effective words/s
# 2020-01-17 02:03:07,755 : INFO : EPOCH 97 - PROGRESS: at 4.98% examples, 1022911 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:08,757 : INFO : EPOCH 97 - PROGRESS: at 10.24% examples, 1062664 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:09,762 : INFO : EPOCH 97 - PROGRESS: at 15.41% examples, 1067315 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:10,765 : INFO : EPOCH 97 - PROGRESS: at 20.59% examples, 1067464 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:11,768 : INFO : EPOCH 97 - PROGRESS: at 25.64% examples, 1072914 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:12,775 : INFO : EPOCH 97 - PROGRESS: at 30.75% examples, 1077842 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:13,776 : INFO : EPOCH 97 - PROGRESS: at 35.83% examples, 1081775 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:14,785 : INFO : EPOCH 97 - PROGRESS: at 40.77% examples, 1080959 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:15,788 : INFO : EPOCH 97 - PROGRESS: at 45.77% examples, 1082591 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:16,788 : INFO : EPOCH 97 - PROGRESS: at 50.72% examples, 1083267 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:17,798 : INFO : EPOCH 97 - PROGRESS: at 55.48% examples, 1080256 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:18,800 : INFO : EPOCH 97 - PROGRESS: at 60.50% examples, 1081069 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:19,800 : INFO : EPOCH 97 - PROGRESS: at 65.51% examples, 1082116 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:20,804 : INFO : EPOCH 97 - PROGRESS: at 70.71% examples, 1082395 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:21,805 : INFO : EPOCH 97 - PROGRESS: at 75.53% examples, 1078968 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:22,806 : INFO : EPOCH 97 - PROGRESS: at 80.41% examples, 1074240 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:23,811 : INFO : EPOCH 97 - PROGRESS: at 85.76% examples, 1075519 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:24,815 : INFO : EPOCH 97 - PROGRESS: at 91.11% examples, 1075155 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:25,820 : INFO : EPOCH 97 - PROGRESS: at 96.27% examples, 1073167 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:26,486 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 02:03:26,491 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 02:03:26,496 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 02:03:26,497 : INFO : EPOCH - 97 : training on 30528396 raw words (21216760 effective words) took 19.7s, 1074641 effective words/s
# 2020-01-17 02:03:27,504 : INFO : EPOCH 98 - PROGRESS: at 4.94% examples, 1015937 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:28,504 : INFO : EPOCH 98 - PROGRESS: at 9.94% examples, 1033250 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:29,505 : INFO : EPOCH 98 - PROGRESS: at 15.08% examples, 1046907 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:30,510 : INFO : EPOCH 98 - PROGRESS: at 20.42% examples, 1060085 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:31,516 : INFO : EPOCH 98 - PROGRESS: at 25.47% examples, 1066238 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:32,520 : INFO : EPOCH 98 - PROGRESS: at 30.44% examples, 1067268 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:33,524 : INFO : EPOCH 98 - PROGRESS: at 35.57% examples, 1074363 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:34,526 : INFO : EPOCH 98 - PROGRESS: at 40.49% examples, 1074451 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:35,535 : INFO : EPOCH 98 - PROGRESS: at 45.51% examples, 1076022 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:36,536 : INFO : EPOCH 98 - PROGRESS: at 50.47% examples, 1077997 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:37,539 : INFO : EPOCH 98 - PROGRESS: at 55.28% examples, 1077297 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:38,543 : INFO : EPOCH 98 - PROGRESS: at 60.25% examples, 1077057 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:39,545 : INFO : EPOCH 98 - PROGRESS: at 64.89% examples, 1072493 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:40,546 : INFO : EPOCH 98 - PROGRESS: at 69.95% examples, 1071636 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:41,550 : INFO : EPOCH 98 - PROGRESS: at 75.04% examples, 1072399 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:42,568 : INFO : EPOCH 98 - PROGRESS: at 80.13% examples, 1069986 words/s, in_qsize 4, out_qsize 1
# 2020-01-17 02:03:43,568 : INFO : EPOCH 98 - PROGRESS: at 85.41% examples, 1070566 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:44,576 : INFO : EPOCH 98 - PROGRESS: at 90.61% examples, 1068700 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:45,585 : INFO : EPOCH 98 - PROGRESS: at 95.79% examples, 1067145 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:46,374 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 02:03:46,383 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 02:03:46,387 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 02:03:46,388 : INFO : EPOCH - 98 : training on 30528396 raw words (21217460 effective words) took 19.9s, 1067004 effective words/s
# 2020-01-17 02:03:47,407 : INFO : EPOCH 99 - PROGRESS: at 5.08% examples, 1041722 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:48,407 : INFO : EPOCH 99 - PROGRESS: at 10.11% examples, 1049209 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:49,414 : INFO : EPOCH 99 - PROGRESS: at 15.28% examples, 1057310 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:50,424 : INFO : EPOCH 99 - PROGRESS: at 20.52% examples, 1061345 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:51,426 : INFO : EPOCH 99 - PROGRESS: at 25.57% examples, 1068095 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:52,426 : INFO : EPOCH 99 - PROGRESS: at 30.56% examples, 1070687 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:53,431 : INFO : EPOCH 99 - PROGRESS: at 35.24% examples, 1063199 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:54,432 : INFO : EPOCH 99 - PROGRESS: at 40.35% examples, 1069883 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:55,435 : INFO : EPOCH 99 - PROGRESS: at 45.16% examples, 1067429 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:03:56,436 : INFO : EPOCH 99 - PROGRESS: at 50.08% examples, 1069502 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:57,446 : INFO : EPOCH 99 - PROGRESS: at 54.99% examples, 1070827 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:58,457 : INFO : EPOCH 99 - PROGRESS: at 59.53% examples, 1062952 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:03:59,458 : INFO : EPOCH 99 - PROGRESS: at 64.56% examples, 1065987 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:00,460 : INFO : EPOCH 99 - PROGRESS: at 69.78% examples, 1067996 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:01,464 : INFO : EPOCH 99 - PROGRESS: at 74.93% examples, 1069894 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:02,465 : INFO : EPOCH 99 - PROGRESS: at 80.17% examples, 1070444 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:03,467 : INFO : EPOCH 99 - PROGRESS: at 85.44% examples, 1070870 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:04,469 : INFO : EPOCH 99 - PROGRESS: at 90.67% examples, 1069706 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:05,475 : INFO : EPOCH 99 - PROGRESS: at 96.10% examples, 1070867 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:06,214 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 02:04:06,220 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 02:04:06,221 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 02:04:06,222 : INFO : EPOCH - 99 : training on 30528396 raw words (21214225 effective words) took 19.8s, 1070423 effective words/s
# 2020-01-17 02:04:07,232 : INFO : EPOCH 100 - PROGRESS: at 4.94% examples, 1013922 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:04:08,232 : INFO : EPOCH 100 - PROGRESS: at 10.18% examples, 1056084 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:09,237 : INFO : EPOCH 100 - PROGRESS: at 15.41% examples, 1067430 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:10,241 : INFO : EPOCH 100 - PROGRESS: at 20.59% examples, 1067120 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:11,247 : INFO : EPOCH 100 - PROGRESS: at 25.60% examples, 1070510 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:12,248 : INFO : EPOCH 100 - PROGRESS: at 30.63% examples, 1073719 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:04:13,252 : INFO : EPOCH 100 - PROGRESS: at 35.63% examples, 1075710 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:14,254 : INFO : EPOCH 100 - PROGRESS: at 40.52% examples, 1074744 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:15,259 : INFO : EPOCH 100 - PROGRESS: at 45.51% examples, 1076120 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:04:16,261 : INFO : EPOCH 100 - PROGRESS: at 50.34% examples, 1075173 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:17,268 : INFO : EPOCH 100 - PROGRESS: at 55.28% examples, 1076927 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:04:18,270 : INFO : EPOCH 100 - PROGRESS: at 60.09% examples, 1073954 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:19,285 : INFO : EPOCH 100 - PROGRESS: at 64.98% examples, 1072839 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:20,289 : INFO : EPOCH 100 - PROGRESS: at 70.22% examples, 1074177 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:21,290 : INFO : EPOCH 100 - PROGRESS: at 75.30% examples, 1075070 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:22,292 : INFO : EPOCH 100 - PROGRESS: at 80.60% examples, 1076148 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:04:23,293 : INFO : EPOCH 100 - PROGRESS: at 85.93% examples, 1077101 words/s, in_qsize 6, out_qsize 0
# 2020-01-17 02:04:24,293 : INFO : EPOCH 100 - PROGRESS: at 91.31% examples, 1077240 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:25,303 : INFO : EPOCH 100 - PROGRESS: at 96.59% examples, 1076336 words/s, in_qsize 5, out_qsize 0
# 2020-01-17 02:04:25,933 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-01-17 02:04:25,944 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-01-17 02:04:25,945 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-01-17 02:04:25,946 : INFO : EPOCH - 100 : training on 30528396 raw words (21218257 effective words) took 19.7s, 1076121 effective words/s
# 2020-01-17 02:04:25,947 : INFO : training on a 3052839600 raw words (2121726549 effective words) took 1964.9s, 1079832 effective words/s
# 2020-01-17 02:04:25,948 : INFO : storing 38549x300 projection weights into Embedding/category/word2Vec/word2Vec.300d.txt

# %%
#模型讀取方式
# model = word2vec.Word2Vec.load("Embedding/word2Vec/word2vec.model")

wvmodel = gensim.models.KeyedVectors.load_word2vec_format(
    'Embedding/category/word2Vec/word2Vec.300d.txt', binary=False, encoding='utf-8')

wvmodel.most_similar(u"player", topn=10)
# wvmodel.most_similar(['dvd','player','changer','machine','video'], topn=20)
# Out:
# 2020-01-17 02:04:31,669 : INFO : loading projection weights from Embedding/category/word2Vec/word2Vec.300d.txt
# 2020-01-17 02:04:39,924 : INFO : loaded (38549, 300) matrix from Embedding/category/word2Vec/word2Vec.300d.txt
# 2020-01-17 02:04:39,925 : INFO : precomputing L2-norms of word weight vectors
# [('vlc', 0.4459226727485657),
#  ('wmp', 0.41637396812438965),
#  ('application', 0.41213300824165344),
#  ('wma', 0.4115654230117798),
#  ('realplayer', 0.4054880738258362),
#  ('quicktime', 0.4026370644569397),
#  ('editor', 0.40150508284568787),
#  ('ps3', 0.39550626277923584),
#  ('browser', 0.39438489079475403),
#  ('microsoft', 0.39393728971481323)]

# %%
vocab_file = "Embedding/category/word2Vec/word.vocab"

if not os.path.exists(vocab_file):
    vocab_count = len(wvmodel.wv.index2entity)    

    print("Writing vocab file...")
    with open(vocab_file, 'w',encoding='utf-8') as writer:
        for word in wvmodel.wv.index2entity[:vocab_count]:
            # print(word, w2vec.wv.vocab[word].count)
            writer.write(word + ' ' + str(wvmodel.wv.vocab[word].count) + '\n') # Output vocab count
    print("Finished writing vocab file")
# Out:
# /home/eagleuser/.conda/envs/Leyan/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.
# /home/eagleuser/.conda/envs/Leyan/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# /home/eagleuser/.conda/envs/Leyan/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # Remove the CWD from sys.path while we load stuff.
# Writing vocab file...
# Finished writing vocab file

# %%
word = wvmodel.wv.index2entity[25]
vector = wvmodel.wv.vectors[25]
print(word)
# print(vector)
# Out:
# take
# /home/eagleuser/.conda/envs/Leyan/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# /home/eagleuser/.conda/envs/Leyan/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
import torch
from data_util.data import Vocab
vocab_size = len(wvmodel.vocab) + 1


vocab = Vocab('Embedding/category/word2Vec/word.vocab', vocab_size)

embed_size = 300
weight = torch.zeros(vocab_size, embed_size)

for i in range(len(vocab._id_to_word.keys())):
    try:
        vocab_word = vocab._id_to_word[i+4]
        w2vec_word = w2vec.wv.index2entity[i]
    except Exception as e :
        continue
    if i + 4 > vocab_size: break
#     print(vocab_word,w2vec_word)
    weight[i+4, :] = torch.from_numpy(w2vec.wv.vectors[i])
        
embedding = torch.nn.Embedding.from_pretrained(weight)
# requires_grad指定是否在训练过程中对词向量的权重进行微调
embedding.weight.requires_grad = True
embedding
# Out:
# Embedding(38550, 300)

# %%
vocab.word2id('the')
# Out:
# 4

# %% [markdown]
# # Embedding/glove

# %%
vocab_size = len(wvmodel.vocab) + 1

vocab = Vocab('Embedding/category/word2Vec/word.vocab', vocab_size)

with open("Embedding/glove/glove.6B.300d.txt", 'r',encoding='utf-8') as f :
#     print(vocab_size) 
    embed_size = 300
    weight = torch.zeros(vocab_size, embed_size)

    for line in f.readlines():
        values = line.split()
        word = values[0]
        if word not in vocab._word_to_id.keys(): continue
        vector = np.asarray(values[1:], "float32")
        wid = vocab.word2id(word)          
        weight[wid, :] = torch.from_numpy(vector)
        

embedding = torch.nn.Embedding.from_pretrained(weight)
# requires_grad指定是否在训练过程中对词向量的权重进行微调
embedding.weight.requires_grad = True
embedding
# Out:
# Embedding(38550, 300)

# %% [markdown]
# # Embedding/Bert

# %%
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM
# BERT
# tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True, do_basic_tokenize=True)
# Load pre-trained model (weights)
model = BertModel.from_pretrained('bert-base-uncased')
# model.eval()
model.embeddings.word_embeddings


# vocab = Vocab('Embedding/word2Vec/word2Vec.vocab', vocab_size)

# embed_size = 300
# weight = torch.zeros(vocab_size, embed_size)


# embedding = torch.nn.Embedding.from_pretrained(weight)
# # requires_grad指定是否在训练过程中对词向量的权重进行微调
# embedding.weight.requires_grad = True
# embedding
# Out:
# 2020-01-17 02:04:53,700 : INFO : Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 2020-01-17 02:04:54,684 : INFO : loading archive file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased.tar.gz from cache at /home/eagleuser/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba
# 2020-01-17 02:04:54,690 : INFO : extracting archive file /home/eagleuser/.pytorch_pretrained_bert/9c41111e2de84547a463fd39217199738d1e3deb72d4fec4399e6e241983c6f0.ae3cef932725ca7a30cdcb93fc6e09150a55e2a130ec7af63975a16c153ae2ba to temp dir /tmp/tmpnha3u5gc
# 2020-01-17 02:04:58,244 : INFO : Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
# Embedding(30522, 768, padding_idx=0)
