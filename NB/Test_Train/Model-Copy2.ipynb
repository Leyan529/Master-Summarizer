# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import time
import re


import torch as T



import torch.nn as nn
import torch.nn.functional as F


from model import Model


from data_util import config, data
from data_util.batcher import Batcher
from data_util.data import Vocab


from train_util import *
from torch.distributions import Categorical
from rouge import Rouge
from numpy import random
import argparse
import torchsnooper

# %%
# random.seed(123)
# T.manual_seed(123)
# if T.cuda.is_available():
#     T.cuda.manual_seed_all(123)
#     print("is_available", T.cuda.is_available())
#     print("use_cuda", use_cuda)

# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# T.cuda.set_device(1)

# use_cuda = config.use_gpu and torch.cuda.is_available()
# print("use_cuda", T.cuda.is_available())

# print("use_cuda", use_cuda)

# %% [markdown]
# # View batch data

# %%
def test_batch():
    vocab = Vocab(config.vocab_path, config.vocab_size)
    batcher = Batcher(config.train_data_path, vocab, mode='train',
                           batch_size=config.batch_size, single_pass=False)
    batch = batcher.next_batch()
    # with torchsnooper.snoop():
    while batch is not None:
        example_list = batch.example_list
        for ex in example_list:
            r = str(ex.original_review)
            s = str(ex.original_summary)
            k = str(ex.key_words)
            sent = ex.original_summary_sents
#             print("original_review_sents:", r)
#             print("original_summary_sents : ", s)
#             print("review_key_words : ", k)
#             print('------------------------------------------------------------\n')
        batch = batcher.next_batch()        
# test_batch()

# %% [markdown]
# # Get Bin Information

# %%
with open("bin/bin-info.txt",'r',encoding='utf-8') as f:
    lines = f.readlines()
    [print(line) for line in lines]
    train_num = int(lines[0].split(":")[1])
    test_num = int(lines[1].split(":")[1])
    val_num = int(lines[2].split(":")[1])
    # f.write("train : %s\n"%(len(flit_key_train_df)))
    # f.write("test : %s\n"%(len(flit_key_test_df)))
    # f.write("valid : %s\n"%(len(flit_key_valid_df)))
# Out:
# train : 26716
#
# test : 8905
#
# valid : 8905

# %% [markdown]
# # View model summary
# #### 只有torchsummaryX成功
# #### 日後將以此模擬呈現結構

# %%
# from torchsummary import summary # 不支援RNN
# from model import Encoder,Model
# # https://www.cnblogs.com/lindaxin/p/8052043.html
# device = T.device("cuda" if T.cuda.is_available() else "cpu") # PyTorch v0.4.0
# encoder = Encoder().to(device)    

# vocab = Vocab(config.vocab_path, config.vocab_size)
# batcher = Batcher(config.train_data_path, vocab, mode='train',
#                        batch_size=config.batch_size, single_pass=False)
# batch = batcher.next_batch()
# enc_batch, enc_lens, enc_padding_mask, enc_batch_extend_vocab, extra_zeros, context = get_enc_data(batch)
# enc_batch = Model().embeds(enc_batch) # Get embeddings for encoder input

# # summary(encoder, enc_batch, enc_lens, show_hierarchical=True) 
# # summary(encoder, [enc_batch, enc_lens])

# %%
# from modelsummary import summary # 未知問題
# from model import Encoder,Model
# # https://www.cnblogs.com/lindaxin/p/8052043.html
# device = T.device("cuda" if T.cuda.is_available() else "cpu") # PyTorch v0.4.0
# encoder = Encoder().to(device)    

# vocab = Vocab(config.vocab_path, config.vocab_size)
# batcher = Batcher(config.train_data_path, vocab, mode='train',
#                        batch_size=config.batch_size, single_pass=False)
# batch = batcher.next_batch()
# enc_batch, enc_lens, enc_padding_mask, enc_batch_extend_vocab, extra_zeros, context = get_enc_data(batch)
# enc_batch = Model().embeds(enc_batch) # Get embeddings for encoder input

# # summary(encoder, enc_batch, enc_lens, show_hierarchical=True) 
# # summary(encoder, enc_batch, enc_lens, show_input=False)

# %%
from torchsummaryX import summary
from model import Encoder,Model
device = T.device("cuda" if T.cuda.is_available() else "cpu") # PyTorch v0.4.0
encoder = Encoder().to(device)    

vocab = Vocab(config.vocab_path, config.vocab_size)
batcher = Batcher(config.train_data_path, vocab, mode='train',
                       batch_size=config.batch_size, single_pass=False)
batch = batcher.next_batch()
enc_batch, enc_lens, enc_padding_mask, enc_batch_extend_vocab, extra_zeros, context = get_enc_data(batch)
enc_batch = Model(False,'word2Vec',vocab).embeds(enc_batch) #Get embeddings for encoder input

summary(encoder, enc_batch, enc_lens) # encoder summary
# Out:
# ========================================================
#            Kernel Shape Output Shape   Params  Mult-Adds
# Layer
# 0_lstm                -  [690, 1024]  3334144    3325952
# 1_reduce_h  [1024, 512]     [8, 512]   524800     524288
# 2_reduce_c  [1024, 512]     [8, 512]   524800     524288
# --------------------------------------------------------
#                        Totals
# Total params          4383744
# Trainable params      4383744
# Non-trainable params        0
# Mult-Adds             4374528
# ========================================================
#            Kernel Shape Output Shape   Params  Mult-Adds
# Layer
# 0_lstm                -  [690, 1024]  3334144    3325952
# 1_reduce_h  [1024, 512]     [8, 512]   524800     524288
# 2_reduce_c  [1024, 512]     [8, 512]   524800     524288

# %% [markdown]
# # Train object

# %%
# from torchsummaryX import summary
class Train(object):
    def __init__(self, opt):
        self.vocab = Vocab(config.vocab_path, config.vocab_size)
#         print('use %s vocab_size %s '%(opt.word_emb_type,config.vocab_size))

        self.batcher = Batcher(config.train_data_path, self.vocab, mode='train',
                               batch_size=config.batch_size, single_pass=False)
        self.opt = opt
        self.start_id = self.vocab.word2id(data.START_DECODING)
        self.end_id = self.vocab.word2id(data.STOP_DECODING)
        self.pad_id = self.vocab.word2id(data.PAD_TOKEN)
        self.unk_id = self.vocab.word2id(data.UNKNOWN_TOKEN)
        time.sleep(5)

    def save_model(self, iter):
        if not os.path.exists(config.save_model_path):
            os.makedirs(config.save_model_path)
        save_path = config.save_model_path + "/%07d.tar" % iter
        T.save({
            "iter": iter + 1,
            "model_dict": self.model.state_dict(),
            "trainer_dict": self.trainer.state_dict()
        }, save_path)

    def setup_train(self):
        self.model = Model(opt.pre_train_emb,opt.word_emb_type,self.vocab) 
#         print("Model : ",self.model)
#         print("Encoder : ",self.model.encoder)
#         print("Decoder : ",self.model.decoder)
#         print("Embeds : ",self.model.embeds)
        self.model = get_cuda(self.model)
        device = T.device("cuda" if T.cuda.is_available() else "cpu") # PyTorch v0.4.0
        if opt.multi_device:
            if T.cuda.device_count() > 1:
                print("Let's use", T.cuda.device_count(), "GPUs!")
                self.model = nn.DataParallel(self.model, list(range(T.cuda.device_count()))).cuda()    
                
                
        if isinstance(self.model,nn.DataParallel):
            self.model = self.model.module
        self.model.to(device)
#         self.model.eval()
        
        self.trainer = T.optim.Adam(self.model.parameters(), lr=config.lr)
        start_iter = 0
        if self.opt.load_model is not None:
            load_model_path = os.path.join(config.save_model_path, self.opt.load_model)
            checkpoint = T.load(load_model_path)
            start_iter = checkpoint["iter"]
            self.model.load_state_dict(checkpoint["model_dict"])
            self.trainer.load_state_dict(checkpoint["trainer_dict"])
            print("Loaded model at " + load_model_path)
        if self.opt.new_lr is not None:
            self.trainer = T.optim.Adam(self.model.parameters(), lr=self.opt.new_lr)
        return start_iter

    def train_batch_MLE(self, enc_out, enc_hidden, enc_padding_mask, ct_e, extra_zeros, enc_batch_extend_vocab, batch):
        ''' Calculate Negative Log Likelihood Loss for the given batch. In order to reduce exposure bias,
                pass the previous generated token as input with a probability of 0.25 instead of ground truth label
        Args:
        :param enc_out: Outputs of the encoder for all time steps (batch_size, length_input_sequence, 2*hidden_size)
        :param enc_hidden: Tuple containing final hidden state & cell state of encoder. Shape of h & c: (batch_size, hidden_size)
        :param enc_padding_mask: Mask for encoder input; Tensor of size (batch_size, length_input_sequence) with values of 0 for pad tokens & 1 for others
        :param ct_e: encoder context vector for time_step=0 (eq 5 in https://arxiv.org/pdf/1705.04304.pdf)
        :param extra_zeros: Tensor used to extend vocab distribution for pointer mechanism
        :param enc_batch_extend_vocab: Input batch that stores OOV ids
        :param batch: batch object
        '''
        dec_batch, max_dec_len, dec_lens, target_batch = get_dec_data(batch)                        #Get input and target batchs for training decoder
        step_losses = []
        s_t = (enc_hidden[0], enc_hidden[1])                                                        #Decoder hidden states
        x_t = get_cuda(T.LongTensor(len(enc_out)).fill_(self.start_id))                             #Input to the decoder
        prev_s = None                                                                               #Used for intra-decoder attention (section 2.2 in https://arxiv.org/pdf/1705.04304.pdf)
        sum_temporal_srcs = None                                                                    #Used for intra-temporal attention (section 2.1 in https://arxiv.org/pdf/1705.04304.pdf)
        for t in range(min(max_dec_len, config.max_dec_steps)):
            use_gound_truth = get_cuda((T.rand(len(enc_out)) > 0.25)).long()                        #Probabilities indicating whether to use ground truth labels instead of previous decoded tokens
            x_t = use_gound_truth * dec_batch[:, t] + (1 - use_gound_truth) * x_t                   #Select decoder input based on use_ground_truth probabilities
            x_t = self.model.embeds(x_t)
            final_dist, s_t, ct_e, sum_temporal_srcs, prev_s = self.model.decoder(x_t, s_t, enc_out, enc_padding_mask, ct_e, extra_zeros, enc_batch_extend_vocab, sum_temporal_srcs, prev_s)
            target = target_batch[:, t]
            log_probs = T.log(final_dist + config.eps)
            step_loss = F.nll_loss(log_probs, target, reduction="none", ignore_index=self.pad_id)
            step_losses.append(step_loss)
            x_t = T.multinomial(final_dist, 1).squeeze()                                            #Sample words from final distribution which can be used as input in next time step
            is_oov = (x_t >= config.vocab_size).long()                                              #Mask indicating whether sampled word is OOV
            x_t = (1 - is_oov) * x_t.detach() + (is_oov) * self.unk_id                              #Replace OOVs with [UNK] token

        losses = T.sum(T.stack(step_losses, 1), 1)                                                  #unnormalized losses for each example in the batch; (batch_size)
        batch_avg_loss = losses / dec_lens                                                          #Normalized losses; (batch_size)
        mle_loss = T.mean(batch_avg_loss)                                                           #Average batch loss
        return mle_loss

    def train_batch_RL(self, enc_out, enc_hidden, enc_padding_mask, ct_e, extra_zeros, enc_batch_extend_vocab, article_oovs, greedy):
        '''Generate sentences from decoder entirely using sampled tokens as input. These sentences are used for ROUGE evaluation
        Args
        :param enc_out: Outputs of the encoder for all time steps (batch_size, length_input_sequence, 2*hidden_size)
        :param enc_hidden: Tuple containing final hidden state & cell state of encoder. Shape of h & c: (batch_size, hidden_size)
        :param enc_padding_mask: Mask for encoder input; Tensor of size (batch_size, length_input_sequence) with values of 0 for pad tokens & 1 for others
        :param ct_e: encoder context vector for time_step=0 (eq 5 in https://arxiv.org/pdf/1705.04304.pdf)
        :param extra_zeros: Tensor used to extend vocab distribution for pointer mechanism
        :param enc_batch_extend_vocab: Input batch that stores OOV ids
        :param article_oovs: Batch containing list of OOVs in each example
        :param greedy: If true, performs greedy based sampling, else performs multinomial sampling
        Returns:
        :decoded_strs: List of decoded sentences
        :log_probs: Log probabilities of sampled words
        '''
        s_t = enc_hidden                                                                            #Decoder hidden states
        x_t = get_cuda(T.LongTensor(len(enc_out)).fill_(self.start_id))                             #Input to the decoder
        prev_s = None                                                                               #Used for intra-decoder attention (section 2.2 in https://arxiv.org/pdf/1705.04304.pdf)
        sum_temporal_srcs = None                                                                    #Used for intra-temporal attention (section 2.1 in https://arxiv.org/pdf/1705.04304.pdf)
        inds = []                                                                                   #Stores sampled indices for each time step
        decoder_padding_mask = []                                                                   #Stores padding masks of generated samples
        log_probs = []                                                                              #Stores log probabilites of generated samples
        mask = get_cuda(T.LongTensor(len(enc_out)).fill_(1))                                        #Values that indicate whether [STOP] token has already been encountered; 1 => Not encountered, 0 otherwise

        for t in range(config.max_dec_steps):
            x_t = self.model.embeds(x_t)
            probs, s_t, ct_e, sum_temporal_srcs, prev_s = self.model.decoder(x_t, s_t, enc_out, enc_padding_mask, ct_e, extra_zeros, enc_batch_extend_vocab, sum_temporal_srcs, prev_s)
            if greedy is False:
                multi_dist = Categorical(probs)
                x_t = multi_dist.sample()                                                           #perform multinomial sampling
                log_prob = multi_dist.log_prob(x_t)
                log_probs.append(log_prob)
            else:
                _, x_t = T.max(probs, dim=1)                                                        #perform greedy sampling
            x_t = x_t.detach()
            inds.append(x_t)
            mask_t = get_cuda(T.zeros(len(enc_out)))                                                #Padding mask of batch for current time step
            mask_t[mask == 1] = 1                                                                   #If [STOP] is not encountered till previous time step, mask_t = 1 else mask_t = 0
            mask[(mask == 1) + (x_t == self.end_id) == 2] = 0                                       #If [STOP] is not encountered till previous time step and current word is [STOP], make mask = 0
            decoder_padding_mask.append(mask_t)
            is_oov = (x_t>=config.vocab_size).long()                                                #Mask indicating whether sampled word is OOV
            x_t = (1-is_oov)*x_t + (is_oov)*self.unk_id                                             #Replace OOVs with [UNK] token

        inds = T.stack(inds, dim=1)
        decoder_padding_mask = T.stack(decoder_padding_mask, dim=1)
        if greedy is False:                                                                         #If multinomial based sampling, compute log probabilites of sampled words
            log_probs = T.stack(log_probs, dim=1)
            log_probs = log_probs * decoder_padding_mask                                            #Not considering sampled words with padding mask = 0
            lens = T.sum(decoder_padding_mask, dim=1)                                               #Length of sampled sentence
            log_probs = T.sum(log_probs, dim=1) / lens  # (bs,)                                     #compute normalizied log probability of a sentence
        decoded_strs = []
        for i in range(len(enc_out)):
            id_list = inds[i].cpu().numpy()
            oovs = article_oovs[i]
            S = data.outputids2words(id_list, self.vocab, oovs)                                     #Generate sentence corresponding to sampled words
            try:
                end_idx = S.index(data.STOP_DECODING)
                S = S[:end_idx]
            except ValueError:
                S = S
            if len(S) < 2:                                                                           #If length of sentence is less than 2 words, replace it with "xxx"; Avoids setences like "." which throws error while calculating ROUGE
                S = ["xxx"]
            S = " ".join(S)
            decoded_strs.append(S)

        return decoded_strs, log_probs
    
    def train_batch_decode(self,batch, enc_out, enc_hidden, enc_padding_mask, ct_e, extra_zeros, enc_batch_extend_vocab, article_oovs, greedy):
        '''Generate sentences from decoder entirely using sampled tokens as input. These sentences are used for ROUGE evaluation
        Args
        :param enc_out: Outputs of the encoder for all time steps (batch_size, length_input_sequence, 2*hidden_size)
        :param enc_hidden: Tuple containing final hidden state & cell state of encoder. Shape of h & c: (batch_size, hidden_size)
        :param enc_padding_mask: Mask for encoder input; Tensor of size (batch_size, length_input_sequence) with values of 0 for pad tokens & 1 for others
        :param ct_e: encoder context vector for time_step=0 (eq 5 in https://arxiv.org/pdf/1705.04304.pdf)
        :param extra_zeros: Tensor used to extend vocab distribution for pointer mechanism
        :param enc_batch_extend_vocab: Input batch that stores OOV ids
        :param article_oovs: Batch containing list of OOVs in each example
        :param greedy: If true, performs greedy based sampling, else performs multinomial sampling
        Returns:
        :decoded_strs: List of decoded sentences
        :log_probs: Log probabilities of sampled words
        '''
        s_t = enc_hidden                                                                            #Decoder hidden states
        x_t = get_cuda(T.LongTensor(len(enc_out)).fill_(self.start_id))                             #Input to the decoder
        prev_s = None                                                                               #Used for intra-decoder attention (section 2.2 in https://arxiv.org/pdf/1705.04304.pdf)
        sum_temporal_srcs = None                                                                    #Used for intra-temporal attention (section 2.1 in https://arxiv.org/pdf/1705.04304.pdf)
        inds = []                                                                                   #Stores sampled indices for each time step
        decoder_padding_mask = []                                                                   #Stores padding masks of generated samples
        log_probs = []                                                                              #Stores log probabilites of generated samples
        mask = get_cuda(T.LongTensor(len(enc_out)).fill_(1))                                        #Values that indicate whether [STOP] token has already been encountered; 1 => Not encountered, 0 otherwise

        for t in range(config.max_dec_steps):
            x_t = self.model.embeds(x_t)
#             print('x_t')
#             print(x_t)
            probs, s_t, ct_e, sum_temporal_srcs, prev_s = self.model.decoder(x_t, s_t, enc_out, enc_padding_mask, ct_e, extra_zeros, enc_batch_extend_vocab, sum_temporal_srcs, prev_s)
            if greedy is False:
                multi_dist = Categorical(probs)
                x_t = multi_dist.sample()                                                           #perform multinomial sampling
#                 log_prob = multi_dist.log_prob(x_t)
#                 log_probs.append(log_prob)
            else:
                _, x_t = T.max(probs, dim=1)                                                        #perform greedy sampling
            x_t = x_t.detach()
            inds.append(x_t)
            mask_t = get_cuda(T.zeros(len(enc_out)))                                                #Padding mask of batch for current time step
            mask_t[mask == 1] = 1                                                                   #If [STOP] is not encountered till previous time step, mask_t = 1 else mask_t = 0
#             mask[(mask == 1) + (x_t == self.end_id) == 2] = 0                                       #If [STOP] is not encountered till previous time step and current word is [STOP], make mask = 0
            decoder_padding_mask.append(mask_t)
#             is_oov = (x_t>=config.vocab_size).long()                                                #Mask indicating whether sampled word is OOV
#             x_t = (1-is_oov)*x_t + (is_oov)*self.unk_id                                             #Replace OOVs with [UNK] token

        inds = T.stack(inds, dim=1)
        decoder_padding_mask = T.stack(decoder_padding_mask, dim=1)
#         if greedy is False:                                                                         #If multinomial based sampling, compute log probabilites of sampled words
#             log_probs = T.stack(log_probs, dim=1)
#             log_probs = log_probs * decoder_padding_mask                                            #Not considering sampled words with padding mask = 0
#             lens = T.sum(decoder_padding_mask, dim=1)                                               #Length of sampled sentence
#             log_probs = T.sum(log_probs, dim=1) / lens  # (bs,)                                     #compute normalizied log probability of a sentence
        decoded_strs = []
        ans_list = []
        for i in range(len(enc_out)):
            id_list = inds[i].cpu().numpy()
            oovs = article_oovs[i]
            S = data.outputids2words(id_list, self.vocab, oovs)                                     #Generate sentence corresponding to sampled words
            try:
                end_idx = S.index(data.STOP_DECODING)
                S = S[:end_idx]
            except ValueError:
                S = S
            if len(S) < 2:                                                                           #If length of sentence is less than 2 words, replace it with "xxx"; Avoids setences like "." which throws error while calculating ROUGE
                S = ["xxx"]
            S = " ".join(S)
            decoded_strs.append(S)
            ans_dict = {
                'review':batch.original_reviews[i],
                'key_words':batch.key_words[i],
                'summary':batch.original_summarys[i],                
                'decoded_str':S                
            }
            ans_list.append(ans_dict)
        return decoded_strs , ans_list

    def reward_function(self, decoded_sents, original_sents):
        rouge = Rouge()
        try:
            scores = rouge.get_scores(decoded_sents, original_sents)
        except Exception:
            print("Rouge failed for multi sentence evaluation.. Finding exact pair")
            scores = []
            for i in range(len(decoded_sents)):
                try:
                    score = rouge.get_scores(decoded_sents[i], original_sents[i])
                except Exception:
                    print("Error occured at:")
                    print("decoded_sents:", decoded_sents[i])
                    print("original_sents:", original_sents[i])
                    score = [{"rouge-l":{"f":0.0}}]
                scores.append(score[0])
        rouge_l_f1 = [score["rouge-l"]["f"] for score in scores]
        rouge_l_f1 = get_cuda(T.FloatTensor(rouge_l_f1))
        return rouge_l_f1 , scores

    # def write_to_file(self, decoded, max, original, sample_r, baseline_r, iter):
    #     with open("temp.txt", "w") as f:
    #         f.write("iter:"+str(iter)+"\n")
    #         for i in range(len(original)):
    #             f.write("dec: "+decoded[i]+"\n")
    #             f.write("max: "+max[i]+"\n")
    #             f.write("org: "+original[i]+"\n")
    #             f.write("Sample_R: %.4f, Baseline_R: %.4f\n\n"%(sample_r[i].item(), baseline_r[i].item()))


    def train_one_batch(self, batch, iter):
        ans_list, batch_scores = None , None
        enc_batch, enc_lens, enc_padding_mask, enc_batch_extend_vocab, extra_zeros, context = get_enc_data(batch)

        enc_batch = self.model.embeds(enc_batch)                                                    #Get embeddings for encoder input
        enc_out, enc_hidden = self.model.encoder(enc_batch, enc_lens)

        # -------------------------------Summarization-----------------------
        if self.opt.train_mle == True:                                                             #perform MLE training
            mle_loss = self.train_batch_MLE(enc_out, enc_hidden, enc_padding_mask, context, extra_zeros, enc_batch_extend_vocab, batch)
        else:
            mle_loss = get_cuda(T.FloatTensor([0]))
            
        if opt.view:
            sample_sents,ans_list = self.train_batch_decode(batch, enc_out, enc_hidden, enc_padding_mask, context, extra_zeros, enc_batch_extend_vocab, batch.art_oovs, greedy=True)
            _ , batch_scores = self.reward_function(sample_sents, batch.original_summarys)
        # --------------RL training-----------------------------------------------------
        if self.opt.train_rl == True:                                                              #perform reinforcement learning training
            # multinomial sampling
            sample_sents, RL_log_probs = self.train_batch_RL(enc_out, enc_hidden, enc_padding_mask, context, extra_zeros, enc_batch_extend_vocab, batch.art_oovs, greedy=False)
            with T.autograd.no_grad():
                # greedy sampling
                greedy_sents, _ = self.train_batch_RL(enc_out, enc_hidden, enc_padding_mask, context, extra_zeros, enc_batch_extend_vocab, batch.art_oovs, greedy=True)

            sample_reward , _ = self.reward_function(sample_sents, batch.original_summarys)
            baseline_reward , _ = self.reward_function(greedy_sents, batch.original_summarys)
            # if iter%200 == 0:
            #     self.write_to_file(sample_sents, greedy_sents, batch.original_abstracts, sample_reward, baseline_reward, iter)
            rl_loss = -(sample_reward - baseline_reward) * RL_log_probs                             #Self-critic policy gradient training (eq 15 in https://arxiv.org/pdf/1705.04304.pdf)
            rl_loss = T.mean(rl_loss)

            batch_reward = T.mean(sample_reward).item()
        else:
            rl_loss = get_cuda(T.FloatTensor([0]))
            batch_reward = 0

    # ------------------------------------------------------------------------------------
#         if opt.train_mle == True: 
        self.trainer.zero_grad()
        (self.opt.mle_weight * mle_loss + self.opt.rl_weight * rl_loss).backward()
        self.trainer.step()       
        
        return mle_loss.item(), batch_reward, ans_list, batch_scores
        
        
    def get_best_res_score(self,results,scores):
        max_score = float(0)
        _id = 0
        for idx in range(len(results)):       
            re_matchData = re.compile(r'\-?\d{1,10}\.?\d{1,10}')
            data = re.findall(re_matchData, str(scores[idx]))
            score = sum([float(d) for d in data])
            if score > max_score: 
                _id = idx
        return results[_id],scores[_id]
            
        
    
    def trainIters(self):
        iter = self.setup_train()
        epoch = 0
        count = mle_total = r_total = 0
        print("Start training.....")
        while iter <= config.max_iterations:
#         while iter <= config.max_epochs:
            f = open('training_log.txt','a+',encoding='utf-8')
            batch = self.batcher.next_batch()
            try:
                mle_loss, r , ans_list, batch_scores = self.train_one_batch(batch, iter)
#                 print(iter,mle_loss)
#                 break
            except KeyboardInterrupt:
                print("-------------------Keyboard Interrupt------------------")
                exit(0)
#             if opt.train_mle == False: break
            mle_total += mle_loss
            r_total += r
            count += 1
            iter += 1

            if iter % 1000 == 0:
                mle_avg = mle_total / count
                r_avg = r_total / count
                epoch = int((iter * config.batch_size) / train_num) + 1
                print('epoch:',epoch ,"iter:", iter, "mle_loss:", "%.3f" % mle_avg, "reward:", "%.4f" % r_avg)
                f.write('epoch: %s iter: %s mle_loss: %.3f reward: %.3f \n'%(epoch,iter,mle_avg,r_avg))
                if opt.view :
                    best_res , best_score = self.get_best_res_score(ans_list,batch_scores)
                    print('best_res:',best_res); f.write('best_res: %s \n' %(best_res))
                    print('best_score:',best_score); f.write('best_score: %s \n' %(best_score))
                count = mle_total = r_total = 0
                f.close()
#                 break

            if iter % 5000 == 0:
                self.save_model(iter)

# %%
# https://blog.csdn.net/u012869752/article/details/72513141
# 由于在jupyter notebook中，args不为空

# nvidia-smi -pm 1

if __name__ == "__main__":   
    parser = argparse.ArgumentParser()
    parser.add_argument('--train_mle', type=bool, default=True)
    parser.add_argument('--train_rl', type=bool, default=False)
    parser.add_argument('--mle_weight', type=float, default=1.0)
    parser.add_argument('--load_model', type=str, default=None)
    parser.add_argument('--new_lr', type=float, default=None)
    parser.add_argument('--multi_device', type=bool, default=True)
    parser.add_argument('--view', type=bool, default=True)
    parser.add_argument('--pre_train_emb', type=bool, default=True)
    parser.add_argument('--word_emb_type', type=str, default='word2Vec')
    parser.add_argument('--truncate', type=bool, default=False)
    opt = parser.parse_args(args=[])

    opt.rl_weight = 1 - opt.mle_weight  
    
#     config.vocab_path = "Embedding/%s/%s.vocab"%(opt.word_emb_type,opt.word_emb_type)
#     if config.word_emb_type == "glove": 
#         config.vocab_size = len(open(config.vocab_path, 'r',encoding='utf-8').readlines())
    
    if opt.truncate :
        if os.path.exists('training_log.txt'):
            with open('training_log.txt','r+',encoding='utf-8') as q :
                q.truncate()     
        else:
            open('training_log.txt','w').close()                

    f = open('training_log.txt','a+',encoding='utf-8')
    if opt.train_rl == True:
        print("Training mle: %s, Training rl: %s, mle weight: %.2f, rl weight: %.2f"%(opt.train_mle, opt.train_rl, opt.mle_weight, opt.rl_weight))
        f.write("Training mle: %s, Training rl: %s, mle weight: %.2f, rl weight: %.2f \n"%(opt.train_mle, opt.train_rl, opt.mle_weight, opt.rl_weight))
    else:
        print("Training mle: %s, mle weight: %.2f"%(opt.train_mle, opt.mle_weight))
        f.write("Training mle: %s, mle weight: %.2f \n"%(opt.train_mle, opt.mle_weight))

    if opt.pre_train_emb :
#         with open(config.vocab_path,'r',encoding='utf-8') as q :
#             config.vocab_size = len(q.readlines())   
        print('use pre_train_%s vocab_size %s '%(opt.word_emb_type,config.vocab_size))
        f.write('use pre_train_%s vocab_size %s \n'%(opt.word_emb_type,config.vocab_size))
        
    else:
        print('use %s %s vocab_size %s '%(opt.word_emb_type,config.vocab_size))
        f.write('use %s %s vocab_size %s \n'%(opt.word_emb_type,config.vocab_size))

    print("intra_encoder:", config.intra_encoder, "intra_decoder:", config.intra_decoder)
    f.write("intra_encoder: %s intra_decoder: %s \n"%(config.intra_encoder, config.intra_decoder))
    f.close()
    
    with open('training_log.txt','a+',encoding='utf-8') as f :
        f.write('----------------------------------------------------------------\n')
    train_processor = Train(opt)
    train_processor.trainIters()
# Out:
# Training mle: True, mle weight: 1.00
# use pre_train_word2Vec vocab_size 50000
# intra_encoder: True intra_decoder: True
# Start training.....
# epoch: 1 iter: 1000 mle_loss: 3.610 reward: 0.0000
# best_res: {'review': 'and have purchase many camera case this case just not get excited this case will not fit any camera much larger than ultra compact like fuji see link below the plaid design cute but the neoprene cover make feel cheap there very little padding uploaded picture this case alongside fuji finepix purplenbspa datum hookproduct link link classa link normal href fujifilm finepix mp digital camera with optical zoom and inch lcd purple bhewa refcmcrarpdrvwtxtieutffujifilm finepix mp digital camera with optical zoom and inch lcd purple anbsp if take look at the picture the case look considerably larger than the camera but there very little room with the camera inside and not know the reason for this since there very little padding think part the reason look far larger the outside as compare to the inside the zipper the interior take up lot space when the camera remove from the case the battery compartment lid snag the inside the case and pull the lid open easy way to either break off the lid lose the card the battery this due to the hidden part the zipper where stitch the inside the case the overall stitching poorly too at least the case receive pucker where should not and not symmetrical ', 'key_words': ['inside', 'stitch'], 'summary': '<s> cute plaid design but cheaply make </s>', 'decoded_str': '[UNK] cute case [UNK]'}
# best_score: {'rouge-1': {'f': 0.18181817785123974, 'p': 0.3333333333333333, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13543599257895406, 'p': 0.3333333333333333, 'r': 0.125}}
# epoch: 1 iter: 2000 mle_loss: 3.495 reward: 0.0000
# best_res: {'review': 'great picture out this small camera test several location and so far so good inexpensive way to keep eye thing run this dvr system for big company good for blindspot building warehouse ', 'key_words': ['small', 'great', 'picture', 'camera', 'company', 'big'], 'summary': '<s> awesome picture from small camera </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.19999999580000008, 'p': 0.3333333333333333, 'r': 0.14285714285714285}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.15675675675685707, 'p': 0.3333333333333333, 'r': 0.14285714285714285}}
# epoch: 1 iter: 3000 mle_loss: 3.503 reward: 0.0000
# best_res: {'review': 'blow away with the new canon mk iii realize that review right the heel purchasing so may update the future as for now will post what out most the ability amazing dead accurate even the dark take some picture with bulb light up the room and would still focus pretty much anything the high iso capability and quality at high isos nothing short astounding not only the high iso quality great but love love love the quality the noise have read several time and concur the noise the iii film like look more like grain than noise have provide link with raw image show phenomenal high iso capability also compare dynamic range vs the nikon would have no hesitation shoot at iso that good as the following link will show with little clean up the image very very usable imo admittedly still have lot to discover and high iso at the very top list so naturally that what explore when come to photography professional pretty old school bell and whistle not matter to as much as image quality so will discover more pro and con as learn and explore more but as far as the meat and bone the camera build and image quality could not more satisfied this the the series that consider true professional camera rather than prosumer at this time can honestly say the canon iii exceed all previous hope and expectation will update this review as well as image the link above the future ', 'key_words': ['update', 'expectation', 'iso', 'top', 'high', 'quality', 'film', 'raw', 'very', 'image', 'camera', 'isos', 'future', 'range', 'usable', 'dynamic', 'realize', 'iii', 'prosumer', 'true', 'professional', 'previous', 'hope', 'imo', 'review', 'list'], 'summary': '<s> camera available until </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22368421052631188, 'p': 0.3333333333333333, 'r': 0.2}}
# epoch: 2 iter: 4000 mle_loss: 3.403 reward: 0.0000
# best_res: {'review': 'this camera good device by fuji have own other fuji camera and have quite pleased with this camera certainly different and therefore has some interesting quality which will discuss here physically the red color great the surface the camera high gloss not pick up normal fingerprint and seem bit scratch resistant the door for the battery and memory card compartment not close as cleanly as would prefer so this worry there door which conceal the usb connection but will need to open the battery cover every time want to charge the battery however the door that hide the port only secure with strip plastic and could easily break off and get lose the camera also seem heavier than most other that have use touchscreen this camera has touchscreen with no button to control menu function everything via the touchscreen the screen large and bright when use the camera the image surround the left and right edge by option so the image not fill the entire screen while shoot picture the touchscreen somewhat responsive although this not the type touchscreen would find phone music device need to apply just bit pressure to activate section the screen other word sense pressure and not the static charge finger there orientation sensor the camera that will sense which way hold the camera landscape and will rotate the menu option right side up accordingly have notice however that the screen very fingerprint prone would also call the touchscreen bit bouncy when touch not like touch glass like touch plastic sheet probably without say but this camera deserve case to protect especially the touchscreen functionality to turn the camera have to pull the protective door down this really counter intuitive since not the way hand work when hold camera much easier to pull slide door to the left right once this take for the device to ready to take picture as soon as the image appear the screen can press the shutter release and take picture within if leave the camera auto then almost ready to the camera will automatically shut down after and not easy to restart quickly the lens at the upper left when hold the camera there no indentation that prevent finger from get the way have have several shot that include the edge finger other word have to hold this camera just right to keep finger out the image there no independent viewfinder so must everything through the display the menu system simple common function available while take picture some option however bury level below the top level so not always quick to get to the setting need there general setup menu that allow to choose global setting such as screen brightness sound level etc image quality auto mode can definitely see the camera work will actively compensate for difference lighting and will choose appropriate flash setting can course override everything and select specific shooting mode the camera seem to perform fairly well low light situation but still incapable capture distant object dark setting other word will not able to sit the middle the auditorium and capture child during recital particularly glaring obstacle how the camera decide to auto focus while use zoom if center object then zoom the image incredibly out focus until zooming and re center the object unfortunately very easy to lose the subject when this happen megapixel really make difference this camera not only feature megapixel but also has exr mode which force the camera to give priority over resolution and noise reduction all this very apparent have never easily impress with higher megapixel number but this camera has convince otherwise for example if take picture from across the room dvr and use the camera edit feature to crop very small region image can clearly discern the very tiny print the control button dvr what this mean well if take picture without use zoom can edit the picture and zoom crop without lose any quality have quite impressed with what can the camera without use natural light picture some the best have e ...
# best_score: {'rouge-1': {'f': 0.13333332835555575, 'p': 0.14285714285714285, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13216374268970296, 'p': 0.14285714285714285, 'r': 0.125}}
# epoch: 2 iter: 5000 mle_loss: 3.469 reward: 0.0000
# best_res: {'review': 'purchase this from as use actually brand new judge by the manual and component still seal original wrapping love this camera especially the dual ovf and evf for frame and view photo the evf the highest resolution for camera this price the ovf allow to see as through the naked eye love to able to view photo through the lcd as well as the evf also like to take photo with the ovf word caution not alarm when use the macro mode for focus will lost the ovf this way will not mislead by the paralex extreme close framing make sense by the way even purchase from as use the limited edition certificate still come the box as new purchase thank for extremely good deal otherwise can not afford this limited edition at the list price update have shoot photo with this camera and love the quality the image particularly satisfy to view the slide show the evf as has higher resolution than the lcd look through the also has lovely effect not there with the lcd ', 'key_words': ['component', 'lcd', 'eye', 'dual', 'manual', 'evf', 'wrapping', 'original', 'seal', 'view', 'camera', 'naked', 'edition', 'love', 'higher', 'certificate', 'resolution', 'ovf', 'limited', 'slide'], 'summary': '<s> love this limited edition at significant price reduction </s>', 'decoded_str': '[UNK] great camera for the price [UNK]'}
# best_score: {'rouge-1': {'f': 0.12499999531250018, 'p': 0.16666666666666666, 'r': 0.1}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11184210526315402, 'p': 0.16666666666666666, 'r': 0.1}}
# epoch: 2 iter: 6000 mle_loss: 3.368 reward: 0.0000
# best_res: {'review': 'purchase this camera look for one that smaller and more portable than dslr but also capable great image pro the image quality great well low light small and easy to handle intuitive operation flash for snapshot con bit slow to save image to disk not seem to as well with action shot no viewfinder but know that when buy will probably add the vf viewfinder accessory have also purchase the fotodiox adapter that allow use slr manual lense with this body summary great quality good camera for family photo sightsee etc ', 'key_words': ['light', 'low', 'great', 'purchase', 'operation', 'image', 'camera', 'lense', 'manual', 'adapter', 'intuitive', 'fotodiox', 'quality', 'good', 'smaller'], 'summary': '<s> small camera great image </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.44444444000000005, 'p': 0.6666666666666666, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.18518518518525923, 'p': 0.3333333333333333, 'r': 0.16666666666666666}}
# epoch: 3 iter: 7000 mle_loss: 3.256 reward: 0.0000
# best_res: {'review': 'have not love with camera since canon that had high school that until have put the through the ringer for now and has perform like champ beautiful design and stunning performance this the best digital camera have ever use ', 'key_words': ['beautiful', 'design', 'digital', 'camera', 'stunning', 'performance'], 'summary': '<s> best digital camera yet </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.22222221777777784, 'p': 0.3333333333333333, 'r': 0.16666666666666666}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.18518518518525923, 'p': 0.3333333333333333, 'r': 0.16666666666666666}}
# epoch: 3 iter: 8000 mle_loss: 3.049 reward: 0.0000
# best_res: {'review': 'this great camera especially for kid the off slide protect the lens take great picture and video buy for like so much buy another one ', 'key_words': ['protect', 'great', 'picture', 'camera', 'video', 'lens'], 'summary': '<s> great camera for the price </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.3999999958, 'p': 0.6666666666666666, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.22222221777777784, 'p': 0.3333333333333333, 'r': 0.16666666666666666}, 'rouge-l': {'f': 0.3135135135136138, 'p': 0.6666666666666666, 'r': 0.2857142857142857}}
# epoch: 3 iter: 9000 mle_loss: 3.360 reward: 0.0000
# best_res: {'review': 'have very satisfied with this product the picture quality simply wonderful at iso setting at and below have recommend this camera and nikon to many friend and anticipate to use nikon camera the future easy to use take great picture this what know about this camera after use for now the and seem to improvement this good design ', 'key_words': ['great', 'nikon', 'design', 'picture', 'camera', 'recommend', 'good'], 'summary': '<s> great camera for some who appreciate photography </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.33333332958333334, 'p': 0.6666666666666666, 'r': 0.2222222222222222}, 'rouge-2': {'f': 0.18181817785123974, 'p': 0.3333333333333333, 'r': 0.125}, 'rouge-l': {'f': 0.23809523809533759, 'p': 0.6666666666666666, 'r': 0.2222222222222222}}
# epoch: 3 iter: 10000 mle_loss: 3.139 reward: 0.0000
# best_res: {'review': 'this great camera for the money take great photo video and the lens very good the telephoto lens zoom very clear and has great zoom distance ', 'key_words': ['zoom', 'great', 'distance', 'camera', 'money', 'video', 'lens', 'photo'], 'summary': '<s> well make camera for the money </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.18181817785123974, 'p': 0.3333333333333333, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13543599257895406, 'p': 0.3333333333333333, 'r': 0.125}}
# epoch: 4 iter: 11000 mle_loss: 3.220 reward: 0.0000
# best_res: {'review': 'space small space top name valuehttps image ssl image image ckgnpuxjs mp classvideo urlinput typehidden name valuehttps image ssl image image riftzbls png classvideo slate img urlnbspthis video take camera phone video test powershot at at frame per ', 'key_words': ['small', 'urlnbspthis', 'video', 'space'], 'summary': '<s> best camera ever </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22368421052631188, 'p': 0.3333333333333333, 'r': 0.2}}
# epoch: 4 iter: 12000 mle_loss: 3.161 reward: 0.0000
# best_res: {'review': 'this camera unbelievable crisp photo and high definition video not to mention very easy to use and navigate through the setting highly recommend for novice photographer professional ', 'key_words': ['crisp', 'definition', 'high', 'video', 'photo'], 'summary': '<s> awesome camera </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 4 iter: 13000 mle_loss: 2.908 reward: 0.0000
# best_res: {'review': 'purchase this from as use actually brand new judge by the manual and component still seal original wrapping love this camera especially the dual ovf and evf for frame and view photo the evf the highest resolution for camera this price the ovf allow to see as through the naked eye love to able to view photo through the lcd as well as the evf also like to take photo with the ovf word caution not alarm when use the macro mode for focus will lost the ovf this way will not mislead by the paralex extreme close framing make sense by the way even purchase from as use the limited edition certificate still come the box as new purchase thank for extremely good deal otherwise can not afford this limited edition at the list price update have shoot photo with this camera and love the quality the image particularly satisfy to view the slide show the evf as has higher resolution than the lcd look through the also has lovely effect not there with the lcd ', 'key_words': ['component', 'lcd', 'eye', 'dual', 'manual', 'evf', 'wrapping', 'original', 'seal', 'view', 'camera', 'naked', 'edition', 'love', 'higher', 'certificate', 'resolution', 'ovf', 'limited', 'slide'], 'summary': '<s> love this limited edition at significant price reduction </s>', 'decoded_str': '[UNK] not buy this camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.13333332888888905, 'p': 0.2, 'r': 0.1}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11111111111118518, 'p': 0.2, 'r': 0.1}}
# epoch: 5 iter: 14000 mle_loss: 2.895 reward: 0.0000
# best_res: {'review': 'nice camera for the price like the auto smile feature lightweight and easy to use able to recover photo after have delete would recommend this camera buy pink one for daughter and blue one for son both enjoy use these camera ', 'key_words': ['recommend', 'camera', 'nice'], 'summary': '<s> decent camera </s>', 'decoded_str': '[UNK] nice camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 5 iter: 15000 mle_loss: 3.414 reward: 0.0000
# best_res: {'review': 'this camera good device by fuji have own other fuji camera and have quite pleased with this camera certainly different and therefore has some interesting quality which will discuss here physically the red color great the surface the camera high gloss not pick up normal fingerprint and seem bit scratch resistant the door for the battery and memory card compartment not close as cleanly as would prefer so this worry there door which conceal the usb connection but will need to open the battery cover every time want to charge the battery however the door that hide the port only secure with strip plastic and could easily break off and get lose the camera also seem heavier than most other that have use touchscreen this camera has touchscreen with no button to control menu function everything via the touchscreen the screen large and bright when use the camera the image surround the left and right edge by option so the image not fill the entire screen while shoot picture the touchscreen somewhat responsive although this not the type touchscreen would find phone music device need to apply just bit pressure to activate section the screen other word sense pressure and not the static charge finger there orientation sensor the camera that will sense which way hold the camera landscape and will rotate the menu option right side up accordingly have notice however that the screen very fingerprint prone would also call the touchscreen bit bouncy when touch not like touch glass like touch plastic sheet probably without say but this camera deserve case to protect especially the touchscreen functionality to turn the camera have to pull the protective door down this really counter intuitive since not the way hand work when hold camera much easier to pull slide door to the left right once this take for the device to ready to take picture as soon as the image appear the screen can press the shutter release and take picture within if leave the camera auto then almost ready to the camera will automatically shut down after and not easy to restart quickly the lens at the upper left when hold the camera there no indentation that prevent finger from get the way have have several shot that include the edge finger other word have to hold this camera just right to keep finger out the image there no independent viewfinder so must everything through the display the menu system simple common function available while take picture some option however bury level below the top level so not always quick to get to the setting need there general setup menu that allow to choose global setting such as screen brightness sound level etc image quality auto mode can definitely see the camera work will actively compensate for difference lighting and will choose appropriate flash setting can course override everything and select specific shooting mode the camera seem to perform fairly well low light situation but still incapable capture distant object dark setting other word will not able to sit the middle the auditorium and capture child during recital particularly glaring obstacle how the camera decide to auto focus while use zoom if center object then zoom the image incredibly out focus until zooming and re center the object unfortunately very easy to lose the subject when this happen megapixel really make difference this camera not only feature megapixel but also has exr mode which force the camera to give priority over resolution and noise reduction all this very apparent have never easily impress with higher megapixel number but this camera has convince otherwise for example if take picture from across the room dvr and use the camera edit feature to crop very small region image can clearly discern the very tiny print the control button dvr what this mean well if take picture without use zoom can edit the picture and zoom crop without lose any quality have quite impressed with what can the camera without use natural light picture some the best have e ...
# best_score: {'rouge-1': {'f': 0.1249999950000002, 'p': 0.125, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.1249999999995, 'p': 0.125, 'r': 0.125}}
# epoch: 5 iter: 16000 mle_loss: 3.242 reward: 0.0000
# best_res: {'review': 'excellent less camera the nex menu system easy to use have fewer button actually make easier to navigate as the menu provide description each option for newer to average user shoot mostly nature and portrait this camera simply stunning such crisp image from the kit lense and such great preview screen that fully tilt able ', 'key_words': ['nature', 'crisp', 'kit', 'system', 'button', 'excellent', 'portrait', 'menu', 'user', 'camera', 'average', 'easier', 'great', 'screen', 'preview', 'image', 'lense', 'fewer', 'navigate', 'easy'], 'summary': '<s> great aps camera easy to use amazing quality </s>', 'decoded_str': '[UNK] excellent camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.15384615029585808, 'p': 0.3333333333333333, 'r': 0.1}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.10613437195724833, 'p': 0.3333333333333333, 'r': 0.1}}
# epoch: 6 iter: 17000 mle_loss: 2.978 reward: 0.0000
# best_res: {'review': 'this camera work well for inexpensive point and shoot camera great value for camera person look for simplicity with decent quality ', 'key_words': ['point', 'camera', 'decent', 'quality', 'inexpensive'], 'summary': '<s> camera review </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 6 iter: 18000 mle_loss: 2.917 reward: 0.0000
# best_res: {'review': 'none the report dust fleck problem decent low light performance and fantastic large photo would not trade this camera for any other the market ', 'key_words': ['light', 'low', 'large', 'fantastic', 'photo', 'decent', 'performance'], 'summary': '<s> best camera ever </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22368421052631188, 'p': 0.3333333333333333, 'r': 0.2}}
# epoch: 6 iter: 19000 mle_loss: 2.964 reward: 0.0000
# best_res: {'review': 'many review point to the limit this camera yes reflex better extreme condition but for the everyday usage this mega pixel wide angle lens compact camera superb at this price and size even the movie feature outstanding ', 'key_words': ['outstanding', 'everyday', 'price', 'wide', 'compact', 'usage', 'camera', 'size', 'extreme', 'feature', 'condition'], 'summary': '<s> great camera </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.5714285665306124, 'p': 0.6666666666666666, 'r': 0.5}, 'rouge-2': {'f': 0.3333333283333334, 'p': 0.3333333333333333, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.5494505494503625, 'p': 0.6666666666666666, 'r': 0.5}}
# epoch: 6 iter: 20000 mle_loss: 2.800 reward: 0.0000
# best_res: {'review': 'buy this and instal runner to help hook up boat trailer installation easy and for work great amazing how easy to connect trailer with these baby then rain camera fog image blur but still at least could see the hitch well enough to hook up then the monitor die now the display just flicker know the monitor because flicker even when menu edit contact the company and reply that send replacement unit ', 'key_words': ['instal', 'reply', 'runner', 'company'], 'summary': '<s> work great for wks get warranty replacement </s>', 'decoded_str': '[UNK] great product [UNK]'}
# best_score: {'rouge-1': {'f': 0.16666666291666676, 'p': 0.3333333333333333, 'r': 0.1111111111111111}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11904761904771854, 'p': 0.3333333333333333, 'r': 0.1111111111111111}}
# epoch: 7 iter: 21000 mle_loss: 2.976 reward: 0.0000
# best_res: {'review': 'buy this model feb and have use until last trip to during dec the camera exposure to water take to the swimming pool at the resort and to the beach etc and completely immerse the water while keep bathing suit pocket after the camera stop work and could see the water trap inside the lense obviously the camera not water proof as say what lie and thank to that about to lose all picture during the trip take out the battery from the camera and also cover with water open every hole the camera to dry and keep dry after come back home could salvage the picture from the memory card but the camera lose all function take picture recording even view both the lense and the lcd screen still mess up with water had to buy new camera and choose powershot favorite model the only reason had buy olympus stylus the quality picture not even close to canon think will more rugged but the result big disappointment never na buy plympu stylus again ', 'key_words': ['lcd', 'lense', 'picture', 'screen', 'lose', 'salvage', 'open', 'hole'], 'summary': '<s> water proof </s>   <s> water disaster </s>', 'decoded_str': '[UNK] not waterproof proof not waterproof [UNK]'}
# best_score: {'rouge-1': {'f': 0.22222221728395072, 'p': 0.25, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.21693121693096162, 'p': 0.25, 'r': 0.2}}
# epoch: 7 iter: 22000 mle_loss: 3.024 reward: 0.0000
# best_res: {'review': 'this phenomenal camera has so many great feature and the photo quality fantastic great buy for the price ', 'key_words': ['buy', 'great', 'camera', 'phenomenal', 'feature'], 'summary': '<s> digital camera </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 7 iter: 23000 mle_loss: 2.769 reward: 0.0000
# best_res: {'review': 'pro take nikond with lens comfortably can fit and can still squeeze space for extra lense just about right size for hiking more comfortable than sle bag easy to change lens the field secure design with zip safely against the back when use con no rain cover useful addition for the next edition pouch for netbook ', 'key_words': ['secure', 'design', 'lense', 'extra'], 'summary': '<s> good bag for lens </s>', 'decoded_str': '[UNK] good bag [UNK]'}
# best_score: {'rouge-1': {'f': 0.44444444000000005, 'p': 0.6666666666666666, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-l': {'f': 0.37037037037044435, 'p': 0.6666666666666666, 'r': 0.3333333333333333}}
# epoch: 8 iter: 24000 mle_loss: 2.879 reward: 0.0000
# best_res: {'review': 'specifically send cowboy studio email and ask if this use the same frequency as single trigger reply yes wrong ', 'key_words': ['trigger', 'single', 'send', 'cowboy', 'studio', 'reply'], 'summary': '<s> not work with other cowboy studio trigger </s>', 'decoded_str': '[UNK] work work work as cowboy trigger as cowboy [UNK]'}
# best_score: {'rouge-1': {'f': 0.4285714239795918, 'p': 0.6, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.3723653395784906, 'p': 0.6, 'r': 0.3333333333333333}}
# epoch: 8 iter: 25000 mle_loss: 3.122 reward: 0.0000
# best_res: {'review': 'this work great when not have official camera bag with to and not bring camera backpack because not technical enough for hike this padding wrap work great easy to wrap and the velcro great would recommend this product definitely give more flexibility to protect equipment ', 'key_words': ['wrap', 'great', 'padding', 'velcro', 'recommend', 'product'], 'summary': '<s> great product </s>', 'decoded_str': '[UNK] great bag [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 8 iter: 26000 mle_loss: 3.089 reward: 0.0000
# best_res: {'review': 'this camera normally take great photo but sometimes when use the flash there small white circle all over the picture this supposedly due to dust particle the air but never had this problem with previous fuji camera ', 'key_words': ['great', 'small', 'camera', 'previous', 'photo', 'white', 'circle'], 'summary': '<s> great except for the white circle </s>', 'decoded_str': '[UNK] great camera but not the bad [UNK]'}
# best_score: {'rouge-1': {'f': 0.266666661688889, 'p': 0.2857142857142857, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2643274853797614, 'p': 0.2857142857142857, 'r': 0.25}}
# epoch: 9 iter: 27000 mle_loss: 2.787 reward: 0.0000
# best_res: {'review': 'intuitive menu small battery keep charge for long time take good photo no problem after highly recommend ', 'key_words': ['menu', 'photo', 'intuitive', 'good'], 'summary': '<s> easy to use and good pix </s>', 'decoded_str': '[UNK] good camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.18181817785123974, 'p': 0.3333333333333333, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13543599257895406, 'p': 0.3333333333333333, 'r': 0.125}}
# epoch: 9 iter: 28000 mle_loss: 2.509 reward: 0.0000
# best_res: {'review': 'this case much bulkier than expect hold basically only the camera and couple small accessory and to not worth the price exchange for the lowepro trekker backpack which less expensive and fit everything extra lense and all accessory nice compact package that can put back ', 'key_words': ['lense', 'nice', 'package', 'extra', 'compact'], 'summary': '<s> great quality but awkward and not hold much </s>', 'decoded_str': '[UNK] great case for the price [UNK]'}
# best_score: {'rouge-1': {'f': 0.12499999531250018, 'p': 0.16666666666666666, 'r': 0.1}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.11184210526315402, 'p': 0.16666666666666666, 'r': 0.1}}
# epoch: 9 iter: 29000 mle_loss: 2.608 reward: 0.0000
# best_res: {'review': 'buy this for boyfriend for use for fire call great little camera and the quality the video awesome ', 'key_words': ['quality', 'camera', 'great'], 'summary': '<s> great investment </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 9 iter: 30000 mle_loss: 2.843 reward: 0.0000
# best_res: {'review': 'receive this camera and so far delighted with that say please advise that if wish to purchase additional battery which when pre order camera the information for the battery type incorrect the website state that the battery type when fact not interchangeable as different size battery and will not work with the charger that come with the camera the accessory kit that indicate for this camera also include the battery speak with and inform this error ship the correct battery and hopefully will correct this information soon ', 'key_words': ['battery', 'additional', 'purchase', 'accessory', 'camera', 'receive', 'kit', 'incorrect', 'website', 'correct'], 'summary': '<s> wrong battery info from </s>', 'decoded_str': '[UNK] battery battery [UNK]'}
# best_score: {'rouge-1': {'f': 0.24999999625000005, 'p': 0.5, 'r': 0.16666666666666666}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.17857142857152802, 'p': 0.5, 'r': 0.16666666666666666}}
# epoch: 10 iter: 31000 mle_loss: 2.254 reward: 0.0000
# best_res: {'review': 'know the draw back to this camera when to buy what not know that the resolution even better than what people say online word caution when instal spp have to install so that will always run as administrator win take several time instal to figure out crash normal install and run as admin ', 'key_words': ['crash', 'normal', 'install'], 'summary': '<s> great resolution </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 10 iter: 32000 mle_loss: 2.843 reward: 0.0000
# best_res: {'review': 'when develop this product film black no picture viewable disappoint since no memory picture for very important event ', 'key_words': ['develop', 'product'], 'summary': '<s> when develop this product film black </s>   <s> no picture </s>', 'decoded_str': '[UNK] no picture picture viewable [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142816326531, 'p': 0.5, 'r': 0.2}, 'rouge-2': {'f': 0.12499999570312517, 'p': 0.2, 'r': 0.09090909090909091}, 'rouge-l': {'f': 0.21804511278205893, 'p': 0.5, 'r': 0.2}}
# epoch: 10 iter: 33000 mle_loss: 2.818 reward: 0.0000
# best_res: {'review': 'has so many feature for the money famous brand so know get quality good menu function so versatile ', 'key_words': ['brand', 'function', 'menu', 'famous', 'so', 'many', 'feature', 'good'], 'summary': '<s> fabulous camera at great price </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.3999999958, 'p': 0.6666666666666666, 'r': 0.2857142857142857}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.15675675675685707, 'p': 0.3333333333333333, 'r': 0.14285714285714285}}
# epoch: 11 iter: 34000 mle_loss: 2.887 reward: 0.0000
# best_res: {'review': 'the camera great unbelievable dedicate eos til get the great camera but to much to carry basis see bounty and rant the the bestest camera the world so buy and have procee to buy the option that fit amazing camera ', 'key_words': ['option', 'great', 'buy', 'camera', 'amazing'], 'summary': '<s> besstest camera ever size and function </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.18181817785123974, 'p': 0.3333333333333333, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13543599257895406, 'p': 0.3333333333333333, 'r': 0.125}}
# epoch: 11 iter: 35000 mle_loss: 2.787 reward: 0.0000
# best_res: {'review': 'have different photo frame range from the little impecca inch photo album to frame each from different company not buy from as out stock the color want when ready to purchase so end up buy from another source the good job display the photo have very hassle free and easy to use maybe part due to limited option bottom line neat little photo frame would buy again yes heartbeat the touch screen work nicely just slide finger down up to move to the next previous photo slide right leave and tap to change folder have over photo load and has hardly make dent the amount memory use the album come with own software program that automatically load onto each time connect to the program contain the internal memory the impecca must use the program to download photo to delete photo the album have never have any problem with the program and easy to use have use with different operating system and win no problem with any the program allow to select photo from crop rotate add title and date to each photo sure to any rotation and crop because when press ok to add title the photo immediately add to the list for download limitation the album come preloade with folder which to store photo can not add more folder so far for that has not problem perhaps other people might want more folder to organize photo the photo each folder display the order select and load into the folder there no way that have find to change the order other than deleate and reload new order can rename the folder but limit to character to that bit limit for example can not label one as grandchild although the album show up window explorer will not see any the folder the photo store the device will not able to copy any the photo from the album back to the slideshow feature cycle through the photo whatever folder when start the slideshow can change by just select another folder the photo display the order which load into the folder no option for random play just the option to set the length time each display there no battery indicator to let know when the battery get low there battery indicator that show up when have plug into but still not let know how far from full charge just if charge blink charge steady all all nice little album especially give the price ', 'key_words': ['folder', 'crop', 'display', 'internal', 'limited', 'select', 'add', 'load', 'system', 'nice', 'order', 'change', 'feature', 'memory', 'operating', 'rotation', 'slideshow', 'rename', 'option', 'win', 'start', 'limit', 'album', 'job', 'good', 'list'], 'summary': '<s> good little photo frame </s>', 'decoded_str': '[UNK] good camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.22222221777777784, 'p': 0.3333333333333333, 'r': 0.16666666666666666}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.18518518518525923, 'p': 0.3333333333333333, 'r': 0.16666666666666666}}
# epoch: 11 iter: 36000 mle_loss: 2.801 reward: 0.0000
# best_res: {'review': 'if travel and like to bring tripod this the ideal solution for buy this recommendation from someone camera club who travel extensively and take lot picture if need something really light carbon fiber the way to if weight less important then the aluminum version available for about less ', 'key_words': ['really', 'ideal', 'carbon', 'light', 'solution'], 'summary': '<s> super light and hold large dslr and long lens without any problem </s>', 'decoded_str': '[UNK] perfect solution for travel and travel [UNK]'}
# best_score: {'rouge-1': {'f': 0.10526315357340738, 'p': 0.16666666666666666, 'r': 0.07692307692307693}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0849564857025364, 'p': 0.16666666666666666, 'r': 0.07692307692307693}}
# epoch: 12 iter: 37000 mle_loss: 2.393 reward: 0.0000
# best_res: {'review': 'had canon that run aa battery which not like however until recently the photo the canon very nice colorful and crisp recently the flash stop work so look for another camera really want to like the camera because extremely happy with hdtv however after spend take indoor photo and photo cloudy dark weather discover that the photo look soft fuzzy under those condition when compare to the old canon had when work properly also not well with move pet child etc very easy camera to use and like the larger view window but only happy with the photo take sunny light outdoors exchange for the canon and take photo pet indoor and the dark cloudy weather all the photo come out much crisper clearer and with truer color that with the think the ok camera but not happy with ', 'key_words': ['pet', 'dark', 'cloudy', 'weather', 'photo', 'indoor'], 'summary': '<s> return this camera </s>', 'decoded_str': '[UNK] nice camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22368421052631188, 'p': 0.3333333333333333, 'r': 0.2}}
# epoch: 12 iter: 38000 mle_loss: 2.459 reward: 0.0000
# best_res: {'review': 'play with for until try take pics underwater less than deep and bad news water leak lcd stop work and camera stop respond first thing to check that battery latch properly close and since can only close once manually lock yep not problem there so guess bad luck defective item anyway will return for another product ', 'key_words': ['bad', 'deep', 'return', 'guess', 'defective', 'news', 'item', 'product'], 'summary': '<s> submerse to test and water leak </s>', 'decoded_str': '[UNK] test test [UNK]'}
# best_score: {'rouge-1': {'f': 0.19999999680000002, 'p': 0.5, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13076923076930555, 'p': 0.5, 'r': 0.125}}
# epoch: 12 iter: 39000 mle_loss: 2.528 reward: 0.0000
# best_res: {'review': 'buy this camera for wife and absolutely love the megapixel take great picture and love the build setting the picture button that allow for different picture setting would highly recommend for anyone who not professional photog ', 'key_words': ['great', 'buy', 'camera', 'picture'], 'summary': '<s> great little camera for good price </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.3636363596694215, 'p': 0.6666666666666666, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.27087198515780375, 'p': 0.6666666666666666, 'r': 0.25}}
# epoch: 12 iter: 40000 mle_loss: 2.706 reward: 0.0000
# best_res: {'review': 'so far so awesome the pentax foray into dslr photography great price and has everything that want to the lens great use for astrophotography have some vignetting and the wider range but that easy enough to correct post processing ', 'key_words': ['great', 'range', 'price', 'vignetting', 'wider'], 'summary': '<s> so far so awesome </s>   <s> the pentax foray into </s>', 'decoded_str': '[UNK] great pentax dslr [UNK]'}
# best_score: {'rouge-1': {'f': 0.15384614958579892, 'p': 0.25, 'r': 0.1111111111111111}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.12232030264826811, 'p': 0.25, 'r': 0.1111111111111111}}
# epoch: 13 iter: 41000 mle_loss: 2.364 reward: 0.0000
# best_res: {'review': 'have use several camera from canon include the mark and now the mark iii this camera will provide with the tool to capture great work but will need the best lense cheap zoom cheap prime lense will produce chromatic aberration that will make the money spend this camera waste other word the resolution the sensor so high exceed many lense currently the market why would someone buy this body instead thenbspa datum hookproduct link link classa link normal href canon eos bgztls refcmcrarpdrvwtxtieutfcanon eos because the build the body the durability the shutter and battery life these factor provide the user with camera that can withstand the extreme nature while work this camera heavier than the even if the has the optional grip so if not like camera with mass this camera not for have use this camera the rain sleet snow and the heat has perform flawlessly the resolution provide enough datum for beautiful print yes professional photographer and immerse the software and hardware to make photograph aware that there much more to photography than the camera body but the camera body sensor that the cornerstone for great image ', 'key_words': ['produce', 'body', 'shutter', 'high', 'spend', 'link', 'rain', 'prime', 'cheap', 'great', 'lense', 'camera', 'tool', 'hardware', 'image', 'print', 'sleet', 'provide', 'immerse', 'chromatic', 'photographer', 'buy', 'zoom', 'eos', 'iii', 'aberration', 'snow', 'heat', 'life', 'beautiful', 'professional', 'software', 'capture', 'sensor', 'mark', 'normal'], 'summary': '<s> canon flagship camera </s>', 'decoded_str': '[UNK] best camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.24999999531250006, 'p': 0.3333333333333333, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.22368421052631188, 'p': 0.3333333333333333, 'r': 0.2}}
# epoch: 13 iter: 42000 mle_loss: 2.756 reward: 0.0000
# best_res: {'review': 'should have look at the product dimension as little bulky for there room for extra memory card battery though find the carabiner attachment annoying but no big great build quality although annoying to take and out the case with the velcro strap for what make for great and protect camera nicely very durable ', 'key_words': ['battery', 'great', 'camera', 'extra', 'memory', 'build', 'quality'], 'summary': '<s> great but little bigger than expect </s>', 'decoded_str': '[UNK] great case for the price [UNK]'}
# best_score: {'rouge-1': {'f': 0.14285713795918387, 'p': 0.16666666666666666, 'r': 0.125}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13736263736245044, 'p': 0.16666666666666666, 'r': 0.125}}
# epoch: 13 iter: 43000 mle_loss: 2.353 reward: 0.0000
# best_res: {'review': 'superb fast tiny bit less than but whole lot better than use to nuts with noise but almost perfect camera for compare to dmarkii other than mp and video feature faster more durable and cheaper would recommend ', 'key_words': ['fast', 'bit', 'camera', 'almost', 'perfect', 'mp', 'tiny', 'feature'], 'summary': '<s> by far the best camera ever </s>', 'decoded_str': '[UNK] great camera for the price [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.13736263736245044, 'p': 0.16666666666666666, 'r': 0.125}}
# epoch: 14 iter: 44000 mle_loss: 2.464 reward: 0.0000
# best_res: {'review': 'pick this camera because have have olympus the past and great very disappointed with this new camera photo major and not like lug expensive camera around but now not have much choice this camera take horrible grainy picture low light with little color have also have huge chunk pixel out and have have for spring the extra money to get canon ', 'key_words': ['grainy', 'light', 'low', 'picture', 'horrible', 'money', 'extra'], 'summary': '<s> horrible camera </s>', 'decoded_str': '[UNK] great camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 14 iter: 45000 mle_loss: 2.157 reward: 0.0000
# best_res: {'review': 'purchase this as replacement for older mp version little rough realy like the fact that can shoot high re for the family and kid pic and easily switch to lower re product image for business and email need ', 'key_words': ['email', 'shoot', 'family', 'high', 'business', 'pic'], 'summary': '<s> just what hope would </s>', 'decoded_str': '[UNK] not what expect [UNK]'}
# best_score: {'rouge-1': {'f': 0.1999999952000001, 'p': 0.25, 'r': 0.16666666666666666}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.18571428571420734, 'p': 0.25, 'r': 0.16666666666666666}}
# epoch: 14 iter: 46000 mle_loss: 2.345 reward: 0.0000
# ...
# epoch: 87 iter: 288000 mle_loss: 1.145 reward: 0.0000
# best_res: {'review': 'after research online finally take the plunge and purchase the coolpix stylish compact and very easy to use literally take from the time open the package to the time start snap picture digital camera and very impressed the price reasonable under for the many feature contain highly recommend ', 'key_words': ['snap', 'package', 'reasonable', 'picture', 'start', 'price', 'open', 'time'], 'summary': '<s> awesome little camera perfect for beginner </s>', 'decoded_str': '[UNK] awesome little camera for beginner [UNK]'}
# best_score: {'rouge-1': {'f': 0.7142857093877552, 'p': 0.8333333333333334, 'r': 0.625}, 'rouge-2': {'f': 0.4615384565680473, 'p': 0.5, 'r': 0.42857142857142855}, 'rouge-l': {'f': 0.6868131868129999, 'p': 0.8333333333333334, 'r': 0.625}}
# epoch: 87 iter: 289000 mle_loss: 1.302 reward: 0.0000
# best_res: {'review': 'absolutely love new nikon the zoom unbelievable ton extra feature that hopefully will use but the camera excellent and would strongly recommend ', 'key_words': ['feature', 'extra', 'ton'], 'summary': '<s> best camera </s>', 'decoded_str': '[UNK] the camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 87 iter: 290000 mle_loss: 1.115 reward: 0.0000
# best_res: {'review': 'after look at lot different make and model this stand out also highly recommend by family member who love daughter love the picture qualitythe size and ease use ', 'key_words': ['qualitythe', 'model', 'size', 'stand'], 'summary': '<s> great little camera </s>', 'decoded_str': '[UNK] great little camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.6666666617283951, 'p': 0.75, 'r': 0.6}, 'rouge-2': {'f': 0.4999999950000001, 'p': 0.5, 'r': 0.5}, 'rouge-l': {'f': 0.6507936507933955, 'p': 0.75, 'r': 0.6}}
# epoch: 88 iter: 291000 mle_loss: 0.910 reward: 0.0000
# best_res: {'review': 'this great camera for nature photography follow recent purchase spend photograph san tripod migrate hummingbird the long zoom high resolutionvibration controland continuous shooting mode lead to some great photograph the close up mode has also very useful while photograph plant ', 'key_words': ['mode', 'zoom', 'long', 'great', 'photograph', 'continuous', 'camera', 'shooting', 'close'], 'summary': '<s> camera for the bird </s>', 'decoded_str': '[UNK] camera for bargain [UNK]'}
# best_score: {'rouge-1': {'f': 0.39999999520000007, 'p': 0.5, 'r': 0.3333333333333333}, 'rouge-2': {'f': 0.22222221728395072, 'p': 0.25, 'r': 0.2}, 'rouge-l': {'f': 0.371428571428493, 'p': 0.5, 'r': 0.3333333333333333}}
# epoch: 88 iter: 292000 mle_loss: 1.570 reward: 0.0000
# best_res: {'review': 'have see better picture with disposable camera save money the camera cute buy as gift but very disappointing quality ', 'key_words': ['quality', 'gift', 'very', 'disappointing'], 'summary': '<s> not buy this camera real dud </s>', 'decoded_str': '[UNK] not buy this camera not picture real brand real [UNK]'}
# best_score: {'rouge-1': {'f': 0.624999995, 'p': 0.625, 'r': 0.625}, 'rouge-2': {'f': 0.3529411716262976, 'p': 0.3, 'r': 0.42857142857142855}, 'rouge-l': {'f': 0.6249999999995, 'p': 0.625, 'r': 0.625}}
# epoch: 88 iter: 293000 mle_loss: 1.107 reward: 0.0000
# best_res: {'review': 'excellent quality picture and hd video awesomeness because this camera can actually carry around easily so long as keep the subject properly light preferably with daylight will see great picture for hd video absolutely need great lighting otherwise the video will grainy ', 'key_words': ['great', 'picture', 'video', 'quality', 'lighting', 'excellent'], 'summary': '<s> great for picture and video clip good lighting must </s>', 'decoded_str': '[UNK] great picture and video clip good lighting must lighting must lighting good lighting [UNK]'}
# best_score: {'rouge-1': {'f': 0.79999999505, 'p': 0.8888888888888888, 'r': 0.7272727272727273}, 'rouge-2': {'f': 0.5714285664399092, 'p': 0.5454545454545454, 'r': 0.6}, 'rouge-l': {'f': 0.7844660194171955, 'p': 0.8888888888888888, 'r': 0.7272727272727273}}
# epoch: 89 iter: 294000 mle_loss: 0.922 reward: 0.0000
# best_res: {'review': 'good price accurate and very reasonable can put pocket and fit the palm hand has decent incident reading ', 'key_words': ['palm', 'incident', 'good', 'decent', 'fit', 'price'], 'summary': '<s> perfectly useful tiny light meter with analogue readout </s>', 'decoded_str': '[UNK] analogue meter [UNK]'}
# best_score: {'rouge-1': {'f': 0.3076923041420118, 'p': 0.6666666666666666, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.10613437195724833, 'p': 0.3333333333333333, 'r': 0.1}}
# epoch: 89 iter: 295000 mle_loss: 0.952 reward: 0.0000
# best_res: {'review': 'this camera unbelievable crisp photo and high definition video not to mention very easy to use and navigate through the setting highly recommend for novice photographer professional ', 'key_words': ['crisp', 'definition', 'high', 'video', 'photo'], 'summary': '<s> awesome camera </s>', 'decoded_str': '[UNK] awesome camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.5714285665306124, 'p': 0.6666666666666666, 'r': 0.5}, 'rouge-2': {'f': 0.3333333283333334, 'p': 0.3333333333333333, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.5494505494503625, 'p': 0.6666666666666666, 'r': 0.5}}
# epoch: 89 iter: 296000 mle_loss: 1.143 reward: 0.0000
# best_res: {'review': 'for anyone else try to find info what type memory card to use page the user manual which available through nikon had trouble figure out what memory card to buy when order the camera the short answer sdhc sdxc memory card speed class higher for shoot movie the approve list sandisk toshiba panasonic and lexar just get so star base expectation will report back after have have experience ', 'key_words': ['panasonic', 'answer', 'higher', 'short', 'toshiba', 'class', 'lexar'], 'summary': '<s> memory card comment </s>', 'decoded_str': '[UNK] comment the panasonic comment [UNK]'}
# best_score: {'rouge-1': {'f': 0.22222221728395072, 'p': 0.25, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.21693121693096162, 'p': 0.25, 'r': 0.2}}
# epoch: 89 iter: 297000 mle_loss: 1.023 reward: 0.0000
# best_res: {'review': 'get this camera after to steves digicam review and print out sample pic from this camera stylus and find the produce the best overall picture with bright color and good depth perception ', 'key_words': ['depth', 'bright', 'color', 'find', 'good', 'produce', 'perception'], 'summary': '<s> excellent camera despite low flash power </s>', 'decoded_str': '[UNK] excellent camera despite low flash despite flash capability [UNK]'}
# best_score: {'rouge-1': {'f': 0.6666666616888889, 'p': 0.7142857142857143, 'r': 0.625}, 'rouge-2': {'f': 0.4999999950781251, 'p': 0.4444444444444444, 'r': 0.5714285714285714}, 'rouge-l': {'f': 0.6608187134499368, 'p': 0.7142857142857143, 'r': 0.625}}
# epoch: 90 iter: 298000 mle_loss: 1.301 reward: 0.0000
# best_res: {'review': 'this camera ahead time back even with improvement process new equipement etc this camera consistent sturdy and has excellent image quality from iso net out other camera provide additional bell whistle but have really only catch up slightly push past the image quality this camera here decision for purchase this camera image quality big viewfinder fully utilize wide lens consistency output and control this camera best buy at the current price ', 'key_words': ['image', 'price', 'current', 'quality', 'excellent'], 'summary': '<s> and compete with latest greatest camera </s>', 'decoded_str': '[UNK] and greatest camera greatest micro market [UNK]'}
# best_score: {'rouge-1': {'f': 0.4285714236734694, 'p': 0.5, 'r': 0.375}, 'rouge-2': {'f': 0.14285713785714302, 'p': 0.14285714285714285, 'r': 0.14285714285714285}, 'rouge-l': {'f': 0.4120879120877251, 'p': 0.5, 'r': 0.375}}
# epoch: 90 iter: 299000 mle_loss: 1.309 reward: 0.0000
# best_res: {'review': 'completely satisfied with camera first thing to upgrade the camera firmware pick up the adaptor for for the hd video pocket cam this camera hit easy to use take great picture ', 'key_words': ['upgrade', 'picture', 'camera', 'great'], 'summary': '<s> very good camera </s>', 'decoded_str': '[UNK] very happy with purchase [UNK]'}
# best_score: {'rouge-1': {'f': 0.19999999500000015, 'p': 0.2, 'r': 0.2}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.19999999999950002, 'p': 0.2, 'r': 0.2}}
# epoch: 90 iter: 300000 mle_loss: 1.164 reward: 0.0000
# best_res: {'review': 'camera cool but the picture small very easy to set up remember the old polaroid like better but with digital just can not compete ', 'key_words': ['small', 'picture', 'camera'], 'summary': '<s> cool camera </s>', 'decoded_str': '[UNK] good camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.2857142808163266, 'p': 0.3333333333333333, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.2747252747250878, 'p': 0.3333333333333333, 'r': 0.25}}
# epoch: 91 iter: 301000 mle_loss: 1.080 reward: 0.0000
# best_res: {'review': 'buy wife new and fit perfectly this case there also zipper compartment for key credit car and memory card real nice ', 'key_words': ['key', 'memory', 'card', 'car', 'credit'], 'summary': '<s> camera case </s>', 'decoded_str': '[UNK] camera case [UNK]'}
# best_score: {'rouge-1': {'f': 0.5714285665306124, 'p': 0.6666666666666666, 'r': 0.5}, 'rouge-2': {'f': 0.3333333283333334, 'p': 0.3333333333333333, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.5494505494503625, 'p': 0.6666666666666666, 'r': 0.5}}
# epoch: 91 iter: 302000 mle_loss: 0.976 reward: 0.0000
# best_res: {'review': 'after use get particle dust hair inside the camera either the sensor the back the lens mean all picture show the foreign article offer to clean the camera for plus shipping google search this and will find that these camera subject to this type dust not want to pay the so buy canon sx will never buy another panasonic and shoot ', 'key_words': ['foreign', 'article', 'camera', 'find'], 'summary': '<s> dust sensor after use mar all photo </s>', 'decoded_str': '[UNK] dust sensor after use mar after use [UNK]'}
# best_score: {'rouge-1': {'f': 0.6666666618666668, 'p': 0.8333333333333334, 'r': 0.5555555555555556}, 'rouge-2': {'f': 0.5333333283555556, 'p': 0.5714285714285714, 'r': 0.5}, 'rouge-l': {'f': 0.6190476190475407, 'p': 0.8333333333333334, 'r': 0.5555555555555556}}
# epoch: 91 iter: 303000 mle_loss: 0.988 reward: 0.0000
# best_res: {'review': 'use this for work as property inspector the optical zoom allow to get great shot from distance without necessarily have to get right up the subject have set up as need and have not use many the other feature just happy to able to get optical zoom at such great price this replacement for panasonic tz that take over picture before start to wear out mechanically take real beating out the field hope this last as long ', 'key_words': ['price', 'zoom', 'great', 'shot', 'optical'], 'summary': '<s> awesome camera </s>', 'decoded_str': '[UNK] awesome camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.5714285665306124, 'p': 0.6666666666666666, 'r': 0.5}, 'rouge-2': {'f': 0.3333333283333334, 'p': 0.3333333333333333, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.5494505494503625, 'p': 0.6666666666666666, 'r': 0.5}}
# epoch: 92 iter: 304000 mle_loss: 0.904 reward: 0.0000
# best_res: {'review': 'digital camera so have some sentimental attachment here have forget about mkii and carry this everywhere love the simplicity macro high iso and creative mode would have nice to have longer zoom but still deserve star ', 'key_words': ['longer', 'mode', 'love', 'zoom', 'iso', 'high', 'simplicity', 'creative'], 'summary': '<s> best point shoot available </s>', 'decoded_str': '[UNK] best shoot available available available [UNK]'}
# best_score: {'rouge-1': {'f': 0.5999999952, 'p': 0.75, 'r': 0.5}, 'rouge-2': {'f': 0.19999999500000015, 'p': 0.2, 'r': 0.2}, 'rouge-l': {'f': 0.5571428571427788, 'p': 0.75, 'r': 0.5}}
# epoch: 92 iter: 305000 mle_loss: 0.987 reward: 0.0000
# best_res: {'review': 'will never buy from beach camera again nor another nikon the new camera miss very inexpensive lens cover strap which nor beach camera refuse to make good not receive everything pay for and receive no assistance just brush off from the manufacturer and seller ', 'key_words': ['nikon', 'buy'], 'summary': '<s> dis satisfaction </s>', 'decoded_str': '[UNK] dis satisfaction [UNK]'}
# best_score: {'rouge-1': {'f': 0.5714285665306124, 'p': 0.6666666666666666, 'r': 0.5}, 'rouge-2': {'f': 0.3333333283333334, 'p': 0.3333333333333333, 'r': 0.3333333333333333}, 'rouge-l': {'f': 0.5494505494503625, 'p': 0.6666666666666666, 'r': 0.5}}
# epoch: 92 iter: 306000 mle_loss: 1.253 reward: 0.0000
# best_res: {'review': 'flood use no deeper then meter that dive need to discuss what to rather disappointed as the whole reaseon buy this for dive please advise what the proper procedure from here live right now and will need replacement ', 'key_words': ['procedure', 'proper'], 'summary': '<s> please contact </s>   <s> there problem </s>', 'decoded_str': '[UNK] please contact [UNK] [UNK] there [UNK] [UNK]'}
# best_score: {'rouge-1': {'f': 0.5999999952, 'p': 0.75, 'r': 0.5}, 'rouge-2': {'f': 0.1538461488757398, 'p': 0.16666666666666666, 'r': 0.14285714285714285}, 'rouge-l': {'f': 0.5571428571427788, 'p': 0.75, 'r': 0.5}}
# epoch: 92 iter: 307000 mle_loss: 0.923 reward: 0.0000
# best_res: {'review': 'this camera fail the time bring into the water prepare the camera accord to panasonic direction into shallow pool underwater take image and the camera stop work send to panasonic deny warranty coverage have now deal with different department at panasonic all tow the company line claim abuse the camera and only offer to sell refurbish camera at cost have total nightmare that say watch out great camera until ask to what suppose to ', 'key_words': ['shallow', 'pool', 'panasonic', 'prepare', 'water', 'refurbish', 'sell', 'bring', 'camera', 'direction'], 'summary': '<s> camera leak </s>', 'decoded_str': '[UNK] leak leak [UNK]'}
# best_score: {'rouge-1': {'f': 0.33333332888888895, 'p': 0.5, 'r': 0.25}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.27777777777785184, 'p': 0.5, 'r': 0.25}}
# epoch: 93 iter: 308000 mle_loss: 1.597 reward: 0.0000
# best_res: {'review': 'use to have olympus zoom camera bulky and only mp this camera much more compact with big lcd display look great have use for so work flawlessly wife like that what really matter will trip to the camera will get lot usage for sure ', 'key_words': ['lcd', 'big', 'camera', 'trip', 'display'], 'summary': '<s> decent camera for the price </s>', 'decoded_str': '[UNK] decent camera for the price [UNK]'}
# best_score: {'rouge-1': {'f': 0.7692307642603551, 'p': 0.8333333333333334, 'r': 0.7142857142857143}, 'rouge-2': {'f': 0.6666666616666668, 'p': 0.6666666666666666, 'r': 0.6666666666666666}, 'rouge-l': {'f': 0.7602862254021723, 'p': 0.8333333333333334, 'r': 0.7142857142857143}}
# epoch: 93 iter: 309000 mle_loss: 1.056 reward: 0.0000
# best_res: {'review': 'have camera system at business always keep extra camera hand for when older camera fail have have some with life and other with life have replace some older camera with these and have to say that the resolution better than older sonys these totally better than some more expensive lorex camera that buy fry will buy these again when need more camera ', 'key_words': ['camera', 'expensive', 'lorex', 'sonys', 'older'], 'summary': '<s> great camera inexpensive price </s>', 'decoded_str': '[UNK] excellent camera [UNK]'}
# best_score: {'rouge-1': {'f': 0.22222221777777784, 'p': 0.3333333333333333, 'r': 0.16666666666666666}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.18518518518525923, 'p': 0.3333333333333333, 'r': 0.16666666666666666}}

# %%
# if self.opt.train_rl == "yes":
# ~/Users/leyan/Text-Summarizer-FOP/data_util/data.py in outputids2words(id_list, vocab, review_oovs)
#     141       review_oov_idx = i - vocab.size()
#     142       try:
# --> 143         w = review_oovs[review_oov_idx]
#     144       except ValueError as e: # i doesn't correspond to an review oov
#     145         raise ValueError('Error: model produced word ID %i which corresponds to review OOV %i but this example only has %i review OOVs' % (i, review_oov_idx, len(review_oovs)))

# IndexError: list index out of range
